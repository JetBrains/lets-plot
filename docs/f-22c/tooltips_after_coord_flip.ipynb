# %%
import numpy as np
from lets_plot import *
LetsPlot.setup_html()
# Out:
#             <div id="6ZpbtM"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v2.5.0rc1/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("6ZpbtM").appendChild(div);
#                     };
#                     var e = document.getElementById("6ZpbtM");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
n = 200
np.random.seed(42)

x = np.repeat(['A','B'], n)
y = np.concatenate((np.random.normal(0, 1, n), np.random.normal(.8, 1, n)))

ggplot({'x': x, 'y': y}, aes(x='x', y='y', color='x')) + geom_boxplot() + coord_flip()
# Out:
#    <div id="lQ9wPQ"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "color":"x"
# },
# "data_meta":{
# },
# "coord":{
# "name":"flip",
# "flip":true
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"boxplot",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# "..middle..":[NaN,NaN,NaN,-0.004191884047736516,NaN,NaN,0.8788393487900246],
# "..lower..":[NaN,NaN,NaN,-0.7082022559518601,NaN,NaN,0.1885418015103058],
# "..upper..":[NaN,NaN,NaN,0.5049907930622943,NaN,NaN,1.488202091042813],
# "..ymin..":[NaN,NaN,NaN,-1.9875689146008928,NaN,NaN,-1.3238957243098068],
# "..ymax..":[NaN,NaN,NaN,2.1904556258099785,NaN,NaN,3.1146585666735085],
# "x":["A","A","A","A","B","B","B"],
# "y":[-2.6197451040897444,2.463242112485286,2.720169166589619,NaN,4.6527314906547215,-2.4412673400690723,NaN]
# }
# }]
# };
#            var plotContainer = document.getElementById("lQ9wPQ");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
