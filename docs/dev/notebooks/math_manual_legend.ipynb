# %%
import numpy as np
from lets_plot import *

# %%
LetsPlot.setup_html()
# Out:
#             <div id="uqbLbN"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.6.2/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("uqbLbN").appendChild(div);
#                     };
#                     var e = document.getElementById("uqbLbN");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
# Define the functions
def f1(x):
    return np.sin(3*x) / (x * (np.cos(x) + 2))

def f2(x):
    return np.cos(x) / x

def f3(x):
    return np.exp(-x)

# %%
c = ['#FFB6C1', '#AAFFAA', '#ADD8E6']
p = (ggplot()
  + geom_vline(xintercept=0, size=0.4)   
  + geom_hline(yintercept=0, size=0.4)   
  + geom_function(fun=f1, xlim=[0.1, 12], color=c[0], size=2, 
                  n=300, manual_key=layer_key('      sin(3x) \n--------\n x(cos(x) + 2)', size=3))
                  # n=300, manual_key=layer_key('      sin(3x)', size=3))
  + geom_function(fun=f2, xlim=[0.1, 12], color=c[1], 
                  n=300, manual_key=layer_key('cos(x) / x', size=3))
  + geom_function(fun=f3, xlim=[0.1, 12], color=c[2], 
                  n=300, manual_key=layer_key('\( e^{-x} \)', size=3))
  + scale_x_continuous(expand=[0, 0.2])
  + scale_y_continuous(limits=[-0.4, 1.0])
  + labs(
      x='x',
      y='f(x)',
      title='Mathematical Functions'
    )
  + theme_classic()
     
  + theme(
      # Titles, labels
      text=element_text(face='italic', family='Computer Modern'), 
      plot_title=element_text(size=20, hjust=0.05),
      axis_title=element_text(size=18),
      legend_text=element_text(size=18, vjust=0.5),
      # Legend
      legend_background=element_rect(size=1),
      legend_position=[0.95, 0.9], 
      legend_justification=[1, 1],
      # Axis, gridlines                 
      axis_line='blank', axis_ticks='blank',
      panel_grid_major=element_line(linetype='longdash'),
  )
  + theme(
      # Layout improvements
      panel_inset=4,
      plot_inset=0,
      axis_text=element_text(margin=0),
      axis_title=element_text(margin=0),
      plot_margin=16
  )
     
  + flavor_solarized_dark()   
  + ggsize(900, 500)   
)     

p
# Out:
#    <div id="pmqpSy"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("pmqpSy");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Mathematical Functions"
# },
# "guides":{
# "x":{
# "title":"x"
# },
# "y":{
# "title":"f(x)"
# }
# },
# "theme":{
# "name":"classic",
# "text":{
# "family":"Computer Modern",
# "face":"italic",
# "blank":false
# },
# "axis_title":{
# "size":18.0,
# "blank":false,
# "margin":0.0
# },
# "axis_ticks":"blank",
# "axis_line":"blank",
# "legend_background":{
# "size":1.0,
# "blank":false
# },
# "legend_text":{
# "size":18.0,
# "vjust":0.5,
# "blank":false
# },
# "legend_position":[0.95,0.9],
# "legend_justification":[1.0,1.0],
# "panel_grid_major":{
# "linetype":"longdash",
# "blank":false
# },
# "plot_title":{
# "size":20.0,
# "hjust":0.05,
# "blank":false
# },
# "axis_text":{
# "margin":0.0,
# "blank":false
# },
# "panel_inset":4.0,
# "plot_margin":16.0,
# "plot_inset":0.0,
# "flavor":"solarized_dark"
# },
# "ggsize":{
# "width":900.0,
# "height":500.0
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0.0,0.2]
# },{
# "aesthetic":"y",
# "limits":[-0.4,1.0]
# }],
# "layers":[{
# "geom":"vline",
# "mapping":{
# },
# "data_meta":{
# },
# "xintercept":0.0,
# "size":0.4,
# "data":{
# }
# },{
# "geom":"hline",
# "mapping":{
# },
# "data_meta":{
# },
# "yintercept":0.0,
# "size":0.4,
# "data":{
# }
# },{
# "geom":"line",
# "stat":"identity",
# "data":{
# "x":[0.1,0.13979933110367893,0.17959866220735787,0.21939799331103682,0.25919732441471577,0.2989966555183947,0.3387959866220736,0.3785953177257525,0.41839464882943145,0.4581939799331104,0.49799331103678934,0.5377926421404683,0.5775919732441472,0.6173913043478261,0.657190635451505,0.696989966555184,0.7367892976588629,0.7765886287625419,0.8163879598662208,0.8561872909698998,0.8959866220735787,0.9357859531772575,0.9755852842809365,1.0153846153846156,1.0551839464882944,1.0949832775919734,1.1347826086