# %% [markdown]
# ggsave (.svg) transforms geom_text integer to float #626
#
# https://github.com/JetBrains/lets-plot/issues/626

# %%
from lets_plot import *
from IPython.display import SVG, Image, HTML
LetsPlot.setup_html()

p = ggplot() + geom_label(aes(x=[0], y=[0], label=[777]))
p
# Out:
#             <div id="27sWFX"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "http://10.100.0.127:8080/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("27sWFX").appendChild(div);
#                     };
#                     var e = document.getElementById("27sWFX");
#                     e.appendChild(script);
#                 })()
#             </script>
#    <div id="uDyftR"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"label",
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "data_meta":{
# },
# "data":{
# "x":[0.0],
# "y":[0.0],
# "label":[777.0]
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("uDyftR");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
display(SVG(ggsave(p, 'issue_626.svg')))
