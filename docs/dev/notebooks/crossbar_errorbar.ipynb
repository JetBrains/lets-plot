# %%
from lets_plot import *

LetsPlot.setup_html()
LetsPlot.set_theme(theme_grey())
# Out:
#             <script type="text/javascript" data-lets-plot-script="library">
#                 window.letsPlotCall = function(f) {f();};
#                 console.log('Embedding: lets-plot-latest.min.js');
# ...

# %%
data = {
    'drink': ['coffee','tea','water', 'milk'],
    'mean': [3, 4, 6, 2],
    'upper': [1, 5, 7, 4],
    'lower': [6, 3, 2, 1]
}

# %%
ggplot(data) + \
    geom_crossbar(aes(x='drink', middle='mean', ymin='lower', ymax='upper', color='mean'),
                  tooltips=layer_tooltips().disable_splitting()) + \
    scale_color_discrete() + theme_grey()
# Out:
#    <div id="xIB4Pt"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "drink":["coffee","tea","water","milk"],
# "mean":[3.0,4.0,6.0,2.0],
# "upper":[1.0,5.0,7.0,4.0],
# "lower":[6.0,3.0,2.0,1.0]
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "name":"grey"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"color",
# "discrete":true
# }],
# "layers":[{
# "geom":"crossbar",
# "mapping":{
# "x":"drink",
# "middle":"mean",
# "ymin":"lower",
# "ymax":"upper",
# "color":"mean"
# },
# "tooltips":{
# "formats":[],
# "disable_splitting":true
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("xIB4Pt");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
ggplot(data) + \
    geom_crossbar(aes(x='drink', middle='mean', ymin='lower', ymax='upper', color='mean'),
                  fill_by='color',
                  tooltips=layer_tooltips().disable_splitting()) + \
    scale_color_discrete()
# Out:
#    <div id="egbuQR"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "drink":["coffee","tea","water","milk"],
# "mean":[3.0,4.0,6.0,2.0],
# "upper":[1.0,5.0,7.0,4.0],
# "lower":[6.0,3.0,2.0,1.0]
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "name":"grey"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"color",
# "discrete":true
# }],
# "layers":[{
# "geom":"crossbar",
# "mapping":{
# "x":"drink",
# "middle":"mean",
# "ymin":"lower",
# "ymax":"upper",
# "color":"mean"
# },
# "tooltips":{
# "formats":[],
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fill_by":"color",
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("egbuQR");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
ggplot(data) + geom_crossbar(aes(x='drink', middle='mean', ymin='lower', ymax='upper', color='mean'))
# Out:
#    <div id="477tHa"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "drink":["coffee","tea","water","milk"],
# "mean":[3.0,4.0,6.0,2.0],
# "upper":[1.0,5.0,7.0,4.0],
# "lower":[6.0,3.0,2.0,1.0]
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "name":"grey"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"crossbar",
# "mapping":{
# "x":"drink",
# "middle":"mean",
# "ymin":"lower",
# "ymax":"upper",
# "color":"mean"
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("477tHa");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
ggplot(data) + \
    geom_errorbar(aes(x='drink', y='mean', ymin='lower', ymax='upper', color='mean')) + \
    scale_color_discrete()
# Out:
#    <div id="9JWvpx"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "drink":["coffee","tea","water","milk"],
# "mean":[3.0,4.0,6.0,2.0],
# "upper":[1.0,5.0,7.0,4.0],
# "lower":[6.0,3.0,2.0,1.0]
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "name":"grey"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"color",
# "discrete":true
# }],
# "layers":[{
# "geom":"errorbar",
# "mapping":{
# "x":"drink",
# "y":"mean",
# "ymin":"lower",
# "ymax":"upper",
# "color":"mean"
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("9JWvpx");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
ggplot(data) + \
    geom_pointrange(aes(x='drink', y='mean', ymin='lower', ymax='upper', fill='mean'), \
                    size=3, linewidth=3, shape=21, color='dark_green') + \
    scale_fill_discrete()
# Out:
#    <div id="DoFmkq"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "drink":["coffee","tea","water","milk"],
# "mean":[3.0,4.0,6.0,2.0],
# "upper":[1.0,5.0,7.0,4.0],
# "lower":[6.0,3.0,2.0,1.0]
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "name":"grey"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "discrete":true
# }],
# "layers":[{
# "geom":"pointrange",
# "mapping":{
# "x":"drink",
# "y":"mean",
# "ymin":"lower",
# "ymax":"upper",
# "fill":"mean"
# },
# "data_meta":{
# },
# "size":3.0,
# "linewidth":3.0,
# "shape":21.0,
# "color":"dark_green",
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("DoFmkq");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
ggplot(data) + \
    geom_pointrange(aes(x='drink', y='mean', ymin='lower', ymax='upper', fill='mean'),
                    size=3, linewidth=3, shape=21, color='dark_green', alpha=0.5) + \
    scale_fill_discrete()
# Out:
#    <div id="CiRsNI"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "drink":["coffee","tea","water","milk"],
# "mean":[3.0,4.0,6.0,2.0],
# "upper":[1.0,5.0,7.0,4.0],
# "lower":[6.0,3.0,2.0,1.0]
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "name":"grey"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "discrete":true
# }],
# "layers":[{
# "geom":"pointrange",
# "mapping":{
# "x":"drink",
# "y":"mean",
# "ymin":"lower",
# "ymax":"upper",
# "fill":"mean"
# },
# "data_meta":{
# },
# "size":3.0,
# "linewidth":3.0,
# "shape":21.0,
# "color":"dark_green",
# "alpha":0.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("CiRsNI");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
