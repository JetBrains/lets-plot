# %% [markdown]
# # Layer Labels (Annotations) in `geom_crossbar`

# %%
from lets_plot import *
LetsPlot.setup_html()
# Out:
#             <div id="14aJX9"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.7.0rc1/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("14aJX9").appendChild(div);
#                     };
#                     var e = document.getElementById("14aJX9");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
data = {
    'vertical_category': ['Without midline', 'Above midline', 'Below midline', 'Above bar', 'Below bar'],
    'horisontal_category': ['Without midline', 'Right of midline', 'Left of midline', 'Right of bar', 'Left of bar'],
    'ymin': [0, 5, 5, 0, 20],
    'ymax': [20, 20, 20, 2, 22],
    'y': [None, 6, 19, 1, 21],
    'value': [20, 15, 15, 2, 2]
}

# %% [markdown]
# ### Automatic Text Positioning

# %%
ggplot(data) + \
    geom_crossbar(
        aes(x='vertical_category', y='y', ymin='ymin', ymax='ymax'), 
        labels=layer_labels(["value"]).size(20))
# Out:
#    <div id="G5ojYg"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("G5ojYg");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# "vertical_category":["Without midline","Above midline","Below midline","Above bar","Below bar"],
# "ymin":[0.0,5.0,5.0,0.0,20.0],
# "ymax":[20.0,20.0,20.0,2.0,22.0],
# "y":[null,6.0,19.0,1.0,21.0],
# "value":[20.0,15.0,15.0,2.0,2.0]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"vertical_category"
# },{
# "type":"str",
# "column":"horisontal_category"
# },{
# "type":"int",
# "column":"ymin"
# },{
# "type":"int",
# "column":"ymax"
# },{
# "type":"int",
# "column":"y"
# },{
# "type":"int",
# "column":"value"
# }]
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"crossbar",
# "mapping":{
# "x":"vertical_category",
# "y":"y",
# "ymin":"ymin",
# "ymax":"ymax"
# },
# "data_meta":{
# },
# "labels":{
# "formats":[],
# "variables":["value"],
# "annotation_size":20.0
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"1"
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %%
ggplot(data) + coord_flip() + \
    geom_crossbar(
        aes(x='horisontal_category', y='y', ymin='ymin', ymax='ymax'), 
        labels=layer_labels(["value"]).size(20))
# Out:
#    <div id="FdH2Vb"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("FdH2Vb");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# "horisontal_category":["Without midline","Right of midline","Left of midline","Right of bar","Left of bar"],
# "ymin":[0.0,5.0,5.0,0.0,20.0],
# "ymax":[20.0,20.0,20.0,2.0,22.0],
# "y":[null,6.0,19.0,1.0,21.0],
# "value":[20.0,15.0,15.0,2.0,2.0]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"vertical_category"
# },{
# "type":"str",
# "column":"horisontal_category"
# },{
# "type":"int",
# "column":"ymin"
# },{
# "type":"int",
# "column":"ymax"
# },{
# "type":"int",
# "column":"y"
# },{
# "type":"int",
# "column":"value"
# }]
# },
# "coord":{
# "name":"flip",
# "flip":true
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"crossbar",
# "mapping":{
# "x":"horisontal_category",
# "y":"y",
# "ymin":"ymin",
# "ymax":"ymax"
# },
# "data_meta":{
# },
# "labels":{
# "formats":[],
# "variables":["value"],
# "annotation_size":20.0
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"2"
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# ### Long Labels Handling
# Lond text strings that don't fit in the bar are drawn with a background.

# %%
ggplot(data) + \
    geom_crossbar(
        aes(x='vertical_category', y='y', ymin='ymin', ymax='ymax'), 
        fill='lightblue',
        labels=layer_labels(["vertical_category"]).size(20))
# Out:
#    <div id="ET1ArC"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("ET1ArC");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# "vertical_category":["Without midline","Above midline","Below midline","Above bar","Below bar"],
# "ymin":[0.0,5.0,5.0,0.0,20.0],
# "ymax":[20.0,20.0,20.0,2.0,22.0],
# "y":[null,6.0,19.0,1.0,21.0]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"vertical_category"
# },{
# "type":"str",
# "column":"horisontal_category"
# },{
# "type":"int",
# "column":"ymin"
# },{
# "type":"int",
# "column":"ymax"
# },{
# "type":"int",
# "column":"y"
# },{
# "type":"int",
# "column":"value"
# }]
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"crossbar",
# "mapping":{
# "x":"vertical_category",
# "y":"y",
# "ymin":"ymin",
# "ymax":"ymax"
# },
# "data_meta":{
# },
# "labels":{
# "formats":[],
# "variables":["vertical_category"],
# "annotation_size":20.0
# },
# "fill":"lightblue",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"3"
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# ### Inheriting the Geometry Colors

# %%
ggplot(data) + \
    geom_crossbar(
        aes(x='vertical_category', y='y', ymin='ymin', ymax='ymax', color="vertical_category"), 
        show_legend=False,
        labels=layer_labels(["value"])
            .size(20)
            .inherit_color()      # <--- Enable using the geometry color in labels.
    )
# Out:
#    <div id="lsrUlZ"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("lsrUlZ");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# "vertical_category":["Without midline","Above midline","Below midline","Above bar","Below bar"],
# "ymin":[0.0,5.0,5.0,0.0,20.0],
# "ymax":[20.0,20.0,20.0,2.0,22.0],
# "y":[null,6.0,19.0,1.0,21.0],
# "value":[20.0,15.0,15.0,2.0,2.0]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"vertical_category"
# },{
# "type":"str",
# "column":"horisontal_category"
# },{
# "type":"int",
# "column":"ymin"
# },{
# "type":"int",
# "column":"ymax"
# },{
# "type":"int",
# "column":"y"
# },{
# "type":"int",
# "column":"value"
# }]
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"crossbar",
# "mapping":{
# "x":"vertical_category",
# "y":"y",
# "ymin":"ymin",
# "ymax":"ymax",
# "color":"vertical_category"
# },
# "show_legend":false,
# "data_meta":{
# },
# "labels":{
# "formats":[],
# "variables":["value"],
# "annotation_size":20.0,
# "use_layer_color":true
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"4"
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>
