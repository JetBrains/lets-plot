# %%
import numpy as np
from lets_plot import *

load_lets_plot_js()
# Out:
#             <div id="NGHV64"></div>
#             <script type="text/javascript">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://dl.bintray.com/jetbrains/datalore-plot/datalore-plot-0.0.1rc4.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#             var div = document.createElement("div");
#             div.style.color = 'darkblue';
# ...

# %%
# This example was found at: https://jakevdp.github.io/PythonDataScienceHandbook/04.04-density-and-contour-plots.html
def f(x, y):
    return np.sin(x) ** 10 + np.cos(10 + y * x) * np.cos(x)

x = np.arange(0, 5, 6./50)
y = np.arange(0, 5, 6./40)
X, Y = np.meshgrid(x, y)
Z = f(X, Y)

# %%
data = dict(
    x = X.reshape(-1),
    y = Y.reshape(-1),
    z = Z.reshape(-1)
)

# %%
p = ggplot(data, aes('x', 'y', fill='z'))
# Draw tile plot
p + geom_tile() + scale_fill_hue()
# Out:
#             <div id="plot_output_chjHyJ"></div>
#             <script type="text/javascript">
#                 (function() {
#                     var plotSpec={
# 'data':{
# ...

# %%
# Same but in grey
#  - remove colorbar
p1 = p + geom_tile(alpha=.5) + scale_fill_grey(100, 20, guide='none')
p1
# Out:
#             <div id="plot_output_SK36LD"></div>
#             <script type="text/javascript">
#                 (function() {
#                     var plotSpec={
# 'data':{
# ...

# %%
# Add contours
p1 + geom_contour(aes(z='z'), color='red')
# Out:
#             <div id="plot_output_BQj8Gs"></div>
#             <script type="text/javascript">
#                 (function() {
#                     var plotSpec={
# 'data':{
# ...

# %%
# Set contour color by level
p1 + geom_contour(aes(z='z', color='..level..')) + scale_color_gradient(low='dark_green', high='yellow')
# Out:
#             <div id="plot_output_ZlY0P3"></div>
#             <script type="text/javascript">
#                 (function() {
#                     var plotSpec={
# 'data':{
# ...

# %% [markdown]
# ### Filling contours by level

# %%
p2 = ggplot(data, aes('x', 'y'))

# Filled polygons are not working well in this case
p2 + geom_polygon(aes(z='z',fill='..level..'), stat='contour')
# Out:
#             <div id="plot_output_ZUXwIj"></div>
#             <script type="text/javascript">
#                 (function() {
#                     var plotSpec={
# 'data':{
# },
# 'mapping':{
# 'x':"x",
# 'y':"y"
# },
# 'kind':"plot",
# 'scales':[],
# 'layers':[{
# 'geom':"polygon",
# 'stat':"contour",
# 'mapping':{
# 'z':"z",
# 'fill':"..level.."
# },
# 'data':{
# ...

# %%
# 'contourf' geom works a lot better
p2 + geom_contourf(aes(z='z',fill='..level..'))
# Out:
#             <div id="plot_output_p2VGQa"></div>
#             <script type="text/javascript">
#                 (function() {
#                     var plotSpec={
# 'data':{
# },
# 'mapping':{
# 'x':"x",
# 'y':"y"
# },
# 'kind':"plot",
# 'scales':[],
# 'layers':[{
# 'geom':"contourf",
# 'mapping':{
# 'z':"z",
# 'fill':"..level.."
# },
# 'data':{
# ...
