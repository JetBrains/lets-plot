# %% [markdown]
# <em><sub>This page is available as an executable or viewable <strong>Jupyter Notebook</strong>:</sub></em>
# <br/><br/>
# <a href="https://mybinder.org/v2/gh/JetBrains/lets-plot/v2.0.3demos1?filepath=docs%2Fexamples%2Fjupyter-notebooks%2Fmap_basemap_gallery.ipynb"
#    target="_parent">
#    <img align="left"
#         src="https://mybinder.org/badge_logo.svg">
# </a>
# <a href="https://nbviewer.jupyter.org/github/JetBrains/lets-plot/blob/master/docs/examples/jupyter-notebooks/map_basemap_gallery.ipynb"
#    target="_parent">
#    <img align="right"
#         src="https://raw.githubusercontent.com/jupyter/design/master/logos/Badges/nbviewer_badge.png"
#         width="109" height="20">
# </a>
# <br/>
# <br/>

# %% [markdown]
# ## The Gallery of Basemaps
#
# The Lets-plot library makes it really easy to add an interactive basemap layer to your plot.
#
# Lets-plot vector map tiles (standard and dark) are available by default.
#
# You can also configure any 3-rd party Z-X-Y raster map tiles services globally, using the `LetsPlot.set(maptiles_zxy(..))` method, or per individual plot, using the `tiles` argument in the `geom_livemap()` function.
#
# In this demo we will be using the `tiles` parameter because each plot here is using different map-tile service.

# %%
from lets_plot import *
LetsPlot.setup_html()
# Out:
#             <div id="agOEOK"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v2.0.3/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("agOEOK").appendChild(div);
#                     };
#                     var e = document.getElementById("agOEOK");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
def show_map(text, tiles=None):
    (ggplot() + geom_livemap(location=[13.3, 37.6], zoom=3, tiles=tiles) + 
     ggsize(500, 450) + 
     ggtitle(text)).show()

# %% [markdown]
# ### Lets-Plot vector tiles

# %%
show_map("Lets-Plot vector tiles (default).")
show_map("Lets-Plot vector tiles (dark).", maptiles_lets_plot(theme='dark'))
show_map("Lets-Plot vector tiles (light).", maptiles_lets_plot(theme='light'))
# Out:
#    <div id="sA9at3"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":500,
# "height":450
# },
# "ggtitle":{
# "text":"Lets-Plot vector tiles (default)."
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[13.3,37.6]
# },
# "zoom":3,
# "tiles":{
# "kind":"vector_lets_plot",
# "url":"wss://tiles.datalore.jetbrains.com",
# "theme":"color",
# "attribution":"Map: <a href=\"https://github.com/JetBrains/lets-plot\">© Lets-Plot</a>, map data: <a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a>."
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com"
# },
# "data":{
# }
# }]
# };
#            var plotContainer = document.getElementById("sA9at3");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
#    <div id="F0vBH0"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":500,
# "height":450
# },
# "ggtitle":{
# "text":"Lets-Plot vector tiles (dark)."
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[13.3,37.6]
# },
# "zoom":3,
# "tiles":{
# "kind":"vector_lets_plot",
# "url":"wss://tiles.datalore.jetbrains.com",
# "theme":"dark",
# "attribution":"Map: <a href=\"https://github.com/JetBrains/lets-plot\">© Lets-Plot</a>, map data: <a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a>."
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com"
# },
# "data":{
# }
# }]
# };
#            var plotContainer = document.getElementById("F0vBH0");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
#    <div id="ZNSNE9"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":500,
# "height":450
# },
# "ggtitle":{
# "text":"Lets-Plot vector tiles (light)."
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[13.3,37.6]
# },
# "zoom":3,
# "tiles":{
# "kind":"vector_lets_plot",
# "url":"wss://tiles.datalore.jetbrains.com",
# "theme":"light",
# "attribution":"Map: <a href=\"https://github.com/JetBrains/lets-plot\">© Lets-Plot</a>, map data: <a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a>."
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com"
# },
# "data":{
# }
# }]
# };
#            var plotContainer = document.getElementById("ZNSNE9");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ### OpenStreetMap
#
# [© OpenStreetMap contributors](https://www.openstreetmap.org/copyright)

# %%
show_map("OpenStreetMap's Standard tile layer", 
         maptiles_zxy(
             url="https://a.tile.openstreetmap.org/{z}/{x}/{y}.png",
             attribution='<a href="https://www.openstreetmap.org/copyright">© OpenStreetMap contributors</a>'
         )
    )
# Out:
#    <div id="nUhH4p"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":500,
# "height":450
# },
# "ggtitle":{
# "text":"OpenStreetMap's Standard tile layer"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[13.3,37.6]
# },
# "zoom":3,
# "tiles":{
# "kind":"raster_zxy",
# "url":"https://a.tile.openstreetmap.org/{z}/{x}/{y}.png",
# "attribution":"<a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a>"
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com"
# },
# "data":{
# }
# }]
# };
#            var plotContainer = document.getElementById("nUhH4p");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ### OpenTopoMap
#
# Map data: [© OpenStreetMap contributors](https://www.openstreetmap.org/copyright), [SRTM](http://viewfinderpanoramas.org/) | map style: [© OpenTopoMap](https://opentopomap.org/) ([CC-BY-SA](https://creativecommons.org/licenses/by-sa/3.0/))

# %%
show_map("OpenTopoMap", 
         maptiles_zxy(
             url="https://tile.opentopomap.org/{z}/{x}/{y}.png",
             attribution='Map data: <a href="https://www.openstreetmap.org/copyright">© OpenStreetMap contributors</a>, <a href="http://viewfinderpanoramas.org/">SRTM</a> | map style: <a href="https://opentopomap.org/">© OpenTopoMap</a> (<a href="https://creativecommons.org/licenses/by-sa/3.0/">CC-BY-SA</a>)'
         )
    )
# Out:
#    <div id="d6Ry14"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":500,
# "height":450
# },
# "ggtitle":{
# "text":"OpenTopoMap"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[13.3,37.6]
# },
# "zoom":3,
# "tiles":{
# "kind":"raster_zxy",
# "url":"https://tile.opentopomap.org/{z}/{x}/{y}.png",
# "attribution":"Map data: <a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a>, <a href=\"http://viewfinderpanoramas.org/\">SRTM</a> | map style: <a href=\"https://opentopomap.org/\">© OpenTopoMap</a> (<a href=\"https://creativecommons.org/licenses/by-sa/3.0/\">CC-BY-SA</a>)"
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com"
# },
# "data":{
# }
# }]
# };
#            var plotContainer = document.getElementById("d6Ry14");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ### Stamen Design ( http://maps.stamen.com)
#
# ##### Toner and Terrain:
#
# Map tiles by <a href="http://stamen.com">Stamen Design</a>, under <a href="http://creativecommons.org/licenses/by/3.0">CC BY 3.0</a>. Data by <a href="http://openstreetmap.org">OpenStreetMap</a>, under <a href="http://www.openstreetmap.org/copyright">ODbL</a>.
#
# ##### Watercolor:
#
# Map tiles by <a href="http://stamen.com">Stamen Design</a>, under <a href="http://creativecommons.org/licenses/by/3.0">CC BY 3.0</a>. Data by <a href="http://openstreetmap.org">OpenStreetMap</a>, under <a href="http://creativecommons.org/licenses/by-sa/3.0">CC BY SA</a>.

# %%
stamen_toner_and_terrian = 'Map tiles by <a href="http://stamen.com">Stamen Design</a>, under <a href="http://creativecommons.org/licenses/by/3.0">CC BY 3.0</a>. Data by <a href="http://openstreetmap.org">OpenStreetMap</a>, under <a href="http://www.openstreetmap.org/copyright">ODbL</a>.'
stamen_watercolor = 'Map tiles by <a href="http://stamen.com">Stamen Design</a>, under <a href="http://creativecommons.org/licenses/by/3.0">CC BY 3.0</a>. Data by <a href="http://openstreetmap.org">OpenStreetMap</a>, under <a href="http://creativecommons.org/licenses/by-sa/3.0">CC BY SA</a>.'

stamen_basemaps = [
    ( 
        "Stamen Design - Toner", 
         dict(
            url = "https://stamen-tiles.a.ssl.fastly.net/toner/{z}/{x}/{y}.png",
            attribution = stamen_toner_and_terrian
        )     
    ),
    (
        "Stamen Design - Terrain", 
        dict(
            url = "https://stamen-tiles.a.ssl.fastly.net/terrain/{z}/{x}/{y}@2x.png",
            attribution = stamen_toner_and_terrian
        )     
    ),
    (
        "Stamen Design - Watercolor", 
        dict(
            url = "https://stamen-tiles.a.ssl.fastly.net/watercolor/{z}/{x}/{y}.png",
            attribution = stamen_watercolor
        )     
    ),
    (
        "Stamen Design - Toner Labels", 
        dict(
            url = "https://stamen-tiles.a.ssl.fastly.net/toner-labels/{z}/{x}/{y}@2x.png",
            attribution = stamen_toner_and_terrian
        )     
    ),
    (
        "Stamen Design - Toner Hybrid", 
        dict(
            url = "https://stamen-tiles.a.ssl.fastly.net/toner-hybrid/{z}/{x}/{y}@2x.png",
            attribution = stamen_toner_and_terrian
        )     
    ),
]

for spec in stamen_basemaps:
    show_map(
        spec[0],
        maptiles_zxy(**spec[1])
    )
# Out:
#    <div id="ZC5Df9"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":500,
# "height":450
# },
# "ggtitle":{
# "text":"Stamen Design - Toner"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[13.3,37.6]
# },
# "zoom":3,
# "tiles":{
# "kind":"raster_zxy",
# "url":"https://stamen-tiles.a.ssl.fastly.net/toner/{z}/{x}/{y}.png",
# "attribution":"Map tiles by <a href=\"http://stamen.com\">Stamen Design</a>, under <a href=\"http://creativecommons.org/licenses/by/3.0\">CC BY 3.0</a>. Data by <a href=\"http://openstreetmap.org\">OpenStreetMap</a>, under <a href=\"http://www.openstreetmap.org/copyright\">ODbL</a>."
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com"
# },
# "data":{
# }
# }]
# };
#            var plotContainer = document.getElementById("ZC5Df9");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
#    <div id="ywgvQN"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":500,
# "height":450
# },
# "ggtitle":{
# "text":"Stamen Design - Terrain"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[13.3,37.6]
# },
# "zoom":3,
# "tiles":{
# "kind":"raster_zxy",
# "url":"https://stamen-tiles.a.ssl.fastly.net/terrain/{z}/{x}/{y}@2x.png",
# "attribution":"Map tiles by <a href=\"http://stamen.com\">Stamen Design</a>, under <a href=\"http://creativecommons.org/licenses/by/3.0\">CC BY 3.0</a>. Data by <a href=\"http://openstreetmap.org\">OpenStreetMap</a>, under <a href=\"http://www.openstreetmap.org/copyright\">ODbL</a>."
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com"
# },
# "data":{
# }
# }]
# };
#            var plotContainer = document.getElementById("ywgvQN");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
#    <div id="YWeynA"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":500,
# "height":450
# },
# "ggtitle":{
# "text":"Stamen Design - Watercolor"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[13.3,37.6]
# },
# "zoom":3,
# "tiles":{
# "kind":"raster_zxy",
# "url":"https://stamen-tiles.a.ssl.fastly.net/watercolor/{z}/{x}/{y}.png",
# "attribution":"Map tiles by <a href=\"http://stamen.com\">Stamen Design</a>, under <a href=\"http://creativecommons.org/licenses/by/3.0\">CC BY 3.0</a>. Data by <a href=\"http://openstreetmap.org\">OpenStreetMap</a>, under <a href=\"http://creativecommons.org/licenses/by-sa/3.0\">CC BY SA</a>."
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com"
# },
# "data":{
# }
# }]
# };
#            var plotContainer = document.getElementById("YWeynA");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
#    <div id="jbDzm4"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":500,
# "height":450
# },
# "ggtitle":{
# "text":"Stamen Design - Toner Labels"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[13.3,37.6]
# },
# "zoom":3,
# "tiles":{
# "kind":"raster_zxy",
# "url":"https://stamen-tiles.a.ssl.fastly.net/toner-labels/{z}/{x}/{y}@2x.png",
# "attribution":"Map tiles by <a href=\"http://stamen.com\">Stamen Design</a>, under <a href=\"http://creativecommons.org/licenses/by/3.0\">CC BY 3.0</a>. Data by <a href=\"http://openstreetmap.org\">OpenStreetMap</a>, under <a href=\"http://www.openstreetmap.org/copyright\">ODbL</a>."
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com"
# },
# "data":{
# }
# }]
# };
#            var plotContainer = document.getElementById("jbDzm4");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
#    <div id="cmfBQP"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":500,
# "height":450
# },
# "ggtitle":{
# "text":"Stamen Design - Toner Hybrid"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[13.3,37.6]
# },
# "zoom":3,
# "tiles":{
# "kind":"raster_zxy",
# "url":"https://stamen-tiles.a.ssl.fastly.net/toner-hybrid/{z}/{x}/{y}@2x.png",
# "attribution":"Map tiles by <a href=\"http://stamen.com\">Stamen Design</a>, under <a href=\"http://creativecommons.org/licenses/by/3.0\">CC BY 3.0</a>. Data by <a href=\"http://openstreetmap.org\">OpenStreetMap</a>, under <a href=\"http://www.openstreetmap.org/copyright\">ODbL</a>."
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com"
# },
# "data":{
# }
# }]
# };
#            var plotContainer = document.getElementById("cmfBQP");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# # CARTO
#
# [© OpenStreetMap contributors](https://www.openstreetmap.org/copyright) [© CARTO](https://carto.com/attributions#basemaps), [© CARTO](https://carto.com/attributions)
#
# Free for none-commercial services only (see [Limitations](https://github.com/CartoDB/basemap-styles#1-web-raster-basemaps), [License](https://github.com/CartoDB/basemap-styles/blob/master/LICENSE.md)).

# %%
carto = '<a href="https://www.openstreetmap.org/copyright">© OpenStreetMap contributors</a> <a href="https://carto.com/attributions#basemaps">© CARTO</a>, <a href="https://carto.com/attributions">© CARTO</a>'

carto_basemaps = [
    ( 
        "CARTO Positron", 
         dict(
            url = "https://a.basemaps.cartocdn.com/rastertiles/light_all/{z}/{x}/{y}@2x.png",
            attribution = carto
        )     
    ),
    ( 
        "CARTO Positron (no labels)", 
         dict(
            url = "https://b.basemaps.cartocdn.com/rastertiles/light_nolabels/{z}/{x}/{y}@2x.png",
            attribution = carto
        )     
    ),
    ( 
        "CARTO Dark Matter (no labels)", 
         dict(
            url = "https://c.basemaps.cartocdn.com/rastertiles/dark_nolabels/{z}/{x}/{y}@2x.png",
            attribution = carto
        )     
    ),
    ( 
        "CARTO Voyager", 
         dict(
            url = "https://d.basemaps.cartocdn.com/rastertiles/voyager/{z}/{x}/{y}@2x.png",
            attribution = carto
        )     
    ),
    ( 
        "CARTO Flat Blue", 
         dict(
            url = "https://cartocdn_a.global.ssl.fastly.net/base-flatblue/{z}/{x}/{y}.png",
            attribution = carto,
        )     
    ),
    ( 
        "CARTO Midnight commander", 
         dict(
            url = "https://cartocdn_b.global.ssl.fastly.net/base-midnight/{z}/{x}/{y}.png",
            attribution = carto
        )     
    ),
    ( 
        "CARTO Antique", 
         dict(
            url = "https://cartocdn_c.global.ssl.fastly.net/base-antique/{z}/{x}/{y}@2x.png",
            attribution = carto
        )     
    ),
]

for spec in carto_basemaps:
    show_map(
        spec[0],
        maptiles_zxy(**spec[1])
    )
# Out:
#    <div id="X0rbD4"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":500,
# "height":450
# },
# "ggtitle":{
# "text":"CARTO Positron"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[13.3,37.6]
# },
# "zoom":3,
# "tiles":{
# "kind":"raster_zxy",
# "url":"https://a.basemaps.cartocdn.com/rastertiles/light_all/{z}/{x}/{y}@2x.png",
# "attribution":"<a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a> <a href=\"https://carto.com/attributions#basemaps\">© CARTO</a>, <a href=\"https://carto.com/attributions\">© CARTO</a>"
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com"
# },
# "data":{
# }
# }]
# };
#            var plotContainer = document.getElementById("X0rbD4");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
#    <div id="fuG8r6"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":500,
# "height":450
# },
# "ggtitle":{
# "text":"CARTO Positron (no labels)"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[13.3,37.6]
# },
# "zoom":3,
# "tiles":{
# "kind":"raster_zxy",
# "url":"https://b.basemaps.cartocdn.com/rastertiles/light_nolabels/{z}/{x}/{y}@2x.png",
# "attribution":"<a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a> <a href=\"https://carto.com/attributions#basemaps\">© CARTO</a>, <a href=\"https://carto.com/attributions\">© CARTO</a>"
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com"
# },
# "data":{
# }
# }]
# };
#            var plotContainer = document.getElementById("fuG8r6");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
#    <div id="PLwTpP"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":500,
# "height":450
# },
# "ggtitle":{
# "text":"CARTO Dark Matter (no labels)"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[13.3,37.6]
# },
# "zoom":3,
# "tiles":{
# "kind":"raster_zxy",
# "url":"https://c.basemaps.cartocdn.com/rastertiles/dark_nolabels/{z}/{x}/{y}@2x.png",
# "attribution":"<a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a> <a href=\"https://carto.com/attributions#basemaps\">© CARTO</a>, <a href=\"https://carto.com/attributions\">© CARTO</a>"
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com"
# },
# "data":{
# }
# }]
# };
#            var plotContainer = document.getElementById("PLwTpP");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
#    <div id="nfmlyS"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":500,
# "height":450
# },
# "ggtitle":{
# "text":"CARTO Voyager"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[13.3,37.6]
# },
# "zoom":3,
# "tiles":{
# "kind":"raster_zxy",
# "url":"https://d.basemaps.cartocdn.com/rastertiles/voyager/{z}/{x}/{y}@2x.png",
# "attribution":"<a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a> <a href=\"https://carto.com/attributions#basemaps\">© CARTO</a>, <a href=\"https://carto.com/attributions\">© CARTO</a>"
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com"
# },
# "data":{
# }
# }]
# };
#            var plotContainer = document.getElementById("nfmlyS");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
#    <div id="XdW22a"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":500,
# "height":450
# },
# "ggtitle":{
# "text":"CARTO Flat Blue"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[13.3,37.6]
# },
# "zoom":3,
# "tiles":{
# "kind":"raster_zxy",
# "url":"https://cartocdn_a.global.ssl.fastly.net/base-flatblue/{z}/{x}/{y}.png",
# "attribution":"<a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a> <a href=\"https://carto.com/attributions#basemaps\">© CARTO</a>, <a href=\"https://carto.com/attributions\">© CARTO</a>"
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com"
# },
# "data":{
# }
# }]
# };
#            var plotContainer = document.getElementById("XdW22a");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
#    <div id="2x5GAq"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":500,
# "height":450
# },
# "ggtitle":{
# "text":"CARTO Midnight commander"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[13.3,37.6]
# },
# "zoom":3,
# "tiles":{
# "kind":"raster_zxy",
# "url":"https://cartocdn_b.global.ssl.fastly.net/base-midnight/{z}/{x}/{y}.png",
# "attribution":"<a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a> <a href=\"https://carto.com/attributions#basemaps\">© CARTO</a>, <a href=\"https://carto.com/attributions\">© CARTO</a>"
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com"
# },
# "data":{
# }
# }]
# };
#            var plotContainer = document.getElementById("2x5GAq");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
#    <div id="9nevH8"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":500,
# "height":450
# },
# "ggtitle":{
# "text":"CARTO Antique"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[13.3,37.6]
# },
# "zoom":3,
# "tiles":{
# "kind":"raster_zxy",
# "url":"https://cartocdn_c.global.ssl.fastly.net/base-antique/{z}/{x}/{y}@2x.png",
# "attribution":"<a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a> <a href=\"https://carto.com/attributions#basemaps\">© CARTO</a>, <a href=\"https://carto.com/attributions\">© CARTO</a>"
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com"
# },
# "data":{
# }
# }]
# };
#            var plotContainer = document.getElementById("9nevH8");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ### NASA's Global Imagery Browse Services (GIBS)
#
# Imagery provided by services from NASA's Global Imagery Browse Services ([GIBS](https://earthdata.nasa.gov/eosdis/science-system-description/eosdis-components/gibs)), part of NASA's Earth Observing System Data and Information System ([EOSDIS](https://earthdata.nasa.gov)).
#
# [NASA's Global Imagery Browse Services (GIBS)](https://earthdata.nasa.gov/eosdis/science-system-description/eosdis-components/gibs).
#
# Global Imagery Browse Services (GIBS) - [API for Developers](https://wiki.earthdata.nasa.gov/display/GIBS/GIBS+API+for+Developers).
#
# Global Imagery Browse Services (GIBS) API - [Generic XYZ Tile Access](https://wiki.earthdata.nasa.gov/display/GIBS/GIBS+API+for+Developers#GIBSAPIforDevelopers-GenericXYZTileAccess).
#
# [GIBS Available Imagery Products](https://wiki.earthdata.nasa.gov/display/GIBS/GIBS+Available+Imagery+Products).

# %%
nasa = '<a href="https://earthdata.nasa.gov/eosdis/science-system-description/eosdis-components/gibs">© NASA Global Imagery Browse Services (GIBS)</a>'

nasa_basemaps = [
    ( 
        "NASA GIBS: CityLights 2012", 
         dict(
            url = "https://gibs.earthdata.nasa.gov/wmts/epsg3857/best/VIIRS_CityLights_2012/default//GoogleMapsCompatible_Level8/{z}/{y}/{x}.jpg",
            attribution = nasa
        )     
    ),
    ( 
        "NASA GIBS: BlueMarble_NextGeneration", 
         dict(
            url = "https://gibs.earthdata.nasa.gov/wmts/epsg3857/best/BlueMarble_NextGeneration/default/GoogleMapsCompatible_Level8/{z}/{y}/{x}.jpeg",
            attribution = nasa
        )     
    ),
    ( 
        "NASA GIBS: Greyscale Shaded Relief (30m)", 
         dict(
            url = "https://gibs.earthdata.nasa.gov/wmts/epsg3857/best/ASTER_GDEM_Greyscale_Shaded_Relief/default/GoogleMapsCompatible_Level12/{z}/{y}/{x}.jpeg",
            attribution = nasa
        )     
    ),
    ( 
        "NASA GIBS: Color Shaded Relief (30m)", 
         dict(
            url = "https://gibs.earthdata.nasa.gov/wmts/epsg3857/best/ASTER_GDEM_Color_Shaded_Relief/default/GoogleMapsCompatible_Level12/{z}/{y}/{x}.jpeg",
            attribution = nasa
        )     
    ),
    ( 
        "NASA GIBS: Terra TrueColor", 
         dict(
            url = "https://gibs.earthdata.nasa.gov/wmts/epsg3857/best/MODIS_Terra_CorrectedReflectance_TrueColor/default/2015-06-07/GoogleMapsCompatible_Level9/{z}/{y}/{x}.jpg",
            attribution = nasa
        )     
    ),
]

for spec in nasa_basemaps:
    show_map(
        spec[0],
        maptiles_zxy(**spec[1])
    )
# Out:
#    <div id="DSQPAC"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":500,
# "height":450
# },
# "ggtitle":{
# "text":"NASA GIBS: CityLights 2012"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[13.3,37.6]
# },
# "zoom":3,
# "tiles":{
# "kind":"raster_zxy",
# "url":"https://gibs.earthdata.nasa.gov/wmts/epsg3857/best/VIIRS_CityLights_2012/default//GoogleMapsCompatible_Level8/{z}/{y}/{x}.jpg",
# "attribution":"<a href=\"https://earthdata.nasa.gov/eosdis/science-system-description/eosdis-components/gibs\">© NASA Global Imagery Browse Services (GIBS)</a>"
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com"
# },
# "data":{
# }
# }]
# };
#            var plotContainer = document.getElementById("DSQPAC");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
#    <div id="qjaOav"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":500,
# "height":450
# },
# "ggtitle":{
# "text":"NASA GIBS: BlueMarble_NextGeneration"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[13.3,37.6]
# },
# "zoom":3,
# "tiles":{
# "kind":"raster_zxy",
# "url":"https://gibs.earthdata.nasa.gov/wmts/epsg3857/best/BlueMarble_NextGeneration/default/GoogleMapsCompatible_Level8/{z}/{y}/{x}.jpeg",
# "attribution":"<a href=\"https://earthdata.nasa.gov/eosdis/science-system-description/eosdis-components/gibs\">© NASA Global Imagery Browse Services (GIBS)</a>"
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com"
# },
# "data":{
# }
# }]
# };
#            var plotContainer = document.getElementById("qjaOav");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
#    <div id="ujcTeh"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":500,
# "height":450
# },
# "ggtitle":{
# "text":"NASA GIBS: Greyscale Shaded Relief (30m)"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[13.3,37.6]
# },
# "zoom":3,
# "tiles":{
# "kind":"raster_zxy",
# "url":"https://gibs.earthdata.nasa.gov/wmts/epsg3857/best/ASTER_GDEM_Greyscale_Shaded_Relief/default/GoogleMapsCompatible_Level12/{z}/{y}/{x}.jpeg",
# "attribution":"<a href=\"https://earthdata.nasa.gov/eosdis/science-system-description/eosdis-components/gibs\">© NASA Global Imagery Browse Services (GIBS)</a>"
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com"
# },
# "data":{
# }
# }]
# };
#            var plotContainer = document.getElementById("ujcTeh");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
#    <div id="0da5fj"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":500,
# "height":450
# },
# "ggtitle":{
# "text":"NASA GIBS: Color Shaded Relief (30m)"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[13.3,37.6]
# },
# "zoom":3,
# "tiles":{
# "kind":"raster_zxy",
# "url":"https://gibs.earthdata.nasa.gov/wmts/epsg3857/best/ASTER_GDEM_Color_Shaded_Relief/default/GoogleMapsCompatible_Level12/{z}/{y}/{x}.jpeg",
# "attribution":"<a href=\"https://earthdata.nasa.gov/eosdis/science-system-description/eosdis-components/gibs\">© NASA Global Imagery Browse Services (GIBS)</a>"
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com"
# },
# "data":{
# }
# }]
# };
#            var plotContainer = document.getElementById("0da5fj");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
#    <div id="yO3wNP"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":500,
# "height":450
# },
# "ggtitle":{
# "text":"NASA GIBS: Terra TrueColor"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[13.3,37.6]
# },
# "zoom":3,
# "tiles":{
# "kind":"raster_zxy",
# "url":"https://gibs.earthdata.nasa.gov/wmts/epsg3857/best/MODIS_Terra_CorrectedReflectance_TrueColor/default/2015-06-07/GoogleMapsCompatible_Level9/{z}/{y}/{x}.jpg",
# "attribution":"<a href=\"https://earthdata.nasa.gov/eosdis/science-system-description/eosdis-components/gibs\">© NASA Global Imagery Browse Services (GIBS)</a>"
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com"
# },
# "data":{
# }
# }]
# };
#            var plotContainer = document.getElementById("yO3wNP");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
