# %% [markdown]
# <em><sub>This page is available as an executable or viewable <strong>Jupyter Notebook</strong>:</sub></em>
# <br/><br/>
# <a href="https://mybinder.org/v2/gh/JetBrains/lets-plot/v2.0.3demos1?filepath=docs%2Fexamples%2Fjupyter-notebooks%2Ffacets.ipynb"
#    target="_parent">
#    <img align="left"
#         src="https://mybinder.org/badge_logo.svg">
# </a>
# <a href="https://nbviewer.jupyter.org/github/JetBrains/lets-plot/blob/master/docs/examples/jupyter-notebooks/facets.ipynb"
#    target="_parent">
#    <img align="right"
#         src="https://raw.githubusercontent.com/jupyter/design/master/logos/Badges/nbviewer_badge.png"
#         width="109" height="20">
# </a>
# <br/>
# <br/>

# %% [markdown]
# ### Creating multi-panel plots using `facets`.
#
# #### Problem
#
# You want to see more aspects of your data and it's not practcal to use the regular `aesthetics` approach for that.
#
# #### Solution - `facets`
#
# You can add one or more new dimentions to your plot using `faceting`.
#
# This approach allows you to split up your data by one or more variables and plot the subsets of data together.
#
#
# In this demo we will explore how various faceting functions work, as well as the built-in `sorting` and `formatting` options.

# %%
import numpy as np
import pandas as pd

from lets_plot import *
LetsPlot.setup_html()
# Out:
#             <div id="aQLPT1"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v2.0.3/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
# ...

# %%
data = pd.read_csv('https://github.com/JetBrains/lets-plot/raw/master/docs/examples/data/mpg2.csv')
data.head(3)
# Out:
#    miles per gallon  number of cylinders  engine displacement (cu. inches)  \
# 0              18.0                    8                             307.0
# 1              15.0                    8                             350.0
# 2              18.0                    8                             318.0
#
#    engine horsepower  vehicle weight (lbs.)  time to accelerate (sec.)  \
# 0                130                   3504                       12.0
# 1                165                   3693                       11.5
# 2                150                   3436                       11.0
#
#    model year origin of car               vehicle name
# 0          70            US  chevrolet chevelle malibu
# 1          70            US          buick skylark 320
# 2          70            US         plymouth satellite

# %% [markdown]
# ### One plot
#
# Create a scatter plot to show how `mpg` is related to a car's `engine horsepower`.
#
# Also use the `color` aesthetic to vizualise the region where a car was designed.

# %%
p = (ggplot(data, aes(x="engine horsepower", y="miles per gallon")) + 
     geom_point(aes(color="origin of car")))
p + ggsize(800, 350)
# Out:
#    <div id="e4ufsn"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# ...

# %% [markdown]
# ### More dimentions
#
# There are two functions for faceting:
#
#  - facet_grid()
#  - facet_wrap()
#
# The former creates 2-D matrix of plot panels and latter creates 1-D strip of plot panels.
#
# We'll be using the `number of cylinders` variable as 1st fatceting variable, and sometimes the `origin of car` as a 2nd fatceting variable.

# %% [markdown]
# ### facet_grid()
#
# The data can be split up by one or two variables that vary on the X and/or Y direction.

# %% [markdown]
# #### One facet
#
# Let's split up the data by `number of cylinders`.

# %%
p + facet_grid(x="number of cylinders")
# Out:
#    <div id="FvgToD"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# ...

# %% [markdown]
# #### Two facets
#
# Split up the data by two faceting variables: `number of cylinders` and `origin of car`.

# %%
p + facet_grid(x="number of cylinders", y="origin of car")
# Out:
#    <div id="gAQI28"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# ...

# %% [markdown]
# #### Formatting and sorting.
#
# Apply a formatting template to the `number of cylinders` and
# sort the `origin of car` values in discending order.
#
# To learn more about formatting templates see: [Formatting](https://jetbrains.github.io/lets-plot-docs/pages/features/formats.html).

# %%
p + facet_grid(x="number of cylinders", y="origin of car", x_format="{d} cyl", y_order=-1)
# Out:
#    <div id="jfZHGg"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# ...

# %% [markdown]
# ### facet_wrap()
#
# The data can be split up by one or more variables.
# The panels layout is flexible and controlled by `ncol`, `nrow` and `dir` options.

# %% [markdown]
# #### One facet
#
# Split data by the `number of cylinders` variable and arrange tiles in two rows.

# %%
p + facet_wrap(facets="number of cylinders", nrow=2)
# Out:
#    <div id="qAtMPa"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# ...

# %% [markdown]
# #### Two facets
#
# Split data by `origin of car` and `number of cylinders` and arrange tiles in 5 columns.

# %%
p + facet_wrap(facets=["origin of car", "number of cylinders"], ncol=5)
# Out:
#    <div id="OF9ZIG"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# ...

# %% [markdown]
# #### Arrange panels vertically.
#
# Use the `dir` parameter to arrange tiles by columns, in 3 columns (the default tile arrangment is "by row").
#
# Also, format `number of cylinders` labels and reverse the sorting direction for this facetting variable.

# %%
p + facet_wrap(facets=["origin of car", "number of cylinders"], 
               ncol=3,
               format=[None, "{} cyl"],
               order=[1, -1],
               dir="v")
# Out:
#    <div id="bNslCC"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# ...
