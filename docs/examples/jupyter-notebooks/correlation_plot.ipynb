# %% [markdown]
# <em><sub>This page is available as an executable or viewable <strong>Jupyter Notebook</strong>:</sub></em>
# <br/><br/>
# <a href="https://mybinder.org/v2/gh/JetBrains/lets-plot/v2.0.0demos1?filepath=docs%2Fexamples%2Fjupyter-notebooks%2Fcorrelation_plot.ipynb"
#    target="_parent">
#    <img align="left"
#         src="https://mybinder.org/badge_logo.svg">
# </a>
# <a href="https://nbviewer.jupyter.org/github/JetBrains/lets-plot/blob/master/docs/examples/jupyter-notebooks/correlation_plot.ipynb"
#    target="_parent">
#    <img align="right"
#         src="https://raw.githubusercontent.com/jupyter/design/master/logos/Badges/nbviewer_badge.png"
#         width="109" height="20">
# </a>
# <br/>
# <br/>

# %% [markdown]
# ## Correlation Plot
#
# The `corr_plot` builder takes a dataframe (can be Pandas `Dataframe` or just Python `dict`) as the input and
# builds a correlation plot.
#
# It allows to combine 'tile', 'point' or 'label' layers in a matrix of 'full', 'lower' or 'upper' type.
#
# A call to the terminal `build()` method will create a resulting 'plot' object.
# This 'plot' object can be further refined using regular Lets-Plot (ggplot) API, like `+ ggtitle()`, `+ ggsize()` and so on.
#
#
# The Ames Housing dataset for this demo was downloaded from [House Prices - Advanced Regression Techniques](https://www.kaggle.com/c/house-prices-advanced-regression-techniques/data?select=train.csv) (train.csv), (c) Kaggle.

# %%
import pandas as pd
from lets_plot import *
from lets_plot.bistro.corr import *

LetsPlot.setup_html()
# Out:
# The geodata is provided by © OpenStreetMap contributors and is made available here under the Open Database License (ODbL).
#             <div id="gw1FLK"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://dl.bintray.com/jetbrains/lets-plot/lets-plot-2.0.0rc2.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("gw1FLK").appendChild(div);
#                     };
#                     var e = document.getElementById("gw1FLK");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
mpg_df = pd.read_csv('https://jetbrains.bintray.com/lets-plot/mpg.csv').drop(columns=['Unnamed: 0'])

# %%
def group(plots):
    """
    Useful for this demo.
    """
    bunch = GGBunch()
    for idx, p in enumerate(plots):
        x = (idx % 2) * 450
        y = int(idx / 2) * 350
        bunch.add_plot(p, x, y)
        
    return bunch

# %% [markdown]
# ### Combining 'tile', 'point' and 'label' layers.
#
# When combining layers, `corr_plot` chooses an acceptable plot configuration by default.

# %%
group([
    corr_plot(mpg_df).tiles().build() + ggtitle("Tiles"),
    corr_plot(mpg_df).points().build() + ggtitle("Points"), 
    corr_plot(mpg_df).tiles().labels().build() + ggtitle("Tiles and labels"),
    corr_plot(mpg_df).points().labels().tiles().build() + ggtitle("Tiles, points and labels")
])
# Out:
#    <div id="Nh3pDJ"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# 'kind':"ggbunch",
# 'items':[{
# 'x':0,
# 'y':0,
# 'width':null,
# 'height':null,
# 'feature_spec':{
# 'data':{
# },
# 'mapping':{
# },
# 'data_meta':{
# },
# 'coord':{
# 'name':"cartesian"
# },
# 'theme':{
# 'axis_title':{
# 'name':"blank"
# },
# 'axis_line_x':{
# 'name':"blank"
# },
# 'axis_line_y':{
# 'name':"blank"
# },
# 'legend_title':{
# 'name':"blank"
# }
# },
# 'ggsize':{
# 'width':400,
# 'height':300.0
# },
# 'ggtitle':{
# 'text':"Tiles"
# },
# 'kind':"plot",
# 'scales':[{
# 'name':"",
# 'aesthetic':"size",
# 'na_value':0,
# 'guide':"none",
# 'scale_mapper_kind':"identity"
# },{
# 'name':"Corr",
# 'aesthetic':"color",
# 'breaks':[-1.0,-0.5,0.0,0.5,1.0],
# 'limits':[-1.0,1.0],
# 'na_value':"rgba(0,0,0,0)",
# 'low':"#B3412C",
# 'mid':"#EDEDED",
# 'high':"#326C81",
# 'midpoint':0,
# 'scale_mapper_kind':"color_gradient2"
# },{
# 'name':"Corr",
# 'aesthetic':"fill",
# 'breaks':[-1.0,-0.5,0.0,0.5,1.0],
# 'limits':[-1.0,1.0],
# 'na_value':"rgba(0,0,0,0)",
# 'low':"#B3412C",
# 'mid':"#EDEDED",
# 'high':"#326C81",
# 'midpoint':0,
# 'scale_mapper_kind':"color_gradient2"
# },{
# 'aesthetic':"x",
# 'expand':[0,0.1],
# 'discrete':true,
# 'reverse':false
# },{
# 'aesthetic':"y",
# 'expand':[0,0.1],
# 'discrete':true,
# 'reverse':true
# }],
# 'layers':[{
# 'geom':"tile",
# 'stat':"corr",
# 'mapping':{
# },
# 'show_legend':true,
# 'sampling':"none",
# 'tooltips':{
# 'tooltip_formats':[{
# 'field':"@..corr..",
# 'format':".2f"
# }],
# 'tooltip_lines':["@..corr.."]
# },
# 'data_meta':{
# },
# 'size':0.0,
# 'width':1.002,
# 'height':1.002,
# 'data':{
# '..x..':["displ","displ","displ","displ","displ","year","year","year","year","year","cyl","cyl","cyl","cyl","cyl","cty","cty","cty","cty","cty","hwy","hwy","hwy","hwy","hwy"],
# '..y..':["displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy"],
# '..corr..':[1.0,0.14784281645020295,0.9302271024198506,-0.7985239689348548,-0.7660200208864677,0.14784281645020295,1.0,0.1222453474355237,-0.0372322908599655,0.0021576430766320123,0.9302271024198506,0.1222453474355237,1.0,-0.8057714082675279,-0.7619123538971942,-0.7985239689348548,-0.0372322908599655,-0.8057714082675279,1.0,0.9559159136495734,-0.7660200208864677,0.0021576430766320123,-0.7619123538971942,0.9559159136495734,1.0]
# }
# }]
# }
# },{
# 'x':450,
# 'y':0,
# 'width':null,
# 'height':null,
# 'feature_spec':{
# 'data':{
# },
# 'mapping':{
# },
# 'data_meta':{
# },
# 'coord':{
# 'name':"fixed",
# 'ratio':1.0
# },
# 'theme':{
# 'axis_title':{
# 'name':"blank"
# },
# 'axis_line_x':{
# 'name':"blank"
# },
# 'axis_line_y':{
# 'name':"blank"
# },
# 'legend_title':{
# 'name':"blank"
# }
# },
# 'ggsize':{
# 'width':400,
# 'height':300.0
# },
# 'ggtitle':{
# 'text':"Points"
# },
# 'kind':"plot",
# 'scales':[{
# 'name':"",
# 'aesthetic':"size",
# 'na_value':0,
# 'guide':"none",
# 'scale_mapper_kind':"identity"
# },{
# 'name':"Corr",
# 'aesthetic':"color",
# 'breaks':[-1.0,-0.5,0.0,0.5,1.0],
# 'limits':[-1.0,1.0],
# 'na_value':"rgba(0,0,0,0)",
# 'low':"#B3412C",
# 'mid':"#EDEDED",
# 'high':"#326C81",
# 'midpoint':0,
# 'scale_mapper_kind':"color_gradient2"
# },{
# 'name':"Corr",
# 'aesthetic':"fill",
# 'breaks':[-1.0,-0.5,0.0,0.5,1.0],
# 'limits':[-1.0,1.0],
# 'na_value':"rgba(0,0,0,0)",
# 'low':"#B3412C",
# 'mid':"#EDEDED",
# 'high':"#326C81",
# 'midpoint':0,
# 'scale_mapper_kind':"color_gradient2"
# },{
# 'aesthetic':"x",
# 'discrete':true,
# 'reverse':false
# },{
# 'aesthetic':"y",
# 'discrete':true,
# 'reverse':true
# }],
# 'layers':[{
# 'geom':"point",
# 'stat':"corr",
# 'mapping':{
# 'size':"..corr_abs.."
# },
# 'show_legend':true,
# 'sampling':"none",
# 'tooltips':{
# 'tooltip_formats':[{
# 'field':"@..corr..",
# 'format':".2f"
# }],
# 'tooltip_lines':["@..corr.."]
# },
# 'data_meta':{
# },
# 'size_unit':"x",
# 'data':{
# '..x..':["displ","displ","displ","displ","displ","year","year","year","year","year","cyl","cyl","cyl","cyl","cyl","cty","cty","cty","cty","cty","hwy","hwy","hwy","hwy","hwy"],
# '..y..':["displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy"],
# '..corr..':[1.0,0.14784281645020295,0.9302271024198506,-0.7985239689348548,-0.7660200208864677,0.14784281645020295,1.0,0.1222453474355237,-0.0372322908599655,0.0021576430766320123,0.9302271024198506,0.1222453474355237,1.0,-0.8057714082675279,-0.7619123538971942,-0.7985239689348548,-0.0372322908599655,-0.8057714082675279,1.0,0.9559159136495734,-0.7660200208864677,0.0021576430766320123,-0.7619123538971942,0.9559159136495734,1.0],
# '..corr_abs..':[1.0,0.14784281645020295,0.9302271024198506,0.7985239689348548,0.7660200208864677,0.14784281645020295,1.0,0.1222453474355237,0.0372322908599655,0.0021576430766320123,0.9302271024198506,0.1222453474355237,1.0,0.8057714082675279,0.7619123538971942,0.7985239689348548,0.0372322908599655,0.8057714082675279,1.0,0.9559159136495734,0.7660200208864677,0.0021576430766320123,0.7619123538971942,0.9559159136495734,1.0]
# }
# }]
# }
# },{
# 'x':0,
# 'y':350,
# 'width':null,
# 'height':null,
# 'feature_spec':{
# 'data':{
# },
# 'mapping':{
# },
# 'data_meta':{
# },
# 'coord':{
# 'name':"cartesian"
# },
# 'theme':{
# 'axis_title':{
# 'name':"blank"
# },
# 'axis_line_x':{
# 'name':"blank"
# },
# 'axis_line_y':{
# 'name':"blank"
# },
# 'legend_title':{
# 'name':"blank"
# }
# },
# 'ggsize':{
# 'width':400,
# 'height':300.0
# },
# 'ggtitle':{
# 'text':"Tiles and labels"
# },
# 'kind':"plot",
# 'scales':[{
# 'name':"",
# 'aesthetic':"size",
# 'na_value':0,
# 'guide':"none",
# 'scale_mapper_kind':"identity"
# },{
# 'name':"Corr",
# 'aesthetic':"color",
# 'breaks':[-1.0,-0.5,0.0,0.5,1.0],
# 'limits':[-1.0,1.0],
# 'na_value':"rgba(0,0,0,0)",
# 'low':"#B3412C",
# 'mid':"#EDEDED",
# 'high':"#326C81",
# 'midpoint':0,
# 'scale_mapper_kind':"color_gradient2"
# },{
# 'name':"Corr",
# 'aesthetic':"fill",
# 'breaks':[-1.0,-0.5,0.0,0.5,1.0],
# 'limits':[-1.0,1.0],
# 'na_value':"rgba(0,0,0,0)",
# 'low':"#B3412C",
# 'mid':"#EDEDED",
# 'high':"#326C81",
# 'midpoint':0,
# 'scale_mapper_kind':"color_gradient2"
# },{
# 'aesthetic':"x",
# 'expand':[0,0.1],
# 'discrete':true,
# 'reverse':false
# },{
# 'aesthetic':"y",
# 'expand':[0,0.1],
# 'discrete':true,
# 'reverse':true
# }],
# 'layers':[{
# 'geom':"tile",
# 'stat':"corr",
# 'mapping':{
# },
# 'show_legend':true,
# 'sampling':"none",
# 'tooltips':{
# 'tooltip_formats':[{
# 'field':"@..corr..",
# 'format':".2f"
# }],
# 'tooltip_lines':["@..corr.."]
# },
# 'data_meta':{
# },
# 'size':0.0,
# 'width':1.002,
# 'height':1.002,
# 'type':"upper",
# 'diag':false,
# 'data':{
# '..x..':["displ","displ","displ","displ","displ","year","year","year","year","year","cyl","cyl","cyl","cyl","cyl","cty","cty","cty","cty","cty","hwy","hwy","hwy","hwy","hwy"],
# '..y..':["displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy"],
# '..corr..':[null,0.14784281645020295,0.9302271024198506,-0.7985239689348548,-0.7660200208864677,null,null,0.1222453474355237,-0.0372322908599655,0.0021576430766320123,null,null,null,-0.8057714082675279,-0.7619123538971942,null,null,null,null,0.9559159136495734,null,null,null,null,null]
# }
# },{
# 'geom':"text",
# 'stat':"corr",
# 'mapping':{
# },
# 'show_legend':true,
# 'sampling':"none",
# 'tooltips':{
# 'tooltip_formats':[{
# 'field':"@..corr..",
# 'format':".2f"
# }],
# 'tooltip_lines':["@..corr.."]
# },
# 'data_meta':{
# },
# 'label_format':".2f",
# 'na_text':"",
# 'size_unit':"x",
# 'type':"lower",
# 'diag':false,
# 'size':1,
# 'data':{
# '..x..':["displ","displ","displ","displ","displ","year","year","year","year","year","cyl","cyl","cyl","cyl","cyl","cty","cty","cty","cty","cty","hwy","hwy","hwy","hwy","hwy"],
# '..y..':["displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy"],
# '..corr..':[null,null,null,null,null,0.14784281645020295,null,null,null,null,0.9302271024198506,0.1222453474355237,null,null,null,-0.7985239689348548,-0.0372322908599655,-0.8057714082675279,null,null,-0.7660200208864677,0.0021576430766320123,-0.7619123538971942,0.9559159136495734,null]
# }
# }]
# }
# },{
# 'x':450,
# 'y':350,
# 'width':null,
# 'height':null,
# 'feature_spec':{
# 'data':{
# },
# 'mapping':{
# },
# 'data_meta':{
# },
# 'coord':{
# 'name':"cartesian"
# },
# 'theme':{
# 'axis_t

# %% [markdown]
# The default plot configuration adapts to the changing options - compare 'Tiles and labels' plot above and below.
#
# You can also override the default plot configuration using the parameter 'type' - compare 'Tiles, points and labels' plot above and below.

# %%
group([
    corr_plot(mpg_df).tiles().labels(color="white").build() + ggtitle("Tiles and labels"),
    (corr_plot(mpg_df)
     .tiles(type="upper")
     .points(type="lower")
     .labels(type="full").build() + ggtitle("Tiles, points and labels"))
])
# Out:
#    <div id="oEOxtK"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# 'kind':"ggbunch",
# 'items':[{
# 'x':0,
# 'y':0,
# 'width':null,
# 'height':null,
# 'feature_spec':{
# 'data':{
# },
# 'mapping':{
# },
# 'data_meta':{
# },
# 'coord':{
# 'name':"cartesian"
# },
# 'theme':{
# 'axis_title':{
# 'name':"blank"
# },
# 'axis_line_x':{
# 'name':"blank"
# },
# 'axis_line_y':{
# 'name':"blank"
# },
# 'legend_title':{
# 'name':"blank"
# }
# },
# 'ggsize':{
# 'width':400,
# 'height':300.0
# },
# 'ggtitle':{
# 'text':"Tiles and labels"
# },
# 'kind':"plot",
# 'scales':[{
# 'name':"",
# 'aesthetic':"size",
# 'na_value':0,
# 'guide':"none",
# 'scale_mapper_kind':"identity"
# },{
# 'name':"Corr",
# 'aesthetic':"color",
# 'breaks':[-1.0,-0.5,0.0,0.5,1.0],
# 'limits':[-1.0,1.0],
# 'na_value':"rgba(0,0,0,0)",
# 'low':"#B3412C",
# 'mid':"#EDEDED",
# 'high':"#326C81",
# 'midpoint':0,
# 'scale_mapper_kind':"color_gradient2"
# },{
# 'name':"Corr",
# 'aesthetic':"fill",
# 'breaks':[-1.0,-0.5,0.0,0.5,1.0],
# 'limits':[-1.0,1.0],
# 'na_value':"rgba(0,0,0,0)",
# 'low':"#B3412C",
# 'mid':"#EDEDED",
# 'high':"#326C81",
# 'midpoint':0,
# 'scale_mapper_kind':"color_gradient2"
# },{
# 'aesthetic':"x",
# 'expand':[0,0.1],
# 'discrete':true,
# 'reverse':false
# },{
# 'aesthetic':"y",
# 'expand':[0,0.1],
# 'discrete':true,
# 'reverse':true
# }],
# 'layers':[{
# 'geom':"tile",
# 'stat':"corr",
# 'mapping':{
# },
# 'show_legend':true,
# 'sampling':"none",
# 'tooltips':{
# 'tooltip_formats':[{
# 'field':"@..corr..",
# 'format':".2f"
# }],
# 'tooltip_lines':["@..corr.."]
# },
# 'data_meta':{
# },
# 'size':0.0,
# 'width':1.002,
# 'height':1.002,
# 'data':{
# '..x..':["displ","displ","displ","displ","displ","year","year","year","year","year","cyl","cyl","cyl","cyl","cyl","cty","cty","cty","cty","cty","hwy","hwy","hwy","hwy","hwy"],
# '..y..':["displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy"],
# '..corr..':[1.0,0.14784281645020295,0.9302271024198506,-0.7985239689348548,-0.7660200208864677,0.14784281645020295,1.0,0.1222453474355237,-0.0372322908599655,0.0021576430766320123,0.9302271024198506,0.1222453474355237,1.0,-0.8057714082675279,-0.7619123538971942,-0.7985239689348548,-0.0372322908599655,-0.8057714082675279,1.0,0.9559159136495734,-0.7660200208864677,0.0021576430766320123,-0.7619123538971942,0.9559159136495734,1.0]
# }
# },{
# 'geom':"text",
# 'stat':"corr",
# 'mapping':{
# },
# 'show_legend':true,
# 'sampling':"none",
# 'tooltips':{
# 'tooltip_formats':[{
# 'field':"@..corr..",
# 'format':".2f"
# }],
# 'tooltip_lines':["@..corr.."]
# },
# 'data_meta':{
# },
# 'label_format':".2f",
# 'na_text':"",
# 'size_unit':"x",
# 'color':"white",
# 'size':1,
# 'data':{
# '..x..':["displ","displ","displ","displ","displ","year","year","year","year","year","cyl","cyl","cyl","cyl","cyl","cty","cty","cty","cty","cty","hwy","hwy","hwy","hwy","hwy"],
# '..y..':["displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy"],
# '..corr..':[1.0,0.14784281645020295,0.9302271024198506,-0.7985239689348548,-0.7660200208864677,0.14784281645020295,1.0,0.1222453474355237,-0.0372322908599655,0.0021576430766320123,0.9302271024198506,0.1222453474355237,1.0,-0.8057714082675279,-0.7619123538971942,-0.7985239689348548,-0.0372322908599655,-0.8057714082675279,1.0,0.9559159136495734,-0.7660200208864677,0.0021576430766320123,-0.7619123538971942,0.9559159136495734,1.0]
# }
# }]
# }
# },{
# 'x':450,
# 'y':0,
# 'width':null,
# 'height':null,
# 'feature_spec':{
# 'data':{
# },
# 'mapping':{
# },
# 'data_meta':{
# },
# 'coord':{
# 'name':"cartesian"
# },
# 'theme':{
# 'axis_title':{
# 'name':"blank"
# },
# 'axis_line_x':{
# 'name':"blank"
# },
# 'axis_line_y':{
# 'name':"blank"
# },
# 'legend_title':{
# 'name':"blank"
# }
# },
# 'ggsize':{
# 'width':400,
# 'height':300.0
# },
# 'ggtitle':{
# 'text':"Tiles, points and labels"
# },
# 'kind':"plot",
# 'scales':[{
# 'name':"",
# 'aesthetic':"size",
# 'na_value':0,
# 'guide':"none",
# 'scale_mapper_kind':"identity"
# },{
# 'name':"Corr",
# 'aesthetic':"color",
# 'breaks':[-1.0,-0.5,0.0,0.5,1.0],
# 'limits':[-1.0,1.0],
# 'na_value':"rgba(0,0,0,0)",
# 'low':"#B3412C",
# 'mid':"#EDEDED",
# 'high':"#326C81",
# 'midpoint':0,
# 'scale_mapper_kind':"color_gradient2"
# },{
# 'name':"Corr",
# 'aesthetic':"fill",
# 'breaks':[-1.0,-0.5,0.0,0.5,1.0],
# 'limits':[-1.0,1.0],
# 'na_value':"rgba(0,0,0,0)",
# 'low':"#B3412C",
# 'mid':"#EDEDED",
# 'high':"#326C81",
# 'midpoint':0,
# 'scale_mapper_kind':"color_gradient2"
# },{
# 'aesthetic':"x",
# 'expand':[0,0.1],
# 'discrete':true,
# 'reverse':false
# },{
# 'aesthetic':"y",
# 'expand':[0,0.1],
# 'discrete':true,
# 'reverse':true
# }],
# 'layers':[{
# 'geom':"tile",
# 'stat':"corr",
# 'mapping':{
# },
# 'show_legend':true,
# 'sampling':"none",
# 'tooltips':{
# 'tooltip_formats':[{
# 'field':"@..corr..",
# 'format':".2f"
# }],
# 'tooltip_lines':["@..corr.."]
# },
# 'data_meta':{
# },
# 'size':0.0,
# 'width':1.002,
# 'height':1.002,
# 'type':"lower",
# 'diag':false,
# 'data':{
# '..x..':["displ","displ","displ","displ","displ","year","year","year","year","year","cyl","cyl","cyl","cyl","cyl","cty","cty","cty","cty","cty","hwy","hwy","hwy","hwy","hwy"],
# '..y..':["displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy"],
# '..corr..':[null,null,null,null,null,0.14784281645020295,null,null,null,null,0.9302271024198506,0.1222453474355237,null,null,null,-0.7985239689348548,-0.0372322908599655,-0.8057714082675279,null,null,-0.7660200208864677,0.0021576430766320123,-0.7619123538971942,0.9559159136495734,null]
# }
# },{
# 'geom':"point",
# 'stat':"corr",
# 'mapping':{
# 'size':"..corr_abs.."
# },
# 'show_legend':true,
# 'sampling':"none",
# 'tooltips':{
# 'tooltip_formats':[{
# 'field':"@..corr..",
# 'format':".2f"
# }],
# 'tooltip_lines':["@..corr.."]
# },
# 'data_meta':{
# },
# 'size_unit':"x",
# 'type':"upper",
# 'diag':false,
# 'data':{
# '..x..':["displ","displ","displ","displ","displ","year","year","year","year","year","cyl","cyl","cyl","cyl","cyl","cty","cty","cty","cty","cty","hwy","hwy","hwy","hwy","hwy"],
# '..y..':["displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy"],
# '..corr..':[null,0.14784281645020295,0.9302271024198506,-0.7985239689348548,-0.7660200208864677,null,null,0.1222453474355237,-0.0372322908599655,0.0021576430766320123,null,null,null,-0.8057714082675279,-0.7619123538971942,null,null,null,null,0.9559159136495734,null,null,null,null,null],
# '..corr_abs..':[null,0.14784281645020295,0.9302271024198506,0.7985239689348548,0.7660200208864677,null,null,0.1222453474355237,0.0372322908599655,0.0021576430766320123,null,null,null,0.8057714082675279,0.7619123538971942,null,null,null,null,0.9559159136495734,null,null,null,null,null]
# }
# },{
# 'geom':"text",
# 'stat':"corr",
# 'mapping':{
# 'size':"..corr_abs.."
# },
# 'show_legend':true,
# 'sampling':"none",
# 'tooltips':{
# 'tooltip_formats':[{
# 'field':"@..corr..",
# 'format':".2f"
# }],
# 'tooltip_lines':["@..corr.."]
# },
# 'data_meta':{
# },
# 'label_format':".2f",
# 'na_text':"",
# 'size_unit':"x",
# 'type':"full",
# 'color':"white",
# 'data':{
# '..x..':["displ","displ","displ","displ","displ","year","year","year","year","year","cyl","cyl","cyl","cyl","cyl","cty","cty","cty","cty","cty","hwy","hwy","hwy","hwy","hwy"],
# '..y..':["displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy"],
# '..corr..':[1.0,0.14784281645020295,0.9302271024198506,-0.7985239689348548,-0.7660200208864677,0.14784281645020295,1.0,0.1222453474355237,-0.0372322908599655,0.0021576430766320123,0.9302271024198506,0.1222453474355237,1.0,-0.8057714082675279,-0.7619123538971942,-0.7985239689348548,-0.0372322908599655,-0.8057714082675279,1.0,0.9559159136495734,-0.7660200208864677,0.0021576430766320123,-0.7619123538971942,0.9559159136495734,1.0],
# '..corr_abs..':[1.0,0.14784281645020295,0.9302271024198506,0.7985239689348548,0.7660200208864677,0.14784281645020295,1.0,0.1222453474355237,0.0372322908599655,0.0021576430766320123,0.9302271024198506,0.1222453474355237,1.0,0.

# %% [markdown]
# ### Customizing colors.
#
# Instead of the default blue-grey-red gradient you can define your own lower-middle-upper colors, or
# choose one of the available 'Brewer' diverging palettes.
#
# Let's create a gradient resembling one of Seaborn gradients.

# %%
bld = corr_plot(mpg_df).points().labels().tiles()

# Configure gradient resembling one of Seaborn gradients.
gradient = (bld
            .palette_gradient(low='#417555', mid='#EDEDED', high='#963CA7')
            .build()) + ggtitle("Custom gradient")

# Configure Brewer 'BrBG' palette.
brewer = (bld
            .palette_BrBG()
            .build()) + ggtitle("Brewer")

# %%
group([
    gradient,
    brewer
])
# Out:
#    <div id="3GiWMu"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# 'kind':"ggbunch",
# 'items':[{
# 'x':0,
# 'y':0,
# 'width':null,
# 'height':null,
# 'feature_spec':{
# 'data':{
# },
# 'mapping':{
# },
# 'data_meta':{
# },
# 'coord':{
# 'name':"cartesian"
# },
# 'theme':{
# 'axis_title':{
# 'name':"blank"
# },
# 'axis_line_x':{
# 'name':"blank"
# },
# 'axis_line_y':{
# 'name':"blank"
# },
# 'legend_title':{
# 'name':"blank"
# }
# },
# 'ggsize':{
# 'width':400,
# 'height':300.0
# },
# 'ggtitle':{
# 'text':"Custom gradient"
# },
# 'kind':"plot",
# 'scales':[{
# 'name':"",
# 'aesthetic':"size",
# 'na_value':0,
# 'guide':"none",
# 'scale_mapper_kind':"identity"
# },{
# 'name':"Corr",
# 'aesthetic':"color",
# 'breaks':[-1.0,-0.5,0.0,0.5,1.0],
# 'limits':[-1.0,1.0],
# 'na_value':"rgba(0,0,0,0)",
# 'low':"#417555",
# 'mid':"#EDEDED",
# 'high':"#963CA7",
# 'midpoint':0,
# 'scale_mapper_kind':"color_gradient2"
# },{
# 'name':"Corr",
# 'aesthetic':"fill",
# 'breaks':[-1.0,-0.5,0.0,0.5,1.0],
# 'limits':[-1.0,1.0],
# 'na_value':"rgba(0,0,0,0)",
# 'low':"#417555",
# 'mid':"#EDEDED",
# 'high':"#963CA7",
# 'midpoint':0,
# 'scale_mapper_kind':"color_gradient2"
# },{
# 'aesthetic':"x",
# 'expand':[0,0.1],
# 'discrete':true,
# 'reverse':false
# },{
# 'aesthetic':"y",
# 'expand':[0,0.1],
# 'discrete':true,
# 'reverse':true
# }],
# 'layers':[{
# 'geom':"tile",
# 'stat':"corr",
# 'mapping':{
# },
# 'show_legend':true,
# 'sampling':"none",
# 'tooltips':{
# 'tooltip_formats':[{
# 'field':"@..corr..",
# 'format':".2f"
# }],
# 'tooltip_lines':["@..corr.."]
# },
# 'data_meta':{
# },
# 'size':0.0,
# 'width':1.002,
# 'height':1.002,
# 'type':"upper",
# 'diag':false,
# 'data':{
# '..x..':["displ","displ","displ","displ","displ","year","year","year","year","year","cyl","cyl","cyl","cyl","cyl","cty","cty","cty","cty","cty","hwy","hwy","hwy","hwy","hwy"],
# '..y..':["displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy"],
# '..corr..':[null,0.14784281645020295,0.9302271024198506,-0.7985239689348548,-0.7660200208864677,null,null,0.1222453474355237,-0.0372322908599655,0.0021576430766320123,null,null,null,-0.8057714082675279,-0.7619123538971942,null,null,null,null,0.9559159136495734,null,null,null,null,null]
# }
# },{
# 'geom':"point",
# 'stat':"corr",
# 'mapping':{
# 'size':"..corr_abs.."
# },
# 'show_legend':true,
# 'sampling':"none",
# 'tooltips':{
# 'tooltip_formats':[{
# 'field':"@..corr..",
# 'format':".2f"
# }],
# 'tooltip_lines':["@..corr.."]
# },
# 'data_meta':{
# },
# 'size_unit':"x",
# 'type':"lower",
# 'diag':false,
# 'data':{
# '..x..':["displ","displ","displ","displ","displ","year","year","year","year","year","cyl","cyl","cyl","cyl","cyl","cty","cty","cty","cty","cty","hwy","hwy","hwy","hwy","hwy"],
# '..y..':["displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy"],
# '..corr..':[null,null,null,null,null,0.14784281645020295,null,null,null,null,0.9302271024198506,0.1222453474355237,null,null,null,-0.7985239689348548,-0.0372322908599655,-0.8057714082675279,null,null,-0.7660200208864677,0.0021576430766320123,-0.7619123538971942,0.9559159136495734,null],
# '..corr_abs..':[null,null,null,null,null,0.14784281645020295,null,null,null,null,0.9302271024198506,0.1222453474355237,null,null,null,0.7985239689348548,0.0372322908599655,0.8057714082675279,null,null,0.7660200208864677,0.0021576430766320123,0.7619123538971942,0.9559159136495734,null]
# }
# },{
# 'geom':"text",
# 'stat':"corr",
# 'mapping':{
# 'size':"..corr_abs.."
# },
# 'show_legend':true,
# 'sampling':"none",
# 'tooltips':{
# 'tooltip_formats':[{
# 'field':"@..corr..",
# 'format':".2f"
# }],
# 'tooltip_lines':["@..corr.."]
# },
# 'data_meta':{
# },
# 'label_format':".2f",
# 'na_text':"",
# 'size_unit':"x",
# 'type':"lower",
# 'diag':false,
# 'color':"white",
# 'data':{
# '..x..':["displ","displ","displ","displ","displ","year","year","year","year","year","cyl","cyl","cyl","cyl","cyl","cty","cty","cty","cty","cty","hwy","hwy","hwy","hwy","hwy"],
# '..y..':["displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy"],
# '..corr..':[null,null,null,null,null,0.14784281645020295,null,null,null,null,0.9302271024198506,0.1222453474355237,null,null,null,-0.7985239689348548,-0.0372322908599655,-0.8057714082675279,null,null,-0.7660200208864677,0.0021576430766320123,-0.7619123538971942,0.9559159136495734,null],
# '..corr_abs..':[null,null,null,null,null,0.14784281645020295,null,null,null,null,0.9302271024198506,0.1222453474355237,null,null,null,0.7985239689348548,0.0372322908599655,0.8057714082675279,null,null,0.7660200208864677,0.0021576430766320123,0.7619123538971942,0.9559159136495734,null]
# }
# }]
# }
# },{
# 'x':450,
# 'y':0,
# 'width':null,
# 'height':null,
# 'feature_spec':{
# 'data':{
# },
# 'mapping':{
# },
# 'data_meta':{
# },
# 'coord':{
# 'name':"cartesian"
# },
# 'theme':{
# 'axis_title':{
# 'name':"blank"
# },
# 'axis_line_x':{
# 'name':"blank"
# },
# 'axis_line_y':{
# 'name':"blank"
# },
# 'legend_title':{
# 'name':"blank"
# }
# },
# 'ggsize':{
# 'width':400,
# 'height':300.0
# },
# 'ggtitle':{
# 'text':"Brewer"
# },
# 'kind':"plot",
# 'scales':[{
# 'name':"",
# 'aesthetic':"size",
# 'na_value':0,
# 'guide':"none",
# 'scale_mapper_kind':"identity"
# },{
# 'name':"Corr",
# 'aesthetic':"color",
# 'breaks':[-1.0,-0.5,0.0,0.5,1.0],
# 'labels':["-1","-0.5","0","0.5","1"],
# 'limits':[-1.0,1.0],
# 'na_value':"rgba(0,0,0,0)",
# 'palette':"BrBG",
# 'scale_mapper_kind':"color_brewer"
# },{
# 'name':"Corr",
# 'aesthetic':"fill",
# 'breaks':[-1.0,-0.5,0.0,0.5,1.0],
# 'labels':["-1","-0.5","0","0.5","1"],
# 'limits':[-1.0,1.0],
# 'na_value':"rgba(0,0,0,0)",
# 'palette':"BrBG",
# 'scale_mapper_kind':"color_brewer"
# },{
# 'aesthetic':"x",
# 'expand':[0,0.1],
# 'discrete':true,
# 'reverse':false
# },{
# 'aesthetic':"y",
# 'expand':[0,0.1],
# 'discrete':true,
# 'reverse':true
# }],
# 'layers':[{
# 'geom':"tile",
# 'stat':"corr",
# 'mapping':{
# },
# 'show_legend':true,
# 'sampling':"none",
# 'tooltips':{
# 'tooltip_formats':[{
# 'field':"@..corr..",
# 'format':".2f"
# }],
# 'tooltip_lines':["@..corr.."]
# },
# 'data_meta':{
# },
# 'size':0.0,
# 'width':1.002,
# 'height':1.002,
# 'type':"upper",
# 'diag':false,
# 'data':{
# '..x..':["displ","displ","displ","displ","displ","year","year","year","year","year","cyl","cyl","cyl","cyl","cyl","cty","cty","cty","cty","cty","hwy","hwy","hwy","hwy","hwy"],
# '..y..':["displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy"],
# '..corr..':[null,0.14784281645020295,0.9302271024198506,-0.7985239689348548,-0.7660200208864677,null,null,0.1222453474355237,-0.0372322908599655,0.0021576430766320123,null,null,null,-0.8057714082675279,-0.7619123538971942,null,null,null,null,0.9559159136495734,null,null,null,null,null]
# }
# },{
# 'geom':"point",
# 'stat':"corr",
# 'mapping':{
# 'size':"..corr_abs.."
# },
# 'show_legend':true,
# 'sampling':"none",
# 'tooltips':{
# 'tooltip_formats':[{
# 'field':"@..corr..",
# 'format':".2f"
# }],
# 'tooltip_lines':["@..corr.."]
# },
# 'data_meta':{
# },
# 'size_unit':"x",
# 'type':"lower",
# 'diag':false,
# 'data':{
# '..x..':["displ","displ","displ","displ","displ","year","year","year","year","year","cyl","cyl","cyl","cyl","cyl","cty","cty","cty","cty","cty","hwy","hwy","hwy","hwy","hwy"],
# '..y..':["displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy"],
# '..corr..':[null,null,null,null,null,0.14784281645020295,null,null,null,null,0.9302271024198506,0.1222453474355237,null,null,null,-0.7985239689348548,-0.0372322908599655,-0.8057714082675279,null,null,-0.7660200208864677,0.0021576430766320123,-0.7619123538971942,0.9559159136495734,null],
# '..corr_abs..':[null,null,null,null,null,0.14784281645020295,null,null,null,null,0.9302271024198506,0.1222453474355237,null,null,null,0.7985239689348548,0.0372322908599655,0.8057714082675279,null,null,0.7660200208864677,0.0021576430766320123,0.7619123538971942,0.9559159136495734,null]
# }
# },{
# 'geom':"text",
# 'stat':"corr",
# 'mapping':{
# 'size':"..corr_abs.."
# },
# 'show_legend':true,
# '

# %% [markdown]
# ###
# ### Correlation plot with large number of variables in dataset.
#
# The [Kaggle House Prices](https://www.kaggle.com/c/house-prices-advanced-regression-techniques/data?select=train.csv) dataset contains 81 variables.

# %%
housing_df = pd.read_csv("../data/Ames_house_prices_train.csv")
housing_df.shape
# Out:
# (1460, 81)

# %% [markdown]
# Correlation plot that shows all the correlations in this dataset is too large and barely useful.

# %%
corr_plot(housing_df).tiles(type='lower').palette_BrBG().build()
# Out:
#    <div id="QzG2vA"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# 'data':{
# },
# 'mapping':{
# },
# 'data_meta':{
# },
# 'coord':{
# 'name':"cartesian"
# },
# 'theme':{
# 'axis_title':{
# 'name':"blank"
# },
# 'axis_line_x':{
# 'name':"blank"
# },
# 'axis_line_y':{
# 'name':"blank"
# },
# 'legend_title':{
# 'name':"blank"
# }
# },
# 'ggsize':{
# 'width':900,
# 'height':675.0
# },
# 'kind':"plot",
# 'scales':[{
# 'name':"",
# 'aesthetic':"size",
# 'na_value':0,
# 'guide':"none",
# 'scale_mapper_kind':"identity"
# },{
# 'name':"Corr",
# 'aesthetic':"color",
# 'breaks':[-1.0,-0.5,0.0,0.5,1.0],
# 'labels':["-1","-0.5","0","0.5","1"],
# 'limits':[-1.0,1.0],
# 'na_value':"rgba(0,0,0,0)",
# 'palette':"BrBG",
# 'scale_mapper_kind':"color_brewer"
# },{
# 'name':"Corr",
# 'aesthetic':"fill",
# 'breaks':[-1.0,-0.5,0.0,0.5,1.0],
# 'labels':["-1","-0.5","0","0.5","1"],
# 'limits':[-1.0,1.0],
# 'na_value':"rgba(0,0,0,0)",
# 'palette':"BrBG",
# 'scale_mapper_kind':"color_brewer"
# },{
# 'aesthetic':"x",
# 'expand':[0,0.1],
# 'discrete':true,
# 'reverse':false
# },{
# 'aesthetic':"y",
# 'expand':[0,0.1],
# 'discrete':true,
# 'reverse':true
# }],
# 'layers':[{
# 'geom':"tile",
# 'stat':"corr",
# 'mapping':{
# },
# 'show_legend':true,
# 'sampling':"none",
# 'tooltips':{
# 'tooltip_formats':[{
# 'field':"@..corr..",
# 'format':".2f"
# }],
# 'tooltip_lines':["@..corr.."]
# },
# 'data_meta':{
# },
# 'size':0.0,
# 'width':1.002,
# 'height':1.002,
# 'type':"upper",
# 'diag':false,
# 'data':{
# '..x..':["Id","Id","Id","Id","Id","Id","Id","Id","Id","Id","Id","Id","Id","Id","Id","Id","Id","Id","Id","Id","Id","Id","Id","Id","Id","Id","Id","Id","Id","Id","Id","Id","Id","Id","Id","Id","Id","Id","MSSubClass","MSSubClass","MSSubClass","MSSubClass","MSSubClass","MSSubClass","MSSubClass","MSSubClass","MSSubClass","MSSubClass","MSSubClass","MSSubClass","MSSubClass","MSSubClass","MSSubClass","MSSubClass","MSSubClass","MSSubClass","MSSubClass","MSSubClass","MSSubClass","MSSubClass","MSSubClass","MSSubClass","MSSubClass","MSSubClass","MSSubClass","MSSubClass","MSSubClass","MSSubClass","MSSubClass","MSSubClass","MSSubClass","MSSubClass","MSSubClass","MSSubClass","MSSubClass","MSSubClass","LotFrontage","LotFrontage","LotFrontage","LotFrontage","LotFrontage","LotFrontage","LotFrontage","LotFrontage","LotFrontage","LotFrontage","LotFrontage","LotFrontage","LotFrontage","LotFrontage","LotFrontage","LotFrontage","LotFrontage","LotFrontage","LotFrontage","LotFrontage","LotFrontage","LotFrontage","LotFrontage","LotFrontage","LotFrontage","LotFrontage","LotFrontage","LotFrontage","LotFrontage","LotFrontage","LotFrontage","LotFrontage","LotFrontage","LotFrontage","LotFrontage","LotFrontage","LotFrontage","LotFrontage","LotArea","LotArea","LotArea","LotArea","LotArea","LotArea","LotArea","LotArea","LotArea","LotArea","LotArea","LotArea","LotArea","LotArea","LotArea","LotArea","LotArea","LotArea","LotArea","LotArea","LotArea","LotArea","LotArea","LotArea","LotArea","LotArea","LotArea","LotArea","LotArea","LotArea","LotArea","LotArea","LotArea","LotArea","LotArea","LotArea","LotArea","LotArea","OverallQual","OverallQual","OverallQual","OverallQual","OverallQual","OverallQual","OverallQual","OverallQual","OverallQual","OverallQual","OverallQual","OverallQual","OverallQual","OverallQual","OverallQual","OverallQual","OverallQual","OverallQual","OverallQual","OverallQual","OverallQual","OverallQual","OverallQual","OverallQual","OverallQual","OverallQual","OverallQual","OverallQual","OverallQual","OverallQual","OverallQual","OverallQual","OverallQual","OverallQual","OverallQual","OverallQual","OverallQual","OverallQual","OverallCond","OverallCond","OverallCond","OverallCond","OverallCond","OverallCond","OverallCond","OverallCond","OverallCond","OverallCond","OverallCond","OverallCond","OverallCond","OverallCond","OverallCond","OverallCond","OverallCond","OverallCond","OverallCond","OverallCond","OverallCond","OverallCond","OverallCond","OverallCond","OverallCond","OverallCond","OverallCond","OverallCond","OverallCond","OverallCond","OverallCond","OverallCond","OverallCond","OverallCond","OverallCond","OverallCond","OverallCond","OverallCond","YearBuilt","YearBuilt","YearBuilt","YearBuilt","YearBuilt","YearBuilt","YearBuilt","YearBuilt","YearBuilt","YearBuilt","YearBuilt","YearBuilt","YearBuilt","YearBuilt","YearBuilt","YearBuilt","YearBuilt","YearBuilt","YearBuilt","YearBuilt","YearBuilt","YearBuilt","YearBuilt","YearBuilt","YearBuilt","YearBuilt","YearBuilt","YearBuilt","YearBuilt","YearBuilt","YearBuilt","YearBuilt","YearBuilt","YearBuilt","YearBuilt","YearBuilt","YearBuilt","YearBuilt","YearRemodAdd","YearRemodAdd","YearRemodAdd","YearRemodAdd","YearRemodAdd","YearRemodAdd","YearRemodAdd","YearRemodAdd","YearRemodAdd","YearRemodAdd","YearRemodAdd","YearRemodAdd","YearRemodAdd","YearRemodAdd","YearRemodAdd","YearRemodAdd","YearRemodAdd","YearRemodAdd","YearRemodAdd","YearRemodAdd","YearRemodAdd","YearRemodAdd","YearRemodAdd","YearRemodAdd","YearRemodAdd","YearRemodAdd","YearRemodAdd","YearRemodAdd","YearRemodAdd","YearRemodAdd","YearRemodAdd","YearRemodAdd","YearRemodAdd","YearRemodAdd","YearRemodAdd","YearRemodAdd","YearRemodAdd","YearRemodAdd","MasVnrArea","MasVnrArea","MasVnrArea","MasVnrArea","MasVnrArea","MasVnrArea","MasVnrArea","MasVnrArea","MasVnrArea","MasVnrArea","MasVnrArea","MasVnrArea","MasVnrArea","MasVnrArea","MasVnrArea","MasVnrArea","MasVnrArea","MasVnrArea","MasVnrArea","MasVnrArea","MasVnrArea","MasVnrArea","MasVnrArea","MasVn ...

# %% [markdown]
# #### The 'threshold' parameter.
#
# The 'threshold' parameter let us specify a level of significance, below which variables are not shown.

# %%
(corr_plot(housing_df, threshold=.5).tiles(diag=False).palette_BrBG().build() 
 + ggtitle("Threshold: 0.5")
 + ggsize(550, 400))
# Out:
#    <div id="oEsgb9"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# 'data':{
# },
# 'mapping':{
# },
# 'data_meta':{
# },
# 'coord':{
# 'name':"cartesian"
# },
# 'theme':{
# 'axis_title':{
# 'name':"blank"
# },
# 'axis_line_x':{
# 'name':"blank"
# },
# 'axis_line_y':{
# 'name':"blank"
# },
# 'legend_title':{
# 'name':"blank"
# }
# },
# 'ggsize':{
# 'width':550,
# 'height':400
# },
# 'ggtitle':{
# 'text':"Threshold: 0.5"
# },
# 'kind':"plot",
# 'scales':[{
# 'name':"",
# 'aesthetic':"size",
# 'na_value':0,
# 'guide':"none",
# 'scale_mapper_kind':"identity"
# },{
# 'name':"Corr",
# 'aesthetic':"color",
# 'breaks':[-1.0,-0.5,0.0,0.5,1.0],
# 'labels':["-1","-0.5","0","0.5","1"],
# 'limits':[-1.0,1.0],
# 'na_value':"rgba(0,0,0,0)",
# 'palette':"BrBG",
# 'scale_mapper_kind':"color_brewer"
# },{
# 'name':"Corr",
# 'aesthetic':"fill",
# 'breaks':[-1.0,-0.5,0.0,0.5,1.0],
# 'labels':["-1","-0.5","0","0.5","1"],
# 'limits':[-1.0,1.0],
# 'na_value':"rgba(0,0,0,0)",
# 'palette':"BrBG",
# 'scale_mapper_kind':"color_brewer"
# },{
# 'aesthetic':"x",
# 'expand':[0,0.1],
# 'discrete':true,
# 'reverse':false
# },{
# 'aesthetic':"y",
# 'expand':[0,0.1],
# 'discrete':true,
# 'reverse':true
# }],
# 'layers':[{
# 'geom':"tile",
# 'stat':"corr",
# 'mapping':{
# },
# 'show_legend':true,
# 'sampling':"none",
# 'tooltips':{
# 'tooltip_formats':[{
# 'field':"@..corr..",
# 'format':".2f"
# }],
# 'tooltip_lines':["@..corr.."]
# },
# 'data_meta':{
# },
# 'size':0.0,
# 'width':1.002,
# 'height':1.002,
# 'diag':false,
# 'threshold':0.5,
# 'data':{
# '..x..':["OverallQual","OverallQual","OverallQual","OverallQual","OverallQual","OverallQual","OverallQual","OverallQual","OverallQual","OverallQual","OverallQual","OverallQual","OverallQual","OverallQual","OverallQual","OverallQual","OverallQual","YearBuilt","YearBuilt","YearBuilt","YearBuilt","YearBuilt","YearBuilt","YearBuilt","YearBuilt","YearBuilt","YearBuilt","YearBuilt","YearBuilt","YearBuilt","YearBuilt","YearBuilt","YearBuilt","YearBuilt","YearRemodAdd","YearRemodAdd","YearRemodAdd","YearRemodAdd","YearRemodAdd","YearRemodAdd","YearRemodAdd","YearRemodAdd","YearRemodAdd","YearRemodAdd","YearRemodAdd","YearRemodAdd","YearRemodAdd","YearRemodAdd","YearRemodAdd","YearRemodAdd","YearRemodAdd","BsmtFinSF1","BsmtFinSF1","BsmtFinSF1","BsmtFinSF1","BsmtFinSF1","BsmtFinSF1","BsmtFinSF1","BsmtFinSF1","BsmtFinSF1","BsmtFinSF1","BsmtFinSF1","BsmtFinSF1","BsmtFinSF1","BsmtFinSF1","BsmtFinSF1","BsmtFinSF1","BsmtFinSF1","TotalBsmtSF","TotalBsmtSF","TotalBsmtSF","TotalBsmtSF","TotalBsmtSF","TotalBsmtSF","TotalBsmtSF","TotalBsmtSF","TotalBsmtSF","TotalBsmtSF","TotalBsmtSF","TotalBsmtSF","TotalBsmtSF","TotalBsmtSF","TotalBsmtSF","TotalBsmtSF","TotalBsmtSF","1stFlrSF","1stFlrSF","1stFlrSF","1stFlrSF","1stFlrSF","1stFlrSF","1stFlrSF","1stFlrSF","1stFlrSF","1stFlrSF","1stFlrSF","1stFlrSF","1stFlrSF","1stFlrSF","1stFlrSF","1stFlrSF","1stFlrSF","2ndFlrSF","2ndFlrSF","2ndFlrSF","2ndFlrSF","2ndFlrSF","2ndFlrSF","2ndFlrSF","2ndFlrSF","2ndFlrSF","2ndFlrSF","2ndFlrSF","2ndFlrSF","2ndFlrSF","2ndFlrSF","2ndFlrSF","2ndFlrSF","2ndFlrSF","GrLivArea","GrLivArea","GrLivArea","GrLivArea","GrLivArea","GrLivArea","GrLivArea","GrLivArea","GrLivArea","GrLivArea","GrLivArea","GrLivArea","GrLivArea","GrLivArea","GrLivArea","GrLivArea","GrLivArea","BsmtFullBath","BsmtFullBath","BsmtFullBath","BsmtFullBath","BsmtFullBath","BsmtFullBath","BsmtFullBath","BsmtFullBath","BsmtFullBath","BsmtFullBath","BsmtFullBath","BsmtFullBath","BsmtFullBath","BsmtFullBath","BsmtFullBath","BsmtFullBath","BsmtFullBath","FullBath","FullBath","FullBath","FullBath","FullBath","FullBath","FullBath","FullBath","FullBath","FullBath","FullBath","FullBath","FullBath","FullBath","FullBath","FullBath","FullBath","HalfBath","HalfBath","HalfBath","HalfBath","HalfBath","HalfBath","HalfBath","HalfBath","HalfBath","HalfBath","HalfBath","HalfBath","HalfBath","HalfBath","HalfBath","HalfBath","HalfBath","BedroomAbvGr","BedroomAbvGr","BedroomAbvGr","BedroomAbvGr","BedroomAbvGr","BedroomAbvGr","BedroomAbvGr","BedroomAbvGr","BedroomAbvGr","BedroomAbvGr","BedroomAbvGr","BedroomAbvGr","BedroomAbvGr","BedroomAbvGr","BedroomAbvGr","BedroomAbvGr","BedroomAbvGr","TotRmsAbvGrd","TotRmsAbvGrd","TotRmsAbvGrd","TotRmsAbvGrd","TotRmsAbvGrd","TotRmsAbvGrd","TotRmsAbvGrd","TotRmsAbvGrd","TotRmsAbvGrd","TotRmsAbvGrd","TotRmsAbvGrd","TotRmsAbvGrd","TotRmsAbvGrd","TotRmsAbvGrd","TotRmsAbvGrd","TotRmsAbvGrd","TotRmsAbvGrd","GarageYrBlt","GarageYrBlt","GarageYrBlt","GarageYrBlt","GarageYrBlt","GarageYrBlt","GarageYrBlt","GarageYrBlt","GarageYrBlt","GarageYrBlt","GarageYrBlt","GarageYrBlt","GarageYrBlt","GarageYrBlt","GarageYrBlt","GarageYrBlt","GarageYrBlt","GarageCars","GarageCars","GarageCars","GarageCars","GarageCars","GarageCars","GarageCars","GarageCars","GarageCars","GarageCars","GarageCars","GarageCars","GarageCars","GarageCars","GarageCars","GarageCars","GarageCars","GarageArea","GarageArea","GarageArea","GarageArea","GarageArea","GarageArea","GarageArea","GarageArea","GarageArea","GarageArea","GarageArea","GarageArea","GarageArea","GarageArea","GarageArea","GarageArea","GarageArea","SalePrice","SalePrice","SalePrice","SalePrice","SalePrice","SalePrice","SalePrice","SalePrice","SalePrice","SalePrice","SalePrice","SalePrice","SalePrice","SalePrice","SalePrice","SalePrice","SalePrice"],
# '..y..':["OverallQual","YearBuilt","YearRemodAdd","BsmtFinSF1","TotalBsmtSF","1stFlrSF","2ndFlrSF","GrLivArea","BsmtFullBath","FullBath","HalfBath","BedroomAbvGr","TotRmsAbvGrd","GarageYrBlt","GarageCars","GarageArea","SalePrice","OverallQual","YearBuilt","YearRemodAdd","BsmtFinSF1","TotalBsmtSF","1stFlrSF","2ndFlrSF","GrLivArea","BsmtFullBath","FullBath","HalfBath","BedroomAbvGr","TotRmsAbvGrd","GarageYrBlt","GarageCars","GarageArea","SalePrice","OverallQual","YearBuilt","YearRemodAdd","BsmtFinSF1","TotalBsmtSF","1stFlrSF","2ndFlrSF","GrLivArea","BsmtFullBath","FullBath","HalfBath","BedroomAbvGr","TotRmsAbvGrd","GarageYrBlt","GarageCars","GarageArea","SalePrice","OverallQual","YearBuilt","YearRemodAdd","BsmtFinSF1","TotalBsmtSF","1stFlrSF","2ndFlrSF","GrLivArea","BsmtFullBath","FullBath","HalfBath","BedroomAbvGr","TotRmsAbvGrd","GarageYrBlt","GarageCars","GarageArea","SalePrice","OverallQual","YearBuilt","YearRemodAdd","BsmtFinSF1","TotalBsmtSF","1stFlrSF","2ndFlrSF","GrLivArea","BsmtFullBath","FullBath","HalfBath","BedroomAbvGr","TotRmsAbvGrd","GarageYrBlt","GarageCars","GarageArea","SalePrice","OverallQual","YearBuilt","YearRemodAdd","BsmtFinSF1","TotalBsmtSF","1stFlrSF","2ndFlrSF","GrLivArea","BsmtFullBath","FullBath","HalfBath","BedroomAbvGr","TotRmsAbvGrd","GarageYrBlt","GarageCars","GarageArea","SalePrice","OverallQual","YearBuilt","YearRemodAdd","BsmtFinSF1","TotalBsmtSF","1stFlrSF","2ndFlrSF","GrLivArea","BsmtFullBath","FullBath","HalfBath","BedroomAbvGr","TotRmsAbvGrd","GarageYrBlt","GarageCars","GarageArea","SalePrice","OverallQual","YearBuilt","YearRemodAdd","BsmtFinSF1","TotalBsmtSF","1stFlrSF","2ndFlrSF","GrLivArea","BsmtFullBath","FullBath","HalfBath","BedroomAbvGr","TotRmsAbvGrd","GarageYrBlt","GarageCars","GarageArea","SalePrice","OverallQual","YearBuilt","YearRemodAdd","BsmtFinSF1","TotalBsmtSF","1stFlrSF","2ndFlrSF","GrLivArea","BsmtFullBath","FullBath","HalfBath","BedroomAbvGr","TotRmsAbvGrd","GarageYrBlt","GarageCars","GarageArea","SalePrice","OverallQual","YearBuilt","YearRemodAdd","BsmtFinSF1","TotalBsmtSF","1stFlrSF","2ndFlrSF","GrLivArea","BsmtFullBath","FullBath","HalfBath","BedroomAbvGr","TotRmsAbvGrd","GarageYrBlt","GarageCars","GarageArea","SalePrice","OverallQual","YearBuilt","YearRemodAdd","BsmtFinSF1","TotalBsmtSF","1stFlrSF","2ndFlrSF","GrLivArea","BsmtFullBath","FullBath","HalfBath","BedroomAbvGr","TotRmsAbvGrd","GarageYrBlt","GarageCars","GarageArea","SalePrice","OverallQual","YearBuilt","YearRemodAdd","BsmtFinSF1","TotalBsmtSF","1stFlrSF","2ndFlrSF","GrLivArea","BsmtFullBath","FullBath","HalfBath","BedroomAbvGr","TotRmsAbvGrd","GarageYrBlt","GarageCars","GarageArea","SalePrice","OverallQual","YearBuilt","YearRemodAdd","BsmtFinSF1","TotalBsmtSF","1stFlrSF","2ndFlrSF","GrLivArea","BsmtFullBath","FullBath","HalfB

# %% [markdown]
# Let's further increase our threshold in order to see only highly correlated variables.

# %%
(corr_plot(housing_df, threshold=.8)
 .tiles()
 .labels(color='white')
 .palette_BrBG().build() 
 + ggtitle("Threshold: 0.8")
 + ggsize(550, 400))
# Out:
#    <div id="E5GVGz"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# 'data':{
# },
# 'mapping':{
# },
# 'data_meta':{
# },
# 'coord':{
# 'name':"cartesian"
# },
# 'theme':{
# 'axis_title':{
# 'name':"blank"
# },
# 'axis_line_x':{
# 'name':"blank"
# },
# 'axis_line_y':{
# 'name':"blank"
# },
# 'legend_title':{
# 'name':"blank"
# }
# },
# 'ggsize':{
# 'width':550,
# 'height':400
# },
# 'ggtitle':{
# 'text':"Threshold: 0.8"
# },
# 'kind':"plot",
# 'scales':[{
# 'name':"",
# 'aesthetic':"size",
# 'na_value':0,
# 'guide':"none",
# 'scale_mapper_kind':"identity"
# },{
# 'name':"Corr",
# 'aesthetic':"color",
# 'breaks':[-1.0,-0.5,0.0,0.5,1.0],
# 'labels':["-1","-0.5","0","0.5","1"],
# 'limits':[-1.0,1.0],
# 'na_value':"rgba(0,0,0,0)",
# 'palette':"BrBG",
# 'scale_mapper_kind':"color_brewer"
# },{
# 'name':"Corr",
# 'aesthetic':"fill",
# 'breaks':[-1.0,-0.5,0.0,0.5,1.0],
# 'labels':["-1","-0.5","0","0.5","1"],
# 'limits':[-1.0,1.0],
# 'na_value':"rgba(0,0,0,0)",
# 'palette':"BrBG",
# 'scale_mapper_kind':"color_brewer"
# },{
# 'aesthetic':"x",
# 'expand':[0,0.1],
# 'discrete':true,
# 'reverse':false
# },{
# 'aesthetic':"y",
# 'expand':[0,0.1],
# 'discrete':true,
# 'reverse':true
# }],
# 'layers':[{
# 'geom':"tile",
# 'stat':"corr",
# 'mapping':{
# },
# 'show_legend':true,
# 'sampling':"none",
# 'tooltips':{
# 'tooltip_formats':[{
# 'field':"@..corr..",
# 'format':".2f"
# }],
# 'tooltip_lines':["@..corr.."]
# },
# 'data_meta':{
# },
# 'size':0.0,
# 'width':1.002,
# 'height':1.002,
# 'diag':false,
# 'threshold':0.8,
# 'data':{
# '..x..':["YearBuilt","YearBuilt","YearBuilt","YearBuilt","YearBuilt","YearBuilt","YearBuilt","YearBuilt","TotalBsmtSF","TotalBsmtSF","TotalBsmtSF","TotalBsmtSF","TotalBsmtSF","TotalBsmtSF","TotalBsmtSF","TotalBsmtSF","1stFlrSF","1stFlrSF","1stFlrSF","1stFlrSF","1stFlrSF","1stFlrSF","1stFlrSF","1stFlrSF","GrLivArea","GrLivArea","GrLivArea","GrLivArea","GrLivArea","GrLivArea","GrLivArea","GrLivArea","TotRmsAbvGrd","TotRmsAbvGrd","TotRmsAbvGrd","TotRmsAbvGrd","TotRmsAbvGrd","TotRmsAbvGrd","TotRmsAbvGrd","TotRmsAbvGrd","GarageYrBlt","GarageYrBlt","GarageYrBlt","GarageYrBlt","GarageYrBlt","GarageYrBlt","GarageYrBlt","GarageYrBlt","GarageCars","GarageCars","GarageCars","GarageCars","GarageCars","GarageCars","GarageCars","GarageCars","GarageArea","GarageArea","GarageArea","GarageArea","GarageArea","GarageArea","GarageArea","GarageArea"],
# '..y..':["YearBuilt","TotalBsmtSF","1stFlrSF","GrLivArea","TotRmsAbvGrd","GarageYrBlt","GarageCars","GarageArea","YearBuilt","TotalBsmtSF","1stFlrSF","GrLivArea","TotRmsAbvGrd","GarageYrBlt","GarageCars","GarageArea","YearBuilt","TotalBsmtSF","1stFlrSF","GrLivArea","TotRmsAbvGrd","GarageYrBlt","GarageCars","GarageArea","YearBuilt","TotalBsmtSF","1stFlrSF","GrLivArea","TotRmsAbvGrd","GarageYrBlt","GarageCars","GarageArea","YearBuilt","TotalBsmtSF","1stFlrSF","GrLivArea","TotRmsAbvGrd","GarageYrBlt","GarageCars","GarageArea","YearBuilt","TotalBsmtSF","1stFlrSF","GrLivArea","TotRmsAbvGrd","GarageYrBlt","GarageCars","GarageArea","YearBuilt","TotalBsmtSF","1stFlrSF","GrLivArea","TotRmsAbvGrd","GarageYrBlt","GarageCars","GarageArea","YearBuilt","TotalBsmtSF","1stFlrSF","GrLivArea","TotRmsAbvGrd","GarageYrBlt","GarageCars","GarageArea"],
# '..corr..':[null,null,null,null,null,0.8256674841743434,null,null,null,null,0.8195299750050355,null,null,null,null,null,null,0.8195299750050355,null,null,null,null,null,null,null,null,null,null,0.8254893743088377,null,null,null,null,null,null,0.8254893743088377,null,null,null,null,0.8256674841743434,null,null,null,null,null,null,null,null,null,null,null,null,null,null,0.8824754142814603,null,null,null,null,null,null,0.8824754142814603,null]
# }
# },{
# 'geom':"text",
# 'stat':"corr",
# 'mapping':{
# },
# 'show_legend':true,
# 'sampling':"none",
# 'tooltips':{
# 'tooltip_formats':[{
# 'field':"@..corr..",
# 'format':".2f"
# }],
# 'tooltip_lines':["@..corr.."]
# },
# 'data_meta':{
# },
# 'label_format':".2f",
# 'na_text':"",
# 'size_unit':"x",
# 'diag':false,
# 'color':"white",
# 'threshold':0.8,
# 'size':1,
# 'data':{
# '..x..':["YearBuilt","YearBuilt","YearBuilt","YearBuilt","YearBuilt","YearBuilt","YearBuilt","YearBuilt","TotalBsmtSF","TotalBsmtSF","TotalBsmtSF","TotalBsmtSF","TotalBsmtSF","TotalBsmtSF","TotalBsmtSF","TotalBsmtSF","1stFlrSF","1stFlrSF","1stFlrSF","1stFlrSF","1stFlrSF","1stFlrSF","1stFlrSF","1stFlrSF","GrLivArea","GrLivArea","GrLivArea","GrLivArea","GrLivArea","GrLivArea","GrLivArea","GrLivArea","TotRmsAbvGrd","TotRmsAbvGrd","TotRmsAbvGrd","TotRmsAbvGrd","TotRmsAbvGrd","TotRmsAbvGrd","TotRmsAbvGrd","TotRmsAbvGrd","GarageYrBlt","GarageYrBlt","GarageYrBlt","GarageYrBlt","GarageYrBlt","GarageYrBlt","GarageYrBlt","GarageYrBlt","GarageCars","GarageCars","GarageCars","GarageCars","GarageCars","GarageCars","GarageCars","GarageCars","GarageArea","GarageArea","GarageArea","GarageArea","GarageArea","GarageArea","GarageArea","GarageArea"],
# '..y..':["YearBuilt","TotalBsmtSF","1stFlrSF","GrLivArea","TotRmsAbvGrd","GarageYrBlt","GarageCars","GarageArea","YearBuilt","TotalBsmtSF","1stFlrSF","GrLivArea","TotRmsAbvGrd","GarageYrBlt","GarageCars","GarageArea","YearBuilt","TotalBsmtSF","1stFlrSF","GrLivArea","TotRmsAbvGrd","GarageYrBlt","GarageCars","GarageArea","YearBuilt","TotalBsmtSF","1stFlrSF","GrLivArea","TotRmsAbvGrd","GarageYrBlt","GarageCars","GarageArea","YearBuilt","TotalBsmtSF","1stFlrSF","GrLivArea","TotRmsAbvGrd","GarageYrBlt","GarageCars","GarageArea","YearBuilt","TotalBsmtSF","1stFlrSF","GrLivArea","TotRmsAbvGrd","GarageYrBlt","GarageCars","GarageArea","YearBuilt","TotalBsmtSF","1stFlrSF","GrLivArea","TotRmsAbvGrd","GarageYrBlt","GarageCars","GarageArea","YearBuilt","TotalBsmtSF","1stFlrSF","GrLivArea","TotRmsAbvGrd","GarageYrBlt","GarageCars","GarageArea"],
# '..corr..':[null,null,null,null,null,0.8256674841743434,null,null,null,null,0.8195299750050355,null,null,null,null,null,null,0.8195299750050355,null,null,null,null,null,null,null,null,null,null,0.8254893743088377,null,null,null,null,null,null,0.8254893743088377,null,null,null,null,0.8256674841743434,null,null,null,null,null,null,null,null,null,null,null,null,null,null,0.8824754142814603,null,null,null,null,null,null,0.8824754142814603,null]
# }
# }]
# };
#            var plotContainer = document.getElementById("E5GVGz");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# This picture can clearly give us some good ideas about possible improvements in our dataset for the purposes of
# training a linear regression model for example.
#
# For the instance, variables 'GarageArea' and 'GarageCars' are most likely not needed both for the model traning
# and can be removed and replaced with a synthetic variable of a sort.

# %% [markdown]
# ### The 'stat_corr()' function.
#
# The 'stat_corr()' function simply creates a bare-bones `ggplot` layer.
#
# In practice, what you get is a basic heatmap and therefore using of the 'stat_corr' function is rarely justifiable,
# unless you are willing to tweek it further to achieve some look that otherwise you couldn't get using the 'corr_plot' builder API.

# %%
group([
    (ggplot(mpg_df) 
     + stat_corr() 
     + ggtitle("Basic Heatmap") + ggsize(450, 400)),
    (ggplot(mpg_df, aes(fill='..corr_abs..'))
     + stat_corr(geom='point', type="lower", diag=False, shape=5)
     + stat_corr(geom='text', type="lower", diag=False, label_format='.1f')
     + scale_color_gradient(low='red', high='blue', guide='none')
     + stat_corr(geom='tile', type="upper", diag=True, threshold=.8)
     + stat_corr(geom='text', type="upper", diag=True, threshold=.8, label_format='.1f', size=1.2, color='white')
     + scale_fill_gradient2(low='white', mid='black', high='white', midpoint=.999, guide='none')
     + ggtitle("Weird Corr Plot") + ggsize(450, 400) + theme(axis_line='blank'))
])
# Out:
#    <div id="nmXxkZ"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# 'kind':"ggbunch",
# 'items':[{
# 'x':0,
# 'y':0,
# 'width':null,
# 'height':null,
# 'feature_spec':{
# 'data':{
# },
# 'mapping':{
# },
# 'data_meta':{
# },
# 'coord':{
# 'name':"cartesian"
# },
# 'ggtitle':{
# 'text':"Basic Heatmap"
# },
# 'ggsize':{
# 'width':450,
# 'height':400
# },
# 'kind':"plot",
# 'scales':[{
# 'aesthetic':"size",
# 'na_value':0,
# 'guide':"none",
# 'scale_mapper_kind':"identity"
# },{
# 'aesthetic':"color",
# 'na_value':"rgba(0,0,0,0)",
# 'scale_mapper_kind':"color_gradient"
# },{
# 'aesthetic':"fill",
# 'na_value':"rgba(0,0,0,0)",
# 'scale_mapper_kind':"color_gradient"
# },{
# 'aesthetic':"x",
# 'expand':[0,0.1],
# 'discrete':true,
# 'reverse':false
# },{
# 'aesthetic':"y",
# 'expand':[0,0.1],
# 'discrete':true,
# 'reverse':true
# }],
# 'layers':[{
# 'geom':"tile",
# 'stat':"corr",
# 'mapping':{
# },
# 'sampling':"none",
# 'tooltips':{
# 'tooltip_formats':[{
# 'field':"@..corr..",
# 'format':".2f"
# }],
# 'tooltip_lines':["@..corr.."]
# },
# 'data_meta':{
# },
# 'type':"full",
# 'na_text':"",
# 'label_format':".2f",
# 'data':{
# '..x..':["displ","displ","displ","displ","displ","year","year","year","year","year","cyl","cyl","cyl","cyl","cyl","cty","cty","cty","cty","cty","hwy","hwy","hwy","hwy","hwy"],
# '..y..':["displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy"],
# '..corr..':[1.0,0.14784281645020295,0.9302271024198506,-0.7985239689348548,-0.7660200208864677,0.14784281645020295,1.0,0.1222453474355237,-0.0372322908599655,0.0021576430766320123,0.9302271024198506,0.1222453474355237,1.0,-0.8057714082675279,-0.7619123538971942,-0.7985239689348548,-0.0372322908599655,-0.8057714082675279,1.0,0.9559159136495734,-0.7660200208864677,0.0021576430766320123,-0.7619123538971942,0.9559159136495734,1.0]
# }
# }]
# }
# },{
# 'x':450,
# 'y':0,
# 'width':null,
# 'height':null,
# 'feature_spec':{
# 'data':{
# },
# 'mapping':{
# 'fill':"..corr_abs.."
# },
# 'data_meta':{
# },
# 'coord':{
# 'name':"cartesian"
# },
# 'ggtitle':{
# 'text':"Weird Corr Plot"
# },
# 'ggsize':{
# 'width':450,
# 'height':400
# },
# 'theme':{
# 'axis_line':"blank"
# },
# 'kind':"plot",
# 'scales':[{
# 'aesthetic':"size",
# 'na_value':0,
# 'guide':"none",
# 'scale_mapper_kind':"identity"
# },{
# 'aesthetic':"color",
# 'na_value':"rgba(0,0,0,0)",
# 'scale_mapper_kind':"color_gradient"
# },{
# 'aesthetic':"x",
# 'discrete':true,
# 'reverse':false
# },{
# 'aesthetic':"y",
# 'discrete':true,
# 'reverse':true
# },{
# 'aesthetic':"size",
# 'na_value':0,
# 'guide':"none",
# 'scale_mapper_kind':"identity"
# },{
# 'aesthetic':"color",
# 'na_value':"rgba(0,0,0,0)",
# 'scale_mapper_kind':"color_gradient"
# },{
# 'aesthetic':"x",
# 'discrete':true,
# 'reverse':false
# },{
# 'aesthetic':"y",
# 'discrete':true,
# 'reverse':true
# },{
# 'aesthetic':"color",
# 'guide':"none",
# 'low':"red",
# 'high':"blue",
# 'scale_mapper_kind':"color_gradient"
# },{
# 'aesthetic':"size",
# 'na_value':0,
# 'guide':"none",
# 'scale_mapper_kind':"identity"
# },{
# 'aesthetic':"color",
# 'na_value':"rgba(0,0,0,0)",
# 'scale_mapper_kind':"color_gradient"
# },{
# 'aesthetic':"fill",
# 'na_value':"rgba(0,0,0,0)",
# 'scale_mapper_kind':"color_gradient"
# },{
# 'aesthetic':"x",
# 'expand':[0,0.1],
# 'discrete':true,
# 'reverse':false
# },{
# 'aesthetic':"y",
# 'expand':[0,0.1],
# 'discrete':true,
# 'reverse':true
# },{
# 'aesthetic':"size",
# 'na_value':0,
# 'guide':"none",
# 'scale_mapper_kind':"identity"
# },{
# 'aesthetic':"color",
# 'na_value':"rgba(0,0,0,0)",
# 'scale_mapper_kind':"color_gradient"
# },{
# 'aesthetic':"x",
# 'discrete':true,
# 'reverse':false
# },{
# 'aesthetic':"y",
# 'discrete':true,
# 'reverse':true
# },{
# 'aesthetic':"fill",
# 'guide':"none",
# 'low':"white",
# 'mid':"black",
# 'high':"white",
# 'midpoint':0.999,
# 'scale_mapper_kind':"color_gradient2"
# }],
# 'layers':[{
# 'geom':"point",
# 'stat':"corr",
# 'mapping':{
# },
# 'sampling':"none",
# 'tooltips':{
# 'tooltip_formats':[{
# 'field':"@..corr..",
# 'format':".2f"
# }],
# 'tooltip_lines':["@..corr.."]
# },
# 'data_meta':{
# },
# 'type':"upper",
# 'diag':false,
# 'na_text':"",
# 'shape':5,
# 'label_format':".2f",
# 'size_unit':"x",
# 'size':0.75,
# 'data':{
# '..x..':["displ","displ","displ","displ","displ","year","year","year","year","year","cyl","cyl","cyl","cyl","cyl","cty","cty","cty","cty","cty","hwy","hwy","hwy","hwy","hwy"],
# '..y..':["displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy"],
# '..corr..':[null,0.14784281645020295,0.9302271024198506,-0.7985239689348548,-0.7660200208864677,null,null,0.1222453474355237,-0.0372322908599655,0.0021576430766320123,null,null,null,-0.8057714082675279,-0.7619123538971942,null,null,null,null,0.9559159136495734,null,null,null,null,null],
# '..corr_abs..':[null,0.14784281645020295,0.9302271024198506,0.7985239689348548,0.7660200208864677,null,null,0.1222453474355237,0.0372322908599655,0.0021576430766320123,null,null,null,0.8057714082675279,0.7619123538971942,null,null,null,null,0.9559159136495734,null,null,null,null,null]
# }
# },{
# 'geom':"text",
# 'stat':"corr",
# 'mapping':{
# },
# 'sampling':"none",
# 'tooltips':{
# 'tooltip_formats':[{
# 'field':"@..corr..",
# 'format':".1f"
# }],
# 'tooltip_lines':["@..corr.."]
# },
# 'data_meta':{
# },
# 'type':"upper",
# 'diag':false,
# 'na_text':"",
# 'label_format':".1f",
# 'size_unit':"x",
# 'size':0.75,
# 'data':{
# '..x..':["displ","displ","displ","displ","displ","year","year","year","year","year","cyl","cyl","cyl","cyl","cyl","cty","cty","cty","cty","cty","hwy","hwy","hwy","hwy","hwy"],
# '..y..':["displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy"],
# '..corr..':[null,0.14784281645020295,0.9302271024198506,-0.7985239689348548,-0.7660200208864677,null,null,0.1222453474355237,-0.0372322908599655,0.0021576430766320123,null,null,null,-0.8057714082675279,-0.7619123538971942,null,null,null,null,0.9559159136495734,null,null,null,null,null]
# }
# },{
# 'geom':"tile",
# 'stat':"corr",
# 'mapping':{
# },
# 'sampling':"none",
# 'tooltips':{
# 'tooltip_formats':[{
# 'field':"@..corr..",
# 'format':".2f"
# }],
# 'tooltip_lines':["@..corr.."]
# },
# 'data_meta':{
# },
# 'type':"lower",
# 'diag':true,
# 'threshold':0.8,
# 'na_text':"",
# 'label_format':".2f",
# 'data':{
# '..x..':["displ","displ","displ","displ","displ","year","year","year","year","year","cyl","cyl","cyl","cyl","cyl","cty","cty","cty","cty","cty","hwy","hwy","hwy","hwy","hwy"],
# '..y..':["displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy"],
# '..corr..':[1.0,null,null,null,null,null,1.0,null,null,null,0.9302271024198506,null,1.0,null,null,null,null,-0.8057714082675279,1.0,null,null,null,null,0.9559159136495734,1.0],
# '..corr_abs..':[1.0,null,null,null,null,null,1.0,null,null,null,0.9302271024198506,null,1.0,null,null,null,null,0.8057714082675279,1.0,null,null,null,null,0.9559159136495734,1.0]
# }
# },{
# 'geom':"text",
# 'stat':"corr",
# 'mapping':{
# },
# 'sampling':"none",
# 'tooltips':{
# 'tooltip_formats':[{
# 'field':"@..corr..",
# 'format':".1f"
# }],
# 'tooltip_lines':["@..corr.."]
# },
# 'data_meta':{
# },
# 'type':"lower",
# 'diag':true,
# 'threshold':0.8,
# 'na_text':"",
# 'label_format':".1f",
# 'size':1.2,
# 'color':"white",
# 'size_unit':"x",
# 'data':{
# '..x..':["displ","displ","displ","displ","displ","year","year","year","year","year","cyl","cyl","cyl","cyl","cyl","cty","cty","cty","cty","cty","hwy","hwy","hwy","hwy","hwy"],
# '..y..':["displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy","displ","year","cyl","cty","hwy"],
# '..corr..':[1.0,null,null,null,null,null,1.0,null,null,null,0.9302271024198506,null,1.0,null,null,null,null,-0.8057714082675279,1.0,null,null,null,null,0.9559159136495734,1.0]
# }
# }]
# }
# }]
# };
#            var plotContainer = document.getElementById("nmXxkZ");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
