# %%
from lets_plot import *

load_lets_plot_js()
# Out:
#             <div id="IdpJVZ"></div>
#             <script type="text/javascript">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://dl.bintray.com/jetbrains/lets-plot/lets-plot-1.0.0rc1.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#             var div = document.createElement("div");
#             div.style.color = 'darkblue';
#             div.textContent = 'Lets-Plot JS successfully loaded.';
#             document.getElementById("IdpJVZ").appendChild(div);
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("IdpJVZ").appendChild(div);
#                     };
#                     var e = document.getElementById("IdpJVZ");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
# This example was found at: http://www.cookbook-r.com/Graphs/Plotting_means_and_error_bars_(ggplot2)
length = [13.23, 22.70, 26.06, 7.98, 16.77, 26.14]
se = [2.4, 1.9, 2.05, 2.74, 1.51, 1.79]
data = dict(
    supp = ['OJ', 'OJ', 'OJ', 'VC', 'VC', 'VC'],
    dose = [0.5, 1.0, 2.0, 0.5, 1.0, 2.0],
    len = length,
    se = se)

ymin = [y - e for y, e in zip(length, se)]
ymax = [y + e for y, e in zip(length, se)]

# %%
p = ggplot(data, aes(x='dose', y='len', color='supp'))

# %%
p + geom_errorbar(aes(ymin=ymin, ymax=ymax), width=.1) \
+ geom_line() \
+ geom_point()
# Out:
#             <div id="plot_output_dQ3JyT"></div>
#             <script type="text/javascript">
#                 (function() {
#                     var plotSpec={
# 'data':{
# 'supp':["OJ","OJ","OJ","VC","VC","VC"],
# 'dose':[0.5,1.0,2.0,0.5,1.0,2.0],
# 'len':[13.23,22.7,26.06,7.98,16.77,26.14]
# },
# 'mapping':{
# 'x':"dose",
# 'y':"len",
# 'color':"supp"
# },
# 'kind':"plot",
# 'scales':[],
# 'layers':[{
# 'geom':"errorbar",
# 'mapping':{
# 'ymin':"ymin",
# 'ymax':"ymax"
# },
# 'width':0.1,
# 'data':{
# 'ymin':[10.83,20.8,24.009999999999998,5.24,15.26,24.35],
# 'ymax':[15.63,24.599999999999998,28.11,10.72,18.28,27.93]
# }
# },{
# 'geom':"line",
# 'data':{
# }
# },{
# 'geom':"point",
# 'data':{
# }
# }]
# };
#                     var plotContainer = document.getElementById("plot_output_dQ3JyT");
#                     window.letsPlotCall(function() {{
#                         LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#                     }});
#                 })();
#             </script>

# %%
# The errorbars overlapped, so use position_dodge to move them horizontally
pd = position_dodge(0.1) # move them .05 to the left and right
p + geom_errorbar(aes(ymin=ymin, ymax=ymax), width=.1, position=pd) \
+ geom_line(position=pd) \
+ geom_point(position=pd)
# Out:
#             <div id="plot_output_9OMV3q"></div>
#             <script type="text/javascript">
#                 (function() {
#                     var plotSpec={
# 'data':{
# 'supp':["OJ","OJ","OJ","VC","VC","VC"],
# 'dose':[0.5,1.0,2.0,0.5,1.0,2.0],
# 'len':[13.23,22.7,26.06,7.98,16.77,26.14]
# },
# 'mapping':{
# 'x':"dose",
# 'y':"len",
# 'color':"supp"
# },
# 'kind':"plot",
# 'scales':[],
# 'layers':[{
# 'geom':"errorbar",
# 'mapping':{
# 'ymin':"ymin",
# 'ymax':"ymax"
# },
# 'position':{
# 'name':"dodge",
# 'width':0.1
# },
# 'width':0.1,
# 'data':{
# 'ymin':[10.83,20.8,24.009999999999998,5.24,15.26,24.35],
# 'ymax':[15.63,24.599999999999998,28.11,10.72,18.28,27.93]
# }
# },{
# 'geom':"line",
# 'position':{
# 'name':"dodge",
# 'width':0.1
# },
# 'data':{
# }
# },{
# 'geom':"point",
# 'position':{
# 'name':"dodge",
# 'width':0.1
# },
# 'data':{
# }
# }]
# };
#                     var plotContainer = document.getElementById("plot_output_9OMV3q");
#                     window.letsPlotCall(function() {{
#                         LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#                     }});
#                 })();
#             </script>

# %%
# Black errorbars - notice the mapping of 'group=supp'
# Without it, the errorbars won't be dodged!
p + geom_errorbar(aes(ymin=ymin, ymax=ymax, group='supp'), color='black', width=.1, position=pd) \
+ geom_line(position=pd) \
+ geom_point(position=pd, size=5)
# Out:
#             <div id="plot_output_iOeNfc"></div>
#             <script type="text/javascript">
#                 (function() {
#                     var plotSpec={
# 'data':{
# 'supp':["OJ","OJ","OJ","VC","VC","VC"],
# 'dose':[0.5,1.0,2.0,0.5,1.0,2.0],
# 'len':[13.23,22.7,26.06,7.98,16.77,26.14]
# },
# 'mapping':{
# 'x':"dose",
# 'y':"len",
# 'color':"supp"
# },
# 'kind':"plot",
# 'scales':[],
# 'layers':[{
# 'geom':"errorbar",
# 'mapping':{
# 'ymin':"ymin",
# 'ymax':"ymax",
# 'group':"supp"
# },
# 'position':{
# 'name':"dodge",
# 'width':0.1
# },
# 'color':"black",
# 'width':0.1,
# 'data':{
# 'ymin':[10.83,20.8,24.009999999999998,5.24,15.26,24.35],
# 'ymax':[15.63,24.599999999999998,28.11,10.72,18.28,27.93]
# }
# },{
# 'geom':"line",
# 'position':{
# 'name':"dodge",
# 'width':0.1
# },
# 'data':{
# }
# },{
# 'geom':"point",
# 'position':{
# 'name':"dodge",
# 'width':0.1
# },
# 'size':5,
# 'data':{
# }
# }]
# };
#                     var plotContainer = document.getElementById("plot_output_iOeNfc");
#                     window.letsPlotCall(function() {{
#                         LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#                     }});
#                 })();
#             </script>

# %%
# Finished graph
# - fixed size
# - point shape # 21 is filled circle 
# - position legend in bottom right
p1 = p + ggtitle("The Effect of Vitamin C on Tooth Growth in Guinea Pigs") \
+ xlab("Dose (mg)") \
+ ylab("Tooth length (mm)") \
+ scale_color_manual(['orange', 'dark_green'], na_value='gray') \
+ ggsize(700, 400)
p1 + geom_errorbar(aes(ymin=ymin, ymax=ymax, group='supp'), color='black', width=.1, position=pd) \
+ geom_line(position=pd) \
+ geom_point(position=pd, size=5, shape=21, fill="white") \
+ theme(legend_justification=[1,0], legend_position=[1,0])
# Out:
#             <div id="plot_output_VAJxN2"></div>
#             <script type="text/javascript">
#                 (function() {
#                     var plotSpec={
# 'data':{
# 'supp':["OJ","OJ","OJ","VC","VC","VC"],
# 'dose':[0.5,1.0,2.0,0.5,1.0,2.0],
# 'len':[13.23,22.7,26.06,7.98,16.77,26.14]
# },
# 'mapping':{
# 'x':"dose",
# 'y':"len",
# 'color':"supp"
# },
# 'ggtitle':{
# 'text':"The Effect of Vitamin C on Tooth Growth in Guinea Pigs"
# },
# 'ggsize':{
# 'width':700,
# 'height':400
# },
# 'theme':{
# 'legend_position':[1,0],
# 'legend_justification':[1,0]
# },
# 'kind':"plot",
# 'scales':[{
# 'name':"Dose (mg)",
# 'aesthetic':"x"
# },{
# 'name':"Tooth length (mm)",
# 'aesthetic':"y"
# },{
# 'aesthetic':"color",
# 'na_value':"gray",
# 'values':["orange","dark_green"]
# }],
# 'layers':[{
# 'geom':"errorbar",
# 'mapping':{
# 'ymin':"ymin",
# 'ymax':"ymax",
# 'group':"supp"
# },
# 'position':{
# 'name':"dodge",
# 'width':0.1
# },
# 'color':"black",
# 'width':0.1,
# 'data':{
# 'ymin':[10.83,20.8,24.009999999999998,5.24,15.26,24.35],
# 'ymax':[15.63,24.599999999999998,28.11,10.72,18.28,27.93]
# }
# },{
# 'geom':"line",
# 'position':{
# 'name':"dodge",
# 'width':0.1
# },
# 'data':{
# }
# },{
# 'geom':"point",
# 'position':{
# 'name':"dodge",
# 'width':0.1
# },
# 'size':5,
# 'shape':21,
# 'fill':"white",
# 'data':{
# }
# }]
# };
#                     var plotContainer = document.getElementById("plot_output_VAJxN2");
#                     window.letsPlotCall(function() {{
#                         LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#                     }});
#                 })();
#             </script>

# %%
# Presend the same data on Bar plot
p1 \
+ geom_bar(aes(fill='supp'), stat='identity', position='dodge', color='black') \
+ geom_errorbar(aes(ymin=ymin, ymax=ymax, group='supp'), color='black', width=.1, position=position_dodge(0.9)) \
+ theme(legend_justification=[0,1], legend_position=[0,1])
# Out:
#             <div id="plot_output_mG1g86"></div>
#             <script type="text/javascript">
#                 (function() {
#                     var plotSpec={
# 'data':{
# 'supp':["OJ","OJ","OJ","VC","VC","VC"],
# 'dose':[0.5,1.0,2.0,0.5,1.0,2.0],
# 'len':[13.23,22.7,26.06,7.98,16.77,26.14]
# },
# 'mapping':{
# 'x':"dose",
# 'y':"len",
# 'color':"supp"
# },
# 'ggtitle':{
# 'text':"The Effect of Vitamin C on Tooth Growth in Guinea Pigs"
# },
# 'ggsize':{
# 'width':700,
# 'height':400
# },
# 'theme':{
# 'legend_position':[0,1],
# 'legend_justification':[0,1]
# },
# 'kind':"plot",
# 'scales':[{
# 'name':"Dose (mg)",
# 'aesthetic':"x"
# },{
# 'name':"Tooth length (mm)",
# 'aesthetic':"y"
# },{
# 'aesthetic':"color",
# 'na_value':"gray",
# 'values':["orange","dark_green"]
# }],
# 'layers':[{
# 'geom':"bar",
# 'stat':"identity",
# 'mapping':{
# 'fill':"supp"
# },
# 'position':"dodge",
# 'color':"black",
# 'data':{
# }
# },{
# 'geom':"errorbar",
# 'mapping':{
# 'ymin':"ymin",
# 'ymax':"ymax",
# 'group':"supp"
# },
# 'position':{
# 'name':"dodge",
# 'width':0.9
# },
# 'color':"black",
# 'width':0.1,
# 'data':{
# 'ymin':[10.83,20.8,24.009999999999998,5.24,15.26,24.35],
# 'ymax':[15.63,24.599999999999998,28.11,10.72,18.28,27.93]
# }
# }]
# };
#                     var plotContainer = document.getElementById("plot_output_mG1g86");
#                     window.letsPlotCall(function() {{
#                         LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#                     }});
#                 })();
#             </script>
