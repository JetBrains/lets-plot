# %%
from datalore_plot import *

# %%
# This example was found at: http://www.cookbook-r.com/Graphs/Plotting_means_and_error_bars_(ggplot2)
length = [13.23, 22.70, 26.06, 7.98, 16.77, 26.14]
se = [2.4, 1.9, 2.05, 2.74, 1.51, 1.79]
data = dict(
    supp = ['OJ', 'OJ', 'OJ', 'VC', 'VC', 'VC'],
    dose = [0.5, 1.0, 2.0, 0.5, 1.0, 2.0],
    len = length,
    se = se)

ymin = [y - e for y, e in zip(length, se)]
ymax = [y + e for y, e in zip(length, se)]

# %%
p = ggplot(data, aes(x='dose', y='len', color='supp'))

# %%
p + geom_errorbar(aes(ymin=ymin, ymax=ymax), width=.1) \
+ geom_line() \
+ geom_point()
# Out:
#                 <script type="text/javascript" src="http://dl.bintray.com/jetbrains/datalore-plot/datalore-plot-0.0.1rc2.min.js"/>
#             <div id="plot_output_qJEeoW"></div>
#             <script type="text/javascript">
#                 var plotSpec={
# 'data':{
# 'supp':["OJ","OJ","OJ","VC","VC","VC"],
# 'dose':[0.5,1.0,2.0,0.5,1.0,2.0],
# 'len':[13.23,22.7,26.06,7.98,16.77,26.14]
# },
# 'mapping':{
# 'x':"dose",
# 'y':"len",
# 'color':"supp"
# },
# 'kind':"plot",
# 'scales':[],
# 'layers':[{
# 'geom':"errorbar",
# 'mapping':{
# 'ymin':"ymin",
# 'ymax':"ymax"
# },
# 'width':0.1,
# 'data':{
# 'ymin':[10.83,20.8,24.009999999999998,5.24,15.26,24.35],
# 'ymax':[15.63,24.599999999999998,28.11,10.72,18.28,27.93]
# }
# },{
# 'geom':"line",
# 'data':{
# }
# },{
# 'geom':"point",
# 'data':{
# }
# }]
# };
#
#                 var plotContainer = document.getElementById("plot_output_qJEeoW");
#                 DatalorePlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#             </script>

# %%
# The errorbars overlapped, so use position_dodge to move them horizontally
pd = position_dodge(0.1) # move them .05 to the left and right
p + geom_errorbar(aes(ymin=ymin, ymax=ymax), width=.1, position=pd) \
+ geom_line(position=pd) \
+ geom_point(position=pd)
# Out:
#             <div id="plot_output_75kDOB"></div>
#             <script type="text/javascript">
#                 var plotSpec={
# 'data':{
# 'supp':["OJ","OJ","OJ","VC","VC","VC"],
# 'dose':[0.5,1.0,2.0,0.5,1.0,2.0],
# 'len':[13.23,22.7,26.06,7.98,16.77,26.14]
# },
# 'mapping':{
# 'x':"dose",
# 'y':"len",
# 'color':"supp"
# },
# 'kind':"plot",
# 'scales':[],
# 'layers':[{
# 'geom':"errorbar",
# 'mapping':{
# 'ymin':"ymin",
# 'ymax':"ymax"
# },
# 'position':{
# 'name':"dodge",
# 'width':0.1
# },
# 'width':0.1,
# 'data':{
# 'ymin':[10.83,20.8,24.009999999999998,5.24,15.26,24.35],
# 'ymax':[15.63,24.599999999999998,28.11,10.72,18.28,27.93]
# }
# },{
# 'geom':"line",
# 'position':{
# 'name':"dodge",
# 'width':0.1
# },
# 'data':{
# }
# },{
# 'geom':"point",
# 'position':{
# 'name':"dodge",
# 'width':0.1
# },
# 'data':{
# }
# }]
# };
#
#                 var plotContainer = document.getElementById("plot_output_75kDOB");
#                 DatalorePlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#             </script>

# %%
# Black errorbars - notice the mapping of 'group=supp'
# Without it, the errorbars won't be dodged!
p + geom_errorbar(aes(ymin=ymin, ymax=ymax, group='supp'), color='black', width=.1, position=pd) \
+ geom_line(position=pd) \
+ geom_point(position=pd, size=5)
# Out:
#             <div id="plot_output_8U1ypz"></div>
#             <script type="text/javascript">
#                 var plotSpec={
# 'data':{
# 'supp':["OJ","OJ","OJ","VC","VC","VC"],
# 'dose':[0.5,1.0,2.0,0.5,1.0,2.0],
# 'len':[13.23,22.7,26.06,7.98,16.77,26.14]
# },
# 'mapping':{
# 'x':"dose",
# 'y':"len",
# 'color':"supp"
# },
# 'kind':"plot",
# 'scales':[],
# 'layers':[{
# 'geom':"errorbar",
# 'mapping':{
# 'ymin':"ymin",
# 'ymax':"ymax",
# 'group':"supp"
# },
# 'position':{
# 'name':"dodge",
# 'width':0.1
# },
# 'color':"black",
# 'width':0.1,
# 'data':{
# 'ymin':[10.83,20.8,24.009999999999998,5.24,15.26,24.35],
# 'ymax':[15.63,24.599999999999998,28.11,10.72,18.28,27.93]
# }
# },{
# 'geom':"line",
# 'position':{
# 'name':"dodge",
# 'width':0.1
# },
# 'data':{
# }
# },{
# 'geom':"point",
# 'position':{
# 'name':"dodge",
# 'width':0.1
# },
# 'size':5,
# 'data':{
# }
# }]
# };
#
#                 var plotContainer = document.getElementById("plot_output_8U1ypz");
#                 DatalorePlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#             </script>

# %%
# Finished graph
# - fixed size
# - point shape # 21 is filled circle 
# - position legend in bottom right
p1 = p + ggtitle("The Effect of Vitamin C on Tooth Growth in Guinea Pigs") \
+ xlab("Dose (mg)") \
+ ylab("Tooth length (mm)") \
+ scale_color_manual(['orange', 'dark_green'], na_value='gray') \
+ ggsize(700, 400)
p1 + geom_errorbar(aes(ymin=ymin, ymax=ymax, group='supp'), color='black', width=.1, position=pd) \
+ geom_line(position=pd) \
+ geom_point(position=pd, size=5, shape=21, fill="white") \
+ theme(legend_justification=[1,0], legend_position=[1,0])
# Out:
#             <div id="plot_output_4EfsUl"></div>
#             <script type="text/javascript">
#                 var plotSpec={
# 'data':{
# 'supp':["OJ","OJ","OJ","VC","VC","VC"],
# 'dose':[0.5,1.0,2.0,0.5,1.0,2.0],
# 'len':[13.23,22.7,26.06,7.98,16.77,26.14]
# },
# 'mapping':{
# 'x':"dose",
# 'y':"len",
# 'color':"supp"
# },
# 'ggtitle':{
# 'text':"The Effect of Vitamin C on Tooth Growth in Guinea Pigs"
# },
# 'ggsize':{
# 'width':700,
# 'height':400
# },
# 'theme':{
# 'legend_position':[1,0],
# 'legend_justification':[1,0]
# },
# 'kind':"plot",
# 'scales':[{
# 'name':"Dose (mg)",
# 'aesthetic':"x"
# },{
# 'name':"Tooth length (mm)",
# 'aesthetic':"y"
# },{
# 'aesthetic':"color",
# 'na_value':"gray",
# 'values':["orange","dark_green"]
# }],
# 'layers':[{
# 'geom':"errorbar",
# 'mapping':{
# 'ymin':"ymin",
# 'ymax':"ymax",
# 'group':"supp"
# },
# 'position':{
# 'name':"dodge",
# 'width':0.1
# },
# 'color':"black",
# 'width':0.1,
# 'data':{
# 'ymin':[10.83,20.8,24.009999999999998,5.24,15.26,24.35],
# 'ymax':[15.63,24.599999999999998,28.11,10.72,18.28,27.93]
# }
# },{
# 'geom':"line",
# 'position':{
# 'name':"dodge",
# 'width':0.1
# },
# 'data':{
# }
# },{
# 'geom':"point",
# 'position':{
# 'name':"dodge",
# 'width':0.1
# },
# 'size':5,
# 'shape':21,
# 'fill':"white",
# 'data':{
# }
# }]
# };
#
#                 var plotContainer = document.getElementById("plot_output_4EfsUl");
#                 DatalorePlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#             </script>

# %%
# Presend the same data on Bar plot
p1 \
+ geom_bar(aes(fill='supp'), stat='identity', position='dodge', color='black') \
+ geom_errorbar(aes(ymin=ymin, ymax=ymax, group='supp'), color='black', width=.1, position=position_dodge(0.9)) \
+ theme(legend_justification=[0,1], legend_position=[0,1])
# Out:
#             <div id="plot_output_LlpKPp"></div>
#             <script type="text/javascript">
#                 var plotSpec={
# 'data':{
# 'supp':["OJ","OJ","OJ","VC","VC","VC"],
# 'dose':[0.5,1.0,2.0,0.5,1.0,2.0],
# 'len':[13.23,22.7,26.06,7.98,16.77,26.14]
# },
# 'mapping':{
# 'x':"dose",
# 'y':"len",
# 'color':"supp"
# },
# 'ggtitle':{
# 'text':"The Effect of Vitamin C on Tooth Growth in Guinea Pigs"
# },
# 'ggsize':{
# 'width':700,
# 'height':400
# },
# 'theme':{
# 'legend_position':[0,1],
# 'legend_justification':[0,1]
# },
# 'kind':"plot",
# 'scales':[{
# 'name':"Dose (mg)",
# 'aesthetic':"x"
# },{
# 'name':"Tooth length (mm)",
# 'aesthetic':"y"
# },{
# 'aesthetic':"color",
# 'na_value':"gray",
# 'values':["orange","dark_green"]
# }],
# 'layers':[{
# 'geom':"bar",
# 'stat':"identity",
# 'mapping':{
# 'fill':"supp"
# },
# 'position':"dodge",
# 'color':"black",
# 'data':{
# }
# },{
# 'geom':"errorbar",
# 'mapping':{
# 'ymin':"ymin",
# 'ymax':"ymax",
# 'group':"supp"
# },
# 'position':{
# 'name':"dodge",
# 'width':0.9
# },
# 'color':"black",
# 'width':0.1,
# 'data':{
# 'ymin':[10.83,20.8,24.009999999999998,5.24,15.26,24.35],
# 'ymax':[15.63,24.599999999999998,28.11,10.72,18.28,27.93]
# }
# }]
# };
#
#                 var plotContainer = document.getElementById("plot_output_LlpKPp");
#                 DatalorePlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#             </script>
