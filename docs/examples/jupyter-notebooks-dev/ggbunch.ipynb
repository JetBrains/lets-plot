# %% [markdown]
# <em><sub>This page is available as an executable or viewable <strong>Jupyter Notebook</strong>:</sub></em>
# <br/><br/>
# <a href="https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/501"
#    target="_parent">
#    <img align="left"
#         src="https://mybinder.org/badge_logo.svg">
# </a>
# <a href="https://nbviewer.jupyter.org/github/JetBrains/lets-plot/blob/master/docs/examples/jupyter-notebooks-dev/ggbunch.ipynb"
#    target="_parent">
#    <img align="right"
#         src="https://raw.githubusercontent.com/jupyter/design/master/logos/Badges/nbviewer_badge.png"
#         width="109" height="20">
# </a>
# <br/>
# <br/>
#
# # GGBunch
#
# *GGBunch* allows to show a collection of plots on one figure. Each plot in the collection can have arbitrary location and size. Where is no automatic layot inside the bunch.

# %%
import numpy as np
from lets_plot import *
load_lets_plot_js()
# Out:
#             <div id="yaE0jI"></div>
#             <script type="text/javascript">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://dl.bintray.com/jetbrains/lets-plot/lets-plot-1.1.0rc1.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#             var div = document.createElement("div");
#             div.style.color = 'darkblue';
#             div.textContent = 'Lets-Plot JS successfully loaded.';
#             document.getElementById("yaE0jI").appendChild(div);
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("yaE0jI").appendChild(div);
#                     };
#                     var e = document.getElementById("yaE0jI");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
cov=[[1, 0], 
     [0, 1]]     
x, y = np.random.multivariate_normal(mean=[0,0], cov=cov, size=400).T

data = dict(
    x = x,
    y = y
)

# %% [markdown]
# ### View this data as a scatter plot and as a histogram

# %%
p = ggplot(data) + ggsize(600,200)

scatter = p + geom_point(aes('x', 'y'), color='black', alpha=.4)
scatter
# Out:
#             <div id="plot_output_ANLyoF"></div>
#             <script type="text/javascript">
#                 (function() {
#                     var plotSpec={
# 'data':{
# 'x':[-0.18716518060056878,2.0729262746169344,-0.7644364339296329,0.047212166558487395,-0.87952962121343,0.12499180171913547,-0.5580758070098114,-0.5283291777151379,-0.1946804690110207,1.381121415941895,-0.6318820441177786,-0.23672066425638347,0.7764175765824392,0.4484739743819607,0.023117867649094456,0.06763266021897056,1.2119775249177493,-1.2359654668587825,0.2985571735215883,-1.1159184906802142,-0.19076255516928606,-0.24975374042694387,-0.3544382392576964,0.8410620470448921,-2.3419541875687373,0.702808004450291,-0.5525279778403908,1.3686198764210258,1.205296362347145,0.6973796485916229,1.4276780082983938,-0.18650527978289644,0.8887974915221792,0.22365492934330702,1.3509942232284964,-1.364025964763441,1.9132569772136967,0.44417913915449525,1.8097827248407532,-2.7052792178874667,-0.38469233361554706,0.902985435955286,-1.7090159128476214,0.27442247179085066,-1.306846488354004,-0.3294411346323956,0.5245765839677878,0.3324816558224547,-0.8500850772157951,0.4326560842019301,2.3055083060461206,-0.37099097140622334,0.7842172087779763,0.1877778096677521,-0.11882793069490312,0.14261587770005826,0.5765259272477529,-1.7555136673821716,1.6362039515321432,0.3105591509467688,1.3224964028783623,0.788779257545149,-1.2901846360689695,-2.842099112021632,-0.6411430256249921,-0.5830254690132946,-0.5875153230011929,-1.2264895783420824,-0.9321767950741974,-0.19583869478155577,-0.460420126992057,0.0777518406466359,-1.4226203771052537,1.2042841689920032,1.3505924807789589,-0.
# '..count..':[1.0,1.0,3.0,3.0,3.0,6.0,9.0,14.0,19.0,12.0,25.0,35.0,24.0,32.0,35.0,30.0,27.0,25.0,25.0,12.0,23.0,12.0,9.0,5.0,3.0,5.0,1.0,0.0,0.0,1.0],
# 'x':[-2.877306655585949,-2.668718567299242,-2.4601304790125353,-2.2515423907258283,-2.0429543024391217,-1.8343662141524146,-1.6257781258657078,-1.417190037579001,-1.2086019492922941,-1.0000138610055873,-0.7914257727188803,-0.5828376844321737,-0.3742495961454666,-0.16566150785876,0.04292658042794706,0.25151466871465367,0.4601027570013607,0.6686908452880678,0.8772789335747744,1.0858670218614814,1.2944551101481885,1.503043198434895,1.7116312867216017,1.9202193750083083,2.128807463295016,2.3373955515817224,2.545983639868429,2.7545717281551365,2.963159816441843,3.1717479047285497]
# }
# }]
# };
#                     var plotContainer = document.getElementById("plot_output_5wkHhV");
#                     window.letsPlotCall(function() {{
#                         LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#                     }});
#                 })();
#             </script>

# %% [markdown]
# ### Combine both plots in one figure

# %%
bunch = GGBunch()
bunch.add_plot(histogram, 0, 0)
bunch.add_plot(scatter, 0, 200)
bunch
# Out:
#             <div id="plot_output_wGfnS5"></div>
#             <script type="text/javascript">
#                 (function() {
#                     var plotSpec={
# 'kind':"ggbunch",
# 'items':[{
# 'x':0,
# 'y':0,
# 'width':null,
# 'height':null,
# 'feature_spec':{
# 'data':{
# },
# 'ggsize':{
# 'width':600,
# 'height':200
# },
# 'kind':"plot",
# 'scales':[],
# 'layers':[{
# 'geom':"histogram",
# 'mapping':{
# 'x':"x",
# 'y':"..count.."
# },
# 'fill':"dark_magenta",
# 'data':{
# '..count..':[1.0,1.0,3.0,3.0,3.0,6.0,9.0,14.0,19.0,12.0,25.0,35.0,24.0,32.0,35.0,30.0,27.0,25.0,25.0,12.0,23.0,12.0,9.0,5.0,3.0,5.0,1.0,0.0,0.0,1.0],
# 'x':[-2.877306655585949,-2.668718567299242,-2.4601304790125353,-2.2515423907258283,-2.0429543024391217,-1.8343662141524146,-1.6257781258657078,-1.417190037579001,-1.2086019492922941,-1.0000138610055873,-0.7914257727188803,-0.5828376844321737,-0.3742495961454666,-0.16566150785876,0.04292658042794706,0.25151466871465367,0.4601027570013607,0.6686908452880678,0.8772789335747744,1.0858670218614814,1.2944551101481885,1.503043198434895,1.7116312867216017,1.9202193750083083,2.128807463295016,2.3373955515817224,2.545983639868429,2.7545717281551365,2.963159816441843,3.1717479047285497]
# }
# }]
# }
# },{
# 'x':0,
# 'y':200,
# 'width':null,
# 'height':null,
# 'feature_spec':{
# 'data':{
# 'x':[-0.18716518060056878,2.0729262746169344,-0.7644364339296329,0.047212166558487395,-0.87952962121343,0.12499180171913547,-0.5580758070098114,-0.5283291777151379,-0.1946804690110207,1.381121415941895,-0.6318820441177786,-0.23672066425638347,0.7764175765824392,0.4484739743819607,0.023117867649094456,0.06763266021897056,1.2119775249177493,-1.2359654668587825,0.2985571735215883,-1.1159184906802142,-0.19076255516928606,-0.24975374042694387,-0.3
072072,-0.5782572634130898,-0.3161353514354302,1.0872328544036298,-0.768000548307217,-0.01807023408638593,1.3148785961372613,-0.3976287361483873,0.6018769301002627,-0.6623788547061259,0.2983464325087052,3.1365403611642324,-0.5882995008250923,-0.7299365446428067,0.33605381917297944,1.6923775429826027,0.4915037696076482,-0.9099768547839963,0.3898530978049455,2.272281260252975,-0.8718647785371528,-0.24164421471542316,-0.8083643910741292,-0.958 ...

# %% [markdown]
# ### Adjust visuals of the bunch figure

# %%
upper_theme = theme(axis_title_x='blank', axis_line='blank')
lower_theme = theme(axis_text_x='blank', axis_ticks_x='blank', axis_line='blank')

# %%
bunch1 = GGBunch()
bunch1.add_plot(histogram + upper_theme, 0, 0)
bunch1.add_plot(scatter + lower_theme, 0, 200)
bunch1
# Out:
#             <div id="plot_output_hD5NIg"></div>
#             <script type="text/javascript">
#                 (function() {
#                     var plotSpec={
# 'kind':"ggbunch",
# 'items':[{
# 'x':0,
# 'y':0,
# 'width':null,
# 'height':null,
# 'feature_spec':{
# 'data':{
# },
# 'ggsize':{
# 'width':600,
# 'height':200
# },
# 'theme':{
# 'axis_title_x':"blank",
# 'axis_line':"blank"
# },
# 'kind':"plot",
# 'scales':[],
# 'layers':[{
# 'geom':"histogram",
# 'mapping':{
# 'x':"x",
# 'y':"..count.."
# },
# 'fill':"dark_magenta",
# 'data':{
# '..count..':[1.0,1.0,3.0,3.0,3.0,6.0,9.0,14.0,19.0,12.0,25.0,35.0,24.0,32.0,35.0,30.0,27.0,25.0,25.0,12.0,23.0,12.0,9.0,5.0,3.0,5.0,1.0,0.0,0.0,1.0],
# 'x':[-2.877306655585949,-2.668718567299242,-2.4601304790125353,-2.2515423907258283,-2.0429543024391217,-1.8343662141524146,-1.6257781258657078,-1.417190037579001,-1.2086019492922941,-1.0000138610055873,-0.7914257727188803,-0.5828376844321737,-0.3742495961454666,-0.16566150785876,0.04292658042794706,0.25151466871465367,0.4601027570013607,0.6686908452880678,0.8772789335747744,1.0858670218614814,1.2944551101481885,1.503043198434895,1.7116312867216017,1.9202193750083083,2.128807463295016,2.3373955515817224,2.545983639868429,2.7545717281551365,2.963159816441843,3.1717479047285497]
# }
# }]
# }
# },{
# 'x':0,
# 'y':200,
# 'width':null,
# 'height':null,
# 'feature_spec':{
# 'data':{
# 'x':[-0.18716518060056878,2.0729262746169344,-0.7644364339296329,0.047212166558487395,-0.87952962121343,0.12499180171913547,-0.5580758070098114,-0.5283291777151379,-0.1946804690110207,1.381121415941895,-0.6318820441177786,-0.23672066425638347,0.7764175765824392,0.4484739743819607,0.023117867649094456,0.06763266021897056,1.2119775249177493,-1.2359654668587825,0.2985571735215883,-1.1159184906802142,-0.19076255516928606,-0.24975374042694387,-0.3544382392576964,0.8410620470448921,-2.3419541875687373,0.702808004450291,-0.5525279778403908,1.3686198764210258,1.205296362347145,0.6973796485916229,1.4276780082983938,-0.18650527978289644,0.8887974915221792,0.22365492934330702,
# %% [markdown]
# ### Adjust plot sizes
#
# *add_plot()* method has two more (optional) parameters: *width* and *height*.
#
# This values will override plot size earlier defined via *ggsize()* function.

# %%
bunch2 = GGBunch()
bunch2.add_plot(histogram + upper_theme, 0, 0, 600, 100)
bunch2.add_plot(scatter + lower_theme, 0, 100, 600, 300)
bunch2
# Out:
#             <div id="plot_output_PaY6uB"></div>
#             <script type="text/javascript">
#                 (function() {
#                     var plotSpec={
# 'kind':"ggbunch",
# 'items':[{
# 'x':0,
# 'y':0,
# 'width':600,
# 'height':100,
# 'feature_spec':{
# 'data':{
# },
# 'ggsize':{
# 'width':600,
# 'height':200
# },
# 'theme':{
# 'axis_title_x':"blank",
# 'axis_line':"blank"
# },
# 'kind':"plot",
# 'scales':[],
# 'layers':[{
# 'geom':"histogram",
# 'mapping':{
# 'x':"x",
# 'y':"..count.."
# },
# 'fill':"dark_magenta",
# 'data':{
# '..count..':[1.0,1.0,3.0,3.0,3.0,6.0,9.0,14.0,19.0,12.0,25.0,35.0,24.0,32.0,35.0,30.0,27.0,25.0,25.0,12.0,23.0,12.0,9.0,5.0,3.0,5.0,1.0,0.0,0.0,1.0],
# 'x':[-2.877306655585949,-2.668718567299242,-2.4601304790125353,-2.2515423907258283,-2.0429543024391217,-1.8343662141524146,-1.6257781258657078,-1.417190037579001,-1.2086019492922941,-1.0000138610055873,-0.7914257727188803,-0.5828376844321737,-0.3742495961454666,-0.16566150785876,0.04292658042794706,0.25151466871465367,0.4601027570013607,0.6686908452880678,0.8772789335747744,1.0858670218614814,1.2944551101481885,1.503043198434895,1.7116312867216017,1.9202193750083083,2.128807463295016,2.3373955515817224,2.545983639868429,2.7545717281551365,2.963159816441843,3.1717479047285497]
# }
# }]
# }
# },{
# 'x':0,
# 'y':100,
# 'width':600,
# 'height':300,
# 'feature_spec':{
# 'data':{
# 'x':[-0.18716518060056878,2.0729262746169344,-0.7644364339296329,0.047212166558487395,-0.87952962121343,0.12499180171913547,-0.5580758070098114,-0.5283291777151379,-0.1946804690110207,1.381121415941895,-0.6318820441177786,-0.23672066425638347,0.7764175765824392,0.4484739743819607,0.023117867649094456,0.06763266021897056,1.2119775249177493,-1.2359654668587825,0.2985571735215883,-1.1159184906802142,-0.19076255516928606,-0.24975374042694387,-0.3544382392576964,0.8410620470448921,-2.3419541875687373,0.702808004450291,-0.5525279778403908,1.3686198764210258,1.205296362347145,0.6973796485916229,1.4276780082983938,-0.18650527978289644,0.8887974915221792,0.22365492934330702,1.3509942232284964,-1.364025964763441,1.9132569772136967,0.44417913915449525,1.8097827248407532,-2.7052792178874667,-0.38469233361554706,0.902985435955286,-1.7090159128476214,0.27442247179085066,-1.306846488354004,-0.3294411346323956,0.