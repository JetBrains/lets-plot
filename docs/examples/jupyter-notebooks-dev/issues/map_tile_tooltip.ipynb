# %%
from lets_plot import *
from lets_plot.geo_data import *

LetsPlot.setup_html()
# Out:
#             <div id="sGVI4i"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://dl.bintray.com/jetbrains/lets-plot/lets-plot-2.0.0rc2.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("sGVI4i").appendChild(div);
#                     };
#                     var e = document.getElementById("sGVI4i");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
import lets_plot
lets_plot.__version__
# Out:
# '2.0.0rc2'

# %%
city = geocode_cities("Boston")

# %%
city.get_centroids()
# Out:
#      city found name                    geometry
# 0  Boston     Boston  POINT (-71.08845 42.31104)

# %%
ggplot() + geom_tile(x=-71.08845, y=42.31104, tooltips=layer_tooltips().line("Some info"))
# Out:
#    <div id="aGavZB"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# 'mapping':{
# },
# 'data_meta':{
# },
# 'kind':"plot",
# 'scales':[],
# 'layers':[{
# 'geom':"tile",
# 'mapping':{
# },
# 'tooltips':{
# 'tooltip_formats':[],
# 'tooltip_lines':["Some info"]
# },
# 'data_meta':{
# },
# 'x':-71.08845,
# 'y':42.31104,
# 'data':{
# }
# }]
# };
#            var plotContainer = document.getElementById("aGavZB");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
(ggplot() + 
 geom_tile(x=-71.08845, y=42.31104, tooltips=layer_tooltips().line("Some info")) + 
 geom_map(map=geocode_states("Massachusetts")))
# Out:
#    <div id="3HXepW"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# 'mapping':{
# },
# 'data_meta':{
# },
# 'kind':"plot",
# 'scales':[],
# 'layers':[{
# 'geom':"tile",
# 'mapping':{
# },
# 'tooltips':{
# 'tooltip_formats':[],
# 'tooltip_lines':["Some info"]
# },
# 'data_meta':{
# },
# 'x':-71.08845,
# 'y':42.31104,
# 'data':{
# }
# },{
# 'geom':"map",
# 'mapping':{
# },
# 'data_meta':{
# },
# 'map_data_meta':{
# 'geodataframe':{
# 'geometry':"geometry"
# }
# },
# 'map':{
# 'state':["Massachusetts"],
# 'found name':["Massachusetts"],
# 'geometry':["{\"type\": \"MultiPolygon\", \"coordinates\": [[[[-70.02685546875, 41.3438245811857], [-70.02685546875, 41.3685641368097], [-70.037841796875, 41.3768085657023], [-70.015869140625, 41.3685641368097], [-69.9609375, 41.2860623874982], [-69.9609375, 41.2695495028426], [-69.971923828125, 41.2447723430821], [-70.0048828125, 41.2365112012462], [-70.081787109375, 41.2447723430821], [-70.103759765625, 41.2365112012462], [-70.11474609375, 41.2447723430821], [-70.169677734375, 41.2530324406532], [-70.224609375, 41.2778064673818], [-70.213623046875, 41.2778064673818], [-70.20263671875, 41.2778064673818], [-70.191650390625, 41.2860623874982], [-70.20263671875, 41.2943172631526], [-70.1806640625, 41.2943172631526], [-70.125732421875, 41.2943172631526], [-70.103759765625, 41.2943172631526], [-70.0927734375, 41.2943172631526], [-70.0927734375, 41.2860623874982], [-70.0927734375, 41.2778064673818], [-70.07080078125, 41.2860623874982], [-70.059814453125, 41.2943172631526], [-70.048828125, 41.2943172631526], [-70.037841796875, 41.3025710943056], [-70.02685546875, 41.3025710943056], [-70.02685546875, 41.2943172631526], [-70.015869140625, 41.3025710943056], [-70.037841796875, 41.3190756229514], [-70.015869140625, 41.3190756229514], [-69.993896484375, 41.3273263203662], [-70.0048828125, 41.3355759731239], [-70.015869140625, 41.3438245811857], [-70.015869140625, 41.3520721445129], [-70.02685546875, 41.3438245811857]], [[-70.20263671875, 41.2778064673818], [-70.20263671875, 41.2695495028426], [-70.191650390625, 41.2778064673818], [-70.20263671875, 41.2778064673818]]], [[[-70.565185546875, 41.3603186630671], [-70.55419921875, 41.3520721445129], [-70.64208984375, 41.3438245811857], [-70.72998046875, 41.3355759731239], [-70.740966796875, 41.3355759731239], [-70.762939453125, 41.3190756229514], [-70.77392578125, 41.3025710943056], [-70.806884765625, 41.3190756229514], [-70.83984375, 41.3438245811857], [-70.828857421875, 41.3520721445129], [-70.806884765625, 41.3603186630671], [-70.784912109375, 41.3520721445129], [-70.77392578125, 41.3520721445129], [-70.751953125, 41.3685641368097], [-70.740966796875, 41.3850519497068], [-70.72998046875, 41.4015355828985], [-70.718994140625, 41.4015355828985], [-70.7080078125, 41.4097758320095], [-70.697021484375, 41.4344903089492], [-70.68603515625, 41.4344903089492], [-70.68603515625, 41.4427263776721], [-70.675048828125, 41.4427263776721], [-70.6640625, 41.4591953795071], [-70.64208984375, 41.4591953795071], [-70.59814453125, 41.4838910426717], [-70.59814453125, 41.4674283125442], [-70.59814453125, 41.4591953795071], [-70.59814453125, 41.4509614012039], [-70.587158203125, 41.4591953795071], [-70.565185546875, 41.4674283125442], [-70.55419921875, 41.4591953795071], [-70.55419921875, 41.4509614012039], [-70.55419921875, 41.4344903089492], [-70.565185546875, 41.4344903089492], [-70.565185546875, 41.4262531950727], [-70.55419921875, 41.4180150360802], [-70.565185546875, 41.4097758320095], [-70.55419921875, 41.4097758320095], [-70.543212890625, 41.4097758320095], [-70.543212890625, 41.4015355828985], [-70.5322265625, 41.4097758320095], [-70.521240234375, 41.4015355828985], [-70.51025390625, 41.3932942887849], [-70.51025390625, 41.3850519497068], [-70.499267578125, 41.3850519497068], [-70.48828125, 41.3850519497068], [-70.46630859375, 41.4015355828985], [-70.46630859375, 41.3932942887849], [-70.46630859375, 41.3850519497068], [-70.455322265625, 41.3850519497068], [-70.4443359375, 41.4015355828985], [-70.455322265625, 41.3520721445129], [-70.46630859375, 41.3520721445129], [-70.499267578125, 41.3520721445129], [-70.51025390625, 41.3520721445129], [-70.543212890625, 41.3520721445129], [-70.5322265625, 41.3603186630671], [-70.543212890625, 41.3603186630671], [-70.55419921875, 41.3603186630671], [-70.565185546875, 41.3603186630671]], [[-70.55419921875, 41.3603186630671], [-70.543212890625, 41.3685641368097], [-70.55419921875, 41.3685641368097], [-70.55419921875, 41.3768085657023], [-70.565185546875, 41.38505194970 ...

# %%
(ggplot() + 
 geom_livemap() +
 geom_tile(x=-71.08845, y=42.31104, tooltips=layer_tooltips().line("Some info")))
# Out:
#    <div id="dK5Z7Y"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# 'mapping':{
# },
# 'data_meta':{
# },
# 'kind':"plot",
# 'scales':[],
# 'layers':[{
# 'geom':"livemap",
# 'mapping':{
# },
# 'data_meta':{
# },
# 'tiles':{
# 'kind':"vector_lets_plot",
# 'url':"wss://tiles.datalore.jetbrains.com",
# 'theme':"color",
# 'attribution':"Map: <a href=\"https://github.com/JetBrains/lets-plot\">© Lets-Plot</a>, map data: <a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a>."
# },
# 'geocoding':{
# 'url':"https://geo2.datalore.jetbrains.com"
# },
# 'data':{
# }
# },{
# 'geom':"tile",
# 'mapping':{
# },
# 'tooltips':{
# 'tooltip_formats':[],
# 'tooltip_lines':["Some info"]
# },
# 'data_meta':{
# },
# 'x':-71.08845,
# 'y':42.31104,
# 'data':{
# }
# }]
# };
#            var plotContainer = document.getElementById("dK5Z7Y");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ### issue: tooltip is not shown.

# %%
(ggplot() + 
 geom_livemap() +
 geom_tile(x=-71.08845, y=42.31104, tooltips=layer_tooltips().line("Some info")) + 
 geom_map(map=geocode_states("Massachusetts")))
# Out:
#    <div id="jHzBFd"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# 'mapping':{
# },
# 'data_meta':{
# },
# 'kind':"plot",
# 'scales':[],
# 'layers':[{
# 'geom':"livemap",
# 'mapping':{
# },
# 'data_meta':{
# },
# 'tiles':{
# 'kind':"vector_lets_plot",
# 'url':"wss://tiles.datalore.jetbrains.com",
# 'theme':"color",
# 'attribution':"Map: <a href=\"https://github.com/JetBrains/lets-plot\">© Lets-Plot</a>, map data: <a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a>."
# },
# 'geocoding':{
# 'url':"https://geo2.datalore.jetbrains.com"
# },
# 'data':{
# }
# },{
# 'geom':"tile",
# 'mapping':{
# },
# 'tooltips':{
# 'tooltip_formats':[],
# 'tooltip_lines':["Some info"]
# },
# 'data_meta':{
# },
# 'x':-71.08845,
# 'y':42.31104,
# 'data':{
# }
# },{
# 'geom':"map",
# 'mapping':{
# },
# 'data_meta':{
# },
# 'map_data_meta':{
# 'geodataframe':{
# 'geometry':"geometry"
# }
# },
# 'map':{
# 'state':["Massachusetts"],
# 'found name':["Massachusetts"],
# 'geometry':["{\"type\": \"MultiPolygon\", \"coordinates\": [[[[-70.02685546875, 41.3438245811857], [-70.02685546875, 41.3685641368097], [-70.037841796875, 41.3768085657023], [-70.015869140625, 41.3685641368097], [-69.9609375, 41.2860623874982], [-69.9609375, 41.2695495028426], [-69.971923828125, 41.2447723430821], [-70.0048828125, 41.2365112012462], [-70.081787109375, 41.2447723430821], [-70.103759765625, 41.2365112012462], [-70.11474609375, 41