# %%
import pandas as pd
import geopandas as gpd
import scipy.stats as ss
from pyproj import Proj, transform
from shapely.geometry import Point
from lets_plot.plot import *

# %% [markdown]
# # Inset map of Kotlin #

# %% [markdown]
# [The geodata is provided by © OpenStreetMap contributors and is made available here under the Open Database License (ODbL)](https://www.openstreetmap.org/copyright).

# %%
def lonlat_to_xy(lon, lat, proj='epsg:3857'):
    LONLAT_PROJ = 'epsg:4326'
    
    return transform(Proj(init=LONLAT_PROJ), Proj(init=proj), lon, lat)

# %%
DISTRICTS = [ 1114193, 1114252, 1114354, 1114806, 1114809, 337424, 1114895, 363103, 1115082, 1115366, 338636, 368287, 1114905, 367375, 1115367, 338635, 369514, 1114902 ]
KOTLIN_ID = 1115082

# %%
gdf = gpd.read_file('data/spb.shp')

# %%
data = { 'osm_id' : [ ], 'lon' : [ ], 'lat' : [ ] }

for i, row in gdf.iterrows():
    for lon, lat in row['geometry'].exterior.coords:
        osm_id = int(row['OSM_ID'])
        if not osm_id in DISTRICTS:
            continue
        data['osm_id'].append(osm_id)
        data['lon'].append(lon)
        data['lat'].append(lat)

# %%
df = pd.DataFrame(data)
df['x'], df['y'] = lonlat_to_xy(df['lon'].tolist(), df['lat'].tolist())
df_kotlin = df[df['osm_id'] == KOTLIN_ID]

# %%
p1 = ggplot()
p1 += geom_polygon(aes(x='x', y='y'), data=df, color='black', fill='white')
p1 += geom_rect(xmin=df_kotlin['x'].min(), xmax=df_kotlin['x'].max(), ymin=df_kotlin['y'].min(), ymax=df_kotlin['y'].max(), color='red', size=.75, alpha=0)
p1 += theme(axis_title=element_blank(), axis_text=element_blank(), axis_ticks=element_blank(), axis_line=element_blank(), legend_position='none')

# %%
kotlin_polygon = gdf[gdf['OSM_ID'] == KOTLIN_ID]['geometry'].iloc[1]
naval_cathedral_centroid = Point(29.777771, 59.991738)

# %%
VIKINGS_AGE = (793, 1067)
COV = [[0.003, -0.002, 0], [-0.002, 0.003, 0], [0, 0, 1000]]
SIZE = 200

viking_camps = ss.multivariate_normal.rvs(mean=[naval_cathedral_centroid.x, naval_cathedral_centroid.y, (VIKINGS_AGE[0] + VIKINGS_AGE[1]) / 2], cov=COV, size=SIZE)
df_random_viking_camps = pd.DataFrame(viking_camps, columns=['lon', 'lat', 'year'])
df_random_viking_camps['year'] = df_random_viking_camps['year'].astype(int)
df_timely_viking_camps = df_random_viking_camps[df_random_viking_camps.apply(lambda vc: vc['year'] in range(VIKINGS_AGE[0], VIKINGS_AGE[1]), axis=1)]
df_viking_camps = df_timely_viking_camps[df_timely_viking_camps.apply(lambda vc: kotlin_polygon.contains(Point(vc['lon'], vc['lat'])), axis=1)]
df_viking_camps = df_viking_camps.assign(**dict(zip(['x', 'y'], lonlat_to_xy(df_viking_camps['lon'].tolist(), df_viking_camps['lat'].tolist()))))

# %%
p2 = ggplot()
p2 += geom_polygon(aes(x='x', y='y'), data=df_kotlin, color='#31a354', fill='#e5f5e0')
p2 += geom_point(aes(x='x', y='y', color='year'), data=df_viking_camps)
p2 += scale_color_gradient(low='#662506', high='#fec44f', name='Year')
p2 += ggtitle('Viking Camps on Kotlin from %s to %s A.D.' % VIKINGS_AGE)
p2 += theme(axis_title=element_blank(), axis_text=element_blank(), axis_ticks=element_blank(), axis_line=element_blank())

# %%
bunch = GGBunch()
bunch.add_plot(p2, 0, 0, 800, 600)
bunch.add_plot(p1, 600, 0, 200, 150)
bunch.show()
# Out:
#             <div id="plot_output_SWgb7O"></div>
#             <script type="text/javascript">
#                 (function() {
#                     var plotSpec={
# 'kind':"ggbunch",
# 'items':[{
# 'x':0,
# 'y':0,
# 'width':800,
# 'height':600,
# 'feature_spec':{
# 'ggtitle':{
# 'text':"Viking Camps on Kotlin from 793 to 1067 A.D."
# },
# 'theme':{
# 'axis_title':{
# 'name':"blank"
# },
# 'axis_text':{
# 'name':"blank"
# },
# 'axis_ticks':{
# 'name':"blank"
# },
# 'axis_line':{
# 'name':"blank"
# }
# },
# 'kind':"plot",
# 'scales':[{
# 'name':"Year",
# 'aesthetic':"color",
# 'low':"#662506",
# 'high':"#fec44f",
# 'scale_mapper_kind':"color_gradient"
# }],
# 'layers':[{
# 'geom':"polygon",
# 'data':{
# 'x':[3311807.9171011494,3311830.9936315916,3311827.832158053,3311949.949639453,3311960.447067435,3311966.2134170583,3311973.983517515,3311987.508835647,3311999.8875630223,3312014.5372080114,3312025.4576500584,3312038.8048570044,3312047.2762702536,3312051.528674802,3312054.322794021,3312055.2133499472,3312053.3209186033,3312047.309666101,3312037.9031691286,3312027.7174357213,3312010.3404632085,3311996.458922707,3311982.299083478,3311968.339619332,3311956.2169267847,3311946.710242271,3311938.0941136833,3311551.0473761447,3311555.689398911,3311504.5380928908,3311444.7038665893,3311451.1826609536,3311327.1393523626,3311312.734610254,3311313.435923046,3311197.463277538,3311186.2979326113,3311177.5370886857,3311166.906077315,3311162.520089378,3311115.888354685,3311121.754891849,3311128.7457558713,3311151.5773834325,3311167.785501292,3311175.633525393,3311184.3721054206,3311204.7992319805,3311211.188970752,3311219.0926545984,3311227.931422168,3311247.746291529,3311244.1951997727,3311280.1625272483,3311267.4721052973,3311261.449720846,3311258.49975434,3311259.123143488,3311321.2394193513,3311318.244925048,3311313.1019645734,3311316.953618955,3311325.046545936,3311340.3863717676,3311344.115574709,3311354.3569678613,3311396.8476174977,3311579.87912426,3311635.2271750825,3311629.772520033,3311656.500329773,3311774.165031541,3311807.9171011494,3305514.997898295,3305535.5424687588,3305530.766862604,3305545.5723548797,3305627.982173914,3305631.689112957,3305639.9267552765,3305638.7356367246,3305633.358905319,3305623.206567759,3305605.885254992,3305549.757967734,3305337.761129467,3305323.4343110016,3305314.5955434325,3305198.622897925,3305183.2162803984,3305177.728229502,3305180.1104666055,3305153.839066778,3305125.1742978985,3305097.1106542703,3305075.6037286487,3305061.2769101835,3305052.3156911745,3305058.29354783,3305086.3571914593,3305096.0308552096,3305103.6785042267,3305112.962549759,3305363.2087650625,3306041.812380938,3306064.6996682454,3306074.9967211434,3306082.9671966843,3306065.7683353564,3306019.670934219,3305984.560766823,3305942.5153951505,3305863.2113899095,3305801.1062459955,3305716.8819192615,3305675.938610548,3305583.2651344626,3305525.935596704,3305473.3816651003,3305396.281785777,3305360.637284825,3305303.3077470665,3305280.3759319633,3305247.113668114,3305197.019897257,3305082.9842108884,3305042.263541156,3304885.3253230355,3304827.940125532,3304754.8700117753,3304647.8585852752,3304575.244881431,3304514.0970851383,3304461.1980631137,3304365.997634587,3304302.0111912796,3304249.9693293334,3304224.5105617894,3304168.383274531,3304090.437367077,3304072.2032344854,3304062.2067442117,3304024.8701870004,3304000.2685795347,3303976.167909778,3303941.992826105,3303918.2817745656,3303904.0440116934,3303847.3378630835,3303841.994527525,3303835.1595107904,3303821.1109910524,3303806.672853096,3303732.556336126,3303648.443328883,3303575.3175553805,3303518.4666914325,3303443.4596185363,3303358.6230346025,3303340.1996588763,3303323.768902035,3303310.2213200056,3303294.413952313,3303232.998989242,3303200.237663102,3303173.9662632747,3303161.598667847,3303153.060462903,3303139.1900543505,3303081.248259393,3303052.472171023,3303045.8597932695,3303023.139485199,3303010.1930284193,3302999.2391905254,3302982.474475212,3302957.2049508016,3302917.018614625,3302877.1885008197,3302836.6125464253,3302808.971916862,3302771.468380413,3302680.564884231,3302630.5379050686,3302593.535306329,3302549.1633572993,3302495.240195959,3302438.600839043,3302424.2406247305,3302408.2885417007,3302382.5403434797,3302346.7399952402,3302292.371555937,3302250.5933510424,3302213.7354676407,3302158.6768474947,3302111.2324805185,3302062.7417103285,3302008.495722465,3301988.5917975116,3301976.591556404,3301945.500022625,3301890.4970622244,3301859.5391118345,3301824.762902911,3301779.6451132926,3301748.9209338333,3301714.9239613456,3301691.947618446,3301668.403546143,3301615.526788016,3301571.3663460184,3301524.222541667,3301484.392427861,3301457.1859443113,3301436.424 ...
