# %% [markdown]
# # Image Matrix
#
# The `image_matrix()` function arranges a set of images in a grid.
#
# Dimensions of the grid are determined by the shape of the input Numpy 2D array.
#
# Each element of the input 2D array is an 2D or 3D Numpy array itself specifying either a grayscale image (2D array)
# or a color RGB(A) image (3D array).
#
# For more information on image arrays please see the documentation of `geom_imshow()` function.
#
# The `image_matrix()` function uses `geom_imshow()` under the hood, so you may want to check these demos as well:
#
#  - [image_101.ipynb](https://nbviewer.jupyter.org/github/JetBrains/lets-plot/blob/master/docs/examples/jupyter-notebooks/image_101.ipynb)
#  - [image_fisher_boat.ipynb](https://nbviewer.jupyter.org/github/JetBrains/lets-plot/blob/master/docs/examples/jupyter-notebooks/image_fisher_boat.ipynb)

# %%
import numpy as np
from lets_plot import *
from lets_plot.bistro.im import image_matrix

LetsPlot.setup_html()
# Out:
#             <div id="0SiNYY"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v2.5.1rc1/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("0SiNYY").appendChild(div);
#                     };
#                     var e = document.getElementById("0SiNYY");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
# Load image file.
from PIL import Image
import requests
from io import BytesIO

response = requests.get('https://github.com/JetBrains/lets-plot-docs/raw/master/source/examples/cookbook/images/fisher_boat.png')
image = Image.open(BytesIO(response.content))
img = np.asarray(image)
img.shape
# Out:
# (225, 225, 3)

# %% [markdown]
# ### Create 2 x 3 grid of images
#
# Use the same image to fill the array elements.

# %%
M = 2  # rows
N = 3  # columns
X = np.empty([M, N], dtype=object)
X.fill(img)

# %% [markdown]
# ### Display images in 2 x 3 grid

# %%
image_matrix(X)
# Out:
#    <div id="RKlbMe"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"ggbunch",
# "items":[{
# "x":0,
# "y":0,
# "width":225,
# "height":225,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"data:image/png;base64,...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":224.5,
# "ymax":224.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":225,
# "y":0,
# "width":225,
# "height":225,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"data:image/png;base64,...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":224.5,
# "ymax":224.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":450,
# "y":0,
# "width":225,
# "height":225,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"data:image/png;base64,...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":224.5,
# "ymax":224.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":0,
# "y":225,
# "width":225,
# "height":225,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"data:image/png;base64,...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":224.5,
# "ymax":224.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":225,
# "y":225,
# "width":225,
# "height":225,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"data:image/png;base64,...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":224.5,
# "ymax":224.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":450,
# "y":225,
# "width":225,
# "height":225,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"data:image/png;base64,...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":224.5,
# "ymax":224.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# }]
# };
#            var plotContainer = document.getElementById("RKlbMe");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ### Images in the grid can be of different sizes

# %%
# Lets vary size of images in the matrix
X1 = np.empty([M, N], dtype=object)
for row in range(M):
    for col in range(N):
        v = (row + col + 1) * 10
        X1[row][col] = img[v:-v,v:-v,:]

image_matrix(X1)
# Out:
#    <div id="CqEe2G"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"ggbunch",
# "items":[{
# "x":0,
# "y":0,
# "width":205,
# "height":205,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"data:image/png;base64,...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":204.5,
# "ymax":204.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":205,
# "y":0,
# "width":185,
# "height":185,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"data:image/png;base64,...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":184.5,
# "ymax":184.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":410,
# "y":0,
# "width":165,
# "height":165,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"data:image/png;base64,...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":164.5,
# "ymax":164.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":0,
# "y":205,
# "width":185,
# "height":185,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"data:image/png;base64,...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":184.5,
# "ymax":184.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":205,
# "y":205,
# "width":165,
# "height":165,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"data:image/png;base64,...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":164.5,
# "ymax":164.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":410,
# "y":205,
# "width":145,
# "height":145,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"data:image/png;base64,...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":144.5,
# "ymax":144.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# }]
# };
#            var plotContainer = document.getElementById("CqEe2G");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ### Normalization of grayscale image
#
# By default, luminance values in grayscale image will be scaled to [0-255] range using a linear scaler.

# %%
# Generate a grayscale image from an RGB image 
# by selecting only one `R` channel:
img_gs = img[:,:,0]

img_gs.dtype
# Out:
# dtype('uint8')

# %% [markdown]
# For the demo purposes we will reduce the range of data in some of the images.

# %%
def _degrade(grayscale_img:np.ndarray, coef:float):
    vmin = grayscale_img.min()
    vmax = grayscale_img.max()
    middle = vmin + (vmax - vmin) / 2

    rows, cols = grayscale_img.shape
    for row in range(rows):
        for col in range(cols):
            v = float(grayscale_img[row][col])
            v_new = middle + (v - middle) * coef
            grayscale_img[row][col] = int(v_new)

# %% [markdown]
# Now lets fill an 2D array with images, applying the `_degrade()` function on each iteration.
#
# The last image added is the one "degraded" the most.

# %%
X2 = np.empty([M, N], dtype=object)
img_copy = img_gs.copy()
for row in range(M):
    for col in range(N):
        X2[row][col] = img_copy
        img_copy = img_copy.copy()
        _degrade(img_copy, coef=.7)
        print("[{}, {}] data range: [{}-{}]".format(row, col, img_copy.min(), img_copy.max()))
# Out:
# [0, 0] data range: [38-216]
# [0, 1] data range: [64-189]
# [0, 2] data range: [82-170]
# [1, 0] data range: [95-156]
# [1, 1] data range: [104-146]
# [1, 2] data range: [110-139]

# %% [markdown]
# ### Display images in grid with normalization (default)

# %%
image_matrix(X2)
# Out:
#    <div id="9tYhYF"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"ggbunch",
# "items":[{
# "x":0,
# "y":0,
# "width":225,
# "height":225,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"data:image/png;base64,...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":224.5,
# "ymax":224.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":225,
# "y":0,
# "width":225,
# "height":225,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"data:image/png;base64,...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":224.5,
# "ymax":224.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":450,
# "y":0,
# "width":225,
# "height":225,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"data:image/png;base64,...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":224.5,
# "ymax":224.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":0,
# "y":225,
# "width":225,
# "height":225,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"data:image/png;base64,...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":224.5,
# "ymax":224.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":225,
# "y":225,
# "width":225,
# "height":225,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"data:image/png;base64,...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":224.5,
# "ymax":224.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":450,
# "y":225,
# "width":225,
# "height":225,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"data:image/png;base64,...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":224.5,
# "ymax":224.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# }]
# };
#            var plotContainer = document.getElementById("9tYhYF");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ### Display images in grid with NO normalization

# %%
image_matrix(X2, norm=False)
# Out:
#    <div id="WPT91t"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"ggbunch",
# "items":[{
# "x":0,
# "y":0,
# "width":225,
# "height":225,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"data:image/png;base64,...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":224.5,
# "ymax":224.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":225,
# "y":0,
# "width":225,
# "height":225,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"data:image/png;base64,...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":224.5,
# "ymax":224.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":450,
# "y":0,
# "width":225,
# "height":225,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"data:image/png;base64,...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":224.5,
# "ymax":224.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":0,
# "y":225,
# "width":225,
# "height":225,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"data:image/png;base64,...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":224.5,
# "ymax":224.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":225,
# "y":225,
# "width":225,
# "height":225,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"data:image/png;base64,...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":224.5,
# "ymax":224.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":450,
# "y":225,
# "width":225,
# "height":225,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"data:image/png;base64,...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":224.5,
# "ymax":224.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# }]
# };
#            var plotContainer = document.getElementById("WPT91t");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ### Scaling image size
#
# In case the image size is too small or too big to show, the displayed dimentions can be changed using the parameter `scale`.
#
# For example,`digits` dataset from `sklearn` package contains very small 8x8 pictures of digits.

# %%
# Load `digits` form sklearn.
from sklearn.datasets import load_digits
digits_bunch = load_digits()
digits_data = digits_bunch.data

# %%
# Create 4x4 ndarray containing the first 16 digits in from `digits` dataset. 
cols = 4
rows = 4
X4 = np.empty((rows, cols), dtype=object)
for row in range(rows):
    for col in range(cols):
        i = row * cols + col;
        digit_data = digits_data[i]
        digit_img = digit_data.reshape(8, 8)
        X4[row][col] = digit_img

# %%
X4[0][0].shape
# Out:
# (8, 8)

# %%
# NOTE: minimal plot size in Lets-Plot is 50x50 px.
#       thus we actually don't see 8x8 images in their native dimentions here. 
image_matrix(X4)
# Out:
#    <div id="CaLZBh"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"ggbunch",
# "items":[{
# "x":0,
# "y":0,
# "width":50,
# "height":50,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":7.5,
# "ymax":7.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":50,
# "y":0,
# "width":50,
# "height":50,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":7.5,
# "ymax":7.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":100,
# "y":0,
# "width":50,
# "height":50,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":7.5,
# "ymax":7.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":150,
# "y":0,
# "width":50,
# "height":50,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":7.5,
# "ymax":7.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":0,
# "y":50,
# "width":50,
# "height":50,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":7.5,
# "ymax":7.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":50,
# "y":50,
# "width":50,
# "height":50,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":7.5,
# "ymax":7.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":100,
# "y":50,
# "width":50,
# "height":50,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":7.5,
# "ymax":7.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":150,
# "y":50,
# "width":50,
# "height":50,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":7.5,
# "ymax":7.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":0,
# "y":100,
# "width":50,
# "height":50,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":7.5,
# "ymax":7.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":50,
# "y":100,
# "width":50,
# "height":50,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":7.5,
# "ymax":7.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":100,
# "y":100,
# "width":50,
# "height":50,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":7.5,
# "ymax":7.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":150,
# "y":100,
# "width":50,
# "height":50,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":7.5,
# "ymax":7.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":0,
# "y":150,
# "width":50,
# "height":50,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":7.5,
# "ymax":7.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":50,
# "y":150,
# "width":50,
# "height":50,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":7.5,
# "ymax":7.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":100,
# "y":150,
# "width":50,
# "height":50,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":7.5,
# "ymax":7.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":150,
# "y":150,
# "width":50,
# "height":50,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":7.5,
# "ymax":7.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# }]
# };
#            var plotContainer = document.getElementById("CaLZBh");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ### Scale Up
#
# Each digit image is 8x8 px. Multiply by 15 to see 120x120 px images.

# %%
image_matrix(X4, scale=15)
# Out:
#    <div id="EAUV4V"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"ggbunch",
# "items":[{
# "x":0,
# "y":0,
# "width":120,
# "height":120,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":7.5,
# "ymax":7.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":120,
# "y":0,
# "width":120,
# "height":120,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":7.5,
# "ymax":7.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":240,
# "y":0,
# "width":120,
# "height":120,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":7.5,
# "ymax":7.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":360,
# "y":0,
# "width":120,
# "height":120,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":7.5,
# "ymax":7.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":0,
# "y":120,
# "width":120,
# "height":120,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":7.5,
# "ymax":7.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":120,
# "y":120,
# "width":120,
# "height":120,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":7.5,
# "ymax":7.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":240,
# "y":120,
# "width":120,
# "height":120,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":7.5,
# "ymax":7.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":360,
# "y":120,
# "width":120,
# "height":120,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":7.5,
# "ymax":7.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":0,
# "y":240,
# "width":120,
# "height":120,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":7.5,
# "ymax":7.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":120,
# "y":240,
# "width":120,
# "height":120,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":7.5,
# "ymax":7.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":240,
# "y":240,
# "width":120,
# "height":120,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":7.5,
# "ymax":7.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":360,
# "y":240,
# "width":120,
# "height":120,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":7.5,
# "ymax":7.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":0,
# "y":360,
# "width":120,
# "height":120,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":7.5,
# "ymax":7.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":120,
# "y":360,
# "width":120,
# "height":120,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":7.5,
# "ymax":7.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":240,
# "y":360,
# "width":120,
# "height":120,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":7.5,
# "ymax":7.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":360,
# "y":360,
# "width":120,
# "height":120,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":7.5,
# "ymax":7.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# }]
# };
#            var plotContainer = document.getElementById("EAUV4V");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ### Scale Down
#
# Use values < 1. to see smaller images.

# %%
image_matrix(X, scale=.3)
# Out:
#    <div id="MmJkl3"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"ggbunch",
# "items":[{
# "x":0.0,
# "y":0.0,
# "width":67.5,
# "height":67.5,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"data:image/png;base64,...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":224.5,
# "ymax":224.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":67.5,
# "y":0.0,
# "width":67.5,
# "height":67.5,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"data:image/png;base64,...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":224.5,
# "ymax":224.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":135.0,
# "y":0.0,
# "width":67.5,
# "height":67.5,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"data:image/png;base64,...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":224.5,
# "ymax":224.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":0.0,
# "y":67.5,
# "width":67.5,
# "height":67.5,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"data:image/png;base64,...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":224.5,
# "ymax":224.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":67.5,
# "y":67.5,
# "width":67.5,
# "height":67.5,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"data:image/png;base64,...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":224.5,
# "ymax":224.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":135.0,
# "y":67.5,
# "width":67.5,
# "height":67.5,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"data:image/png;base64,...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":224.5,
# "ymax":224.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# }]
# };
#            var plotContainer = document.getElementById("MmJkl3");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ## The `cmap` parameter
#
# Use parameter `cmap` to display grayscale images in pseudo-colors.

# %%
image_matrix(X2, cmap="viridis", norm=False)
# Out:
#    <div id="r20QhC"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"ggbunch",
# "items":[{
# "x":0,
# "y":0,
# "width":225,
# "height":225,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"data:image/png;base64,...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":224.5,
# "ymax":224.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":225,
# "y":0,
# "width":225,
# "height":225,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"data:image/png;base64,...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":224.5,
# "ymax":224.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":450,
# "y":0,
# "width":225,
# "height":225,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"data:image/png;base64,...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":224.5,
# "ymax":224.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":0,
# "y":225,
# "width":225,
# "height":225,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"data:image/png;base64,...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":224.5,
# "ymax":224.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":225,
# "y":225,
# "width":225,
# "height":225,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"data:image/png;base64,...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":224.5,
# "ymax":224.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":450,
# "y":225,
# "width":225,
# "height":225,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"data:image/png;base64,...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":224.5,
# "ymax":224.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# }]
# };
#            var plotContainer = document.getElementById("r20QhC");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
