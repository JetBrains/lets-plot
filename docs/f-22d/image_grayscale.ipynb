# %% [markdown]
# ## Using parameters `norm, vmain, vmax` and `cmap` in `geom_imshow()`
#
# You can use parameters `norm, vmain, vmax` and `cmap` when rendering grayscale images.
#
# A grayscale image is specified by Numpy's 2D array where each element's value
# represents the luminance of corresponding pixel in the image.

# %%
import numpy as np
from lets_plot import *
LetsPlot.setup_html()
# Out:
#             <div id="I1t6Lr"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v2.5.1rc1/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("I1t6Lr").appendChild(div);
#                     };
#                     var e = document.getElementById("I1t6Lr");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
# Generate 2D Numpy arrays. 
# First two arrays both contain float numbers but have different range of values.
# The 3rd array contains int-s.
arr_f0 = np.linspace(.3, .7, 30).reshape(1, -1)
arr_f1 = np.linspace(30., 170., 30).reshape(1, -1)
arr_i = np.linspace(30, 170, 30, dtype=int).reshape(1, -1)

# %%
print("arr_f0: shape {}, data range [{}-{}] {}".format(arr_f0.shape, arr_f0.min(), arr_f0.max(), arr_f0.dtype))
print("arr_f1: shape {}, data range [{}-{}] {}".format(arr_f1.shape, arr_f1.min(), arr_f1.max(), arr_f1.dtype))
print("arr_i : shape {}, data range [{}-{}] {}".format(arr_i.shape, arr_i.min(), arr_i.max(), arr_i.dtype))
# Out:
# arr_f0: shape (1, 30), data range [0.3-0.7] float64
# arr_f1: shape (1, 30), data range [30.0-170.0] float64
# arr_i : shape (1, 30), data range [30-170] int64

# %%
# Setup suitable plot options for the demo.
p = (ggplot() + ggsize(450, 60) + geom_rect(xmin=-0.5, ymin=-0.5, xmax=29.5, ymax=0.5, color="black", alpha=0) + 
coord_cartesian() + theme_classic() + theme(axis="blank"))

# %% [markdown]
# #### Image normalization
#
# By default, `geom_imshow()` applies a linear scaling to transform data values to range [0-255].

# %%
(p + geom_imshow(arr_f0)).show()
(p + geom_imshow(arr_f1)).show()
(p + geom_imshow(arr_i)).show()
# Out:
#    <div id="XZob5M"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":450,
# "height":60
# },
# "coord":{
# "name":"cartesian",
# "flip":false
# },
# "theme":{
# "name":"classic",
# "axis":"blank"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"rect",
# "mapping":{
# },
# "data_meta":{
# },
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":29.5,
# "ymax":0.5,
# "color":"black",
# "alpha":0,
# "data":{
# }
# },{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":29.5,
# "ymax":0.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("XZob5M");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
#    <div id="hgRFmp"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":450,
# "height":60
# },
# "coord":{
# "name":"cartesian",
# "flip":false
# },
# "theme":{
# "name":"classic",
# "axis":"blank"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"rect",
# "mapping":{
# },
# "data_meta":{
# },
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":29.5,
# "ymax":0.5,
# "color":"black",
# "alpha":0,
# "data":{
# }
# },{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":29.5,
# "ymax":0.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("hgRFmp");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
#    <div id="QZzdBM"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":450,
# "height":60
# },
# "coord":{
# "name":"cartesian",
# "flip":false
# },
# "theme":{
# "name":"classic",
# "axis":"blank"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"rect",
# "mapping":{
# },
# "data_meta":{
# },
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":29.5,
# "ymax":0.5,
# "color":"black",
# "alpha":0,
# "data":{
# }
# },{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":29.5,
# "ymax":0.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("QZzdBM");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ##
#
# You can disable image normalization using the `norm` parameter.

# %%
(p + geom_imshow(arr_f0, norm=False)).show()
(p + geom_imshow(arr_f1, norm=False)).show()
(p + geom_imshow(arr_i, norm=False)).show()
# Out:
#    <div id="98Epba"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":450,
# "height":60
# },
# "coord":{
# "name":"cartesian",
# "flip":false
# },
# "theme":{
# "name":"classic",
# "axis":"blank"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"rect",
# "mapping":{
# },
# "data_meta":{
# },
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":29.5,
# "ymax":0.5,
# "color":"black",
# "alpha":0,
# "data":{
# }
# },{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":29.5,
# "ymax":0.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("98Epba");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
#    <div id="bWMvos"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":450,
# "height":60
# },
# "coord":{
# "name":"cartesian",
# "flip":false
# },
# "theme":{
# "name":"classic",
# "axis":"blank"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"rect",
# "mapping":{
# },
# "data_meta":{
# },
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":29.5,
# "ymax":0.5,
# "color":"black",
# "alpha":0,
# "data":{
# }
# },{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":29.5,
# "ymax":0.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("bWMvos");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
#    <div id="rb2vEZ"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":450,
# "height":60
# },
# "coord":{
# "name":"cartesian",
# "flip":false
# },
# "theme":{
# "name":"classic",
# "axis":"blank"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"rect",
# "mapping":{
# },
# "data_meta":{
# },
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":29.5,
# "ymax":0.5,
# "color":"black",
# "alpha":0,
# "data":{
# }
# },{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":29.5,
# "ymax":0.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("rb2vEZ");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### Define normalization range using `vmin, vmax` parameters

# %%
# Set upper limit less than the data max value.
(p + geom_imshow(arr_f0, vmax=.5)).show()
(p + geom_imshow(arr_f1, vmax=100)).show()
(p + geom_imshow(arr_i, vmax=100)).show()
# Out:
#    <div id="UB6opx"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":450,
# "height":60
# },
# "coord":{
# "name":"cartesian",
# "flip":false
# },
# "theme":{
# "name":"classic",
# "axis":"blank"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"rect",
# "mapping":{
# },
# "data_meta":{
# },
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":29.5,
# "ymax":0.5,
# "color":"black",
# "alpha":0,
# "data":{
# }
# },{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":29.5,
# "ymax":0.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("UB6opx");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
#    <div id="XclBXt"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":450,
# "height":60
# },
# "coord":{
# "name":"cartesian",
# "flip":false
# },
# "theme":{
# "name":"classic",
# "axis":"blank"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"rect",
# "mapping":{
# },
# "data_meta":{
# },
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":29.5,
# "ymax":0.5,
# "color":"black",
# "alpha":0,
# "data":{
# }
# },{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":29.5,
# "ymax":0.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("XclBXt");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
#    <div id="scQAYS"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":450,
# "height":60
# },
# "coord":{
# "name":"cartesian",
# "flip":false
# },
# "theme":{
# "name":"classic",
# "axis":"blank"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"rect",
# "mapping":{
# },
# "data_meta":{
# },
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":29.5,
# "ymax":0.5,
# "color":"black",
# "alpha":0,
# "data":{
# }
# },{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":29.5,
# "ymax":0.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("scQAYS");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# Set limits wider than the data entire range.
(p + geom_imshow(arr_f0, vmin=.4, vmax=.6)).show()
(p + geom_imshow(arr_f1, vmin=70, vmax=120)).show()
(p + geom_imshow(arr_i, vmin=50, vmax=150)).show()
# Out:
#    <div id="MPGgSb"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":450,
# "height":60
# },
# "coord":{
# "name":"cartesian",
# "flip":false
# },
# "theme":{
# "name":"classic",
# "axis":"blank"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"rect",
# "mapping":{
# },
# "data_meta":{
# },
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":29.5,
# "ymax":0.5,
# "color":"black",
# "alpha":0,
# "data":{
# }
# },{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":29.5,
# "ymax":0.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("MPGgSb");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
#    <div id="NfvpJH"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":450,
# "height":60
# },
# "coord":{
# "name":"cartesian",
# "flip":false
# },
# "theme":{
# "name":"classic",
# "axis":"blank"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"rect",
# "mapping":{
# },
# "data_meta":{
# },
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":29.5,
# "ymax":0.5,
# "color":"black",
# "alpha":0,
# "data":{
# }
# },{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":29.5,
# "ymax":0.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("NfvpJH");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
#    <div id="rqB5Ra"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":450,
# "height":60
# },
# "coord":{
# "name":"cartesian",
# "flip":false
# },
# "theme":{
# "name":"classic",
# "axis":"blank"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"rect",
# "mapping":{
# },
# "data_meta":{
# },
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":29.5,
# "ymax":0.5,
# "color":"black",
# "alpha":0,
# "data":{
# }
# },{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":29.5,
# "ymax":0.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("rqB5Ra");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### Colormaps

# %%
(p + geom_imshow(arr_f0, cmap="magma")).show()
(p + geom_imshow(arr_f1, cmap="viridis")).show()
(p + geom_imshow(arr_i, cmap="plasma")).show()
# Out:
#    <div id="gQgktS"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":450,
# "height":60
# },
# "coord":{
# "name":"cartesian",
# "flip":false
# },
# "theme":{
# "name":"classic",
# "axis":"blank"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"rect",
# "mapping":{
# },
# "data_meta":{
# },
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":29.5,
# "ymax":0.5,
# "color":"black",
# "alpha":0,
# "data":{
# }
# },{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":29.5,
# "ymax":0.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("gQgktS");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
#    <div id="oGqfSN"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":450,
# "height":60
# },
# "coord":{
# "name":"cartesian",
# "flip":false
# },
# "theme":{
# "name":"classic",
# "axis":"blank"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"rect",
# "mapping":{
# },
# "data_meta":{
# },
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":29.5,
# "ymax":0.5,
# "color":"black",
# "alpha":0,
# "data":{
# }
# },{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":29.5,
# "ymax":0.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("oGqfSN");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
#    <div id="RotbnO"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":450,
# "height":60
# },
# "coord":{
# "name":"cartesian",
# "flip":false
# },
# "theme":{
# "name":"classic",
# "axis":"blank"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"rect",
# "mapping":{
# },
# "data_meta":{
# },
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":29.5,
# "ymax":0.5,
# "color":"black",
# "alpha":0,
# "data":{
# }
# },{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":29.5,
# "ymax":0.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("RotbnO");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
