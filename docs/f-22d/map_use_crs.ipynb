# %% [markdown]
# ## Parameter `use_crs`
#
# The `use_crs` parameter is supported by all geometry layers which have the `map` parameter, i.e. by layers which can be used for vizualization of Geopandas GeoDataFrame.
#
# Those layers are: `point, path, polygon, text, label and map`.
#
# By default, Lets-Plot converts all coordinates in every GeoDataFrame to degrees of longitude and latitude and leter projects these map coordinates to screen coordinates useing Mercator projection.
#
# Sometimes it might be necessary to use some other coordinate reference system (CRS) instead of the default WGS84 / Mercator.
#
# If this is the case, you can use the `use_crs` parameter to specify EPSG code of CRS to project GeoDataFrame coordinates to.

# %%
import numpy as np
from lets_plot import *
LetsPlot.setup_html()
# Out:
#             <div id="5PnYhU"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v2.5.1rc1/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("5PnYhU").appendChild(div);
#                     };
#                     var e = document.getElementById("5PnYhU");
#                     e.appendChild(script);
#                 })()
#             </script>

# %% [markdown]
# Let's say we have a raster image (for example, a satellite or aerial photograph, or a DEM image) that covers a square lend area with:
# - left-bottom corner at coordinates (25_000, 4_500_000)
# - right-top corner at coordinates (525_000, 5_000_000)
#
# In practice, the image coordinates and the image coordinate reference system (CRS) are known from
# a metadata accompanying the image.
#
# Here, for the sake of simplicity, we will use just a simple generated image 2 x 2 pix.
#
# We will also presume that our image coordinates use [UTM zone 33N](https://epsg.io/32633) CRS (aka EPSG:32633).
#
# Thus, the image coordinates are given in **meters** instead of more familiar longitude and latatude.

# %%
# image 2 x 2 pix
image_arr = np.array([
    [[150, 0, 0], [0, 150, 0]],
    [[0, 0, 150], [150, 150, 0]]
])

image_CRS = "EPSG:32633"

# Image coordinates
min_x = 25_000
max_x = 525_000
min_y = 4_500_000
max_y = 5_000_000

ggplot() + geom_imshow(image_arr, extent=[min_x, max_x, min_y, max_y])
# Out:
#    <div id="iu72eH"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"...",
# "xmin":25000.0,
# "ymin":4500000.0,
# "xmax":525000.0,
# "ymax":5000000.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("iu72eH");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ### Combining image and map
#
# Step 1 here would be to aquare a Geopandas GeoDataFrame containing map of the area of interesst.
#
# In this demo we will use GeoDataFrame containing a map of Italy which we will obtain using Lets-Plot geocoding module.

# %%
from lets_plot.geo_data import *
# Out:
# The geodata is provided by © OpenStreetMap contributors and is made available here under the Open Database License (ODbL).

# %%
italy = geocode_countries('italy').inc_res().get_boundaries()

ggplot() + geom_map(map=italy)
# Out:
#    <div id="oUcIot"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"map",
# "mapping":{
# },
# "data_meta":{
# },
# "map":{
# "country":["italy"],
# "found name":["Italia"],
# "geometry":["{\"type\": \"MultiPolygon\", \"coordinates\": [[[[14.4580078125, 40.6806380252146], [14.4580078125, 40.713955826286], [14.4580078125, 40.7472569628042], [14.4140625, 40.7472569628042], [14.3701171875, 40.7805414318603], [14.326171875, 40.8138092305696], [14.2822265625, 40.8470603560712], [14.2822265625, 40.8138092305696], [14.23828125, 40.8470603560712], [14.23828125, 40.8138092305696], [14.1943359375, 40.8138092305696], [14.150390625, 40.7805414318603], [14.150390625, 40.8138092305696], [14.1064453125, 40.8138092305696], [14.0625, 40.8138092305696], [14.0625, 40.8470603560712], [14.0185546875, 40.9135125761276], [14.0185546875, 40.94671366508], [13.974609375, 40.9798980696201], [13.974609375, 41.0130657870063], [13.9306640625, 41.0130657870063], [13
949, 4567678.216357676], [340355.36411872646, 4564008.844660506], [336671.06943424133, 4564090.483292958], [336753.33293320343, 4567759.867566987], [333155.0168437271, 4571510.944004451], [333239.164012722, 4575176.667987818], [329646.4351499847, 4578925.974015811], [326057.42358464294, 4582675.333909858], [322472.1301279868, 4586424.74794994], [318798.91979583027, 4586515.791025281], [315125.695981453, 4586608.700615257], [311452.4584144356, 4586703.476850717], [307876.4220194755, 4590458.586552728], [304205.016206766, 4590557.110786883], [300533.5959706416, 4590657.502342328], [300634.54641188507, 4594314.158519708], [297170.63938118226, 4601724.254241005], [286498.36385134165, 4612990.434345833], [282948.3885343955, 4616745.942496905], [279402.13951477513, 4620501.508330625], [272204.83703058696, 4624372.610564463], [268550.0410864977, 4624489.960083552], [268667.89187030884, 4628130.178536732], [268903.6406036998, 4635405.084615959], [265374.18547084916, 4639159.053719828], [261848.4612016108, 4642913.080844911], [261970.12047177006, 4646544.108858143], [258326.4686059196, 4646667.166094124], [254808.20849287955, 4650421.309560099], [251293.6816707491, 4654175.511325205], [247653.71666248966, 4654304.219415468], [244144.7755535598, 4658060.369129738], [240506.6464940362, 4658192.841183503], [236868.50155150332, 4658327.18780433], [237003.29259369895, 4661950.940172861], [237138.0999461767, 4665572.845205914], [233503.67514202598, 4665709.098503467], [233640.36706735054, 4669329.171649906], [230007.7949529916, 4669467.316205674], [230146.37188330299, 4673085.557068894], [230284.9649992017, 4676701.949522673], [226796.59377047163, 4680456.560829991], [226937.08835707878, 4684069.27112815], [223311.96226645855, 4684211.230727983], [223454.34273630503, 4687822.107104048], [216353.92163144232, 4691720.746248692], [209260.9375189875, 4695625.1082193265], [202175.3922521472, 4699535.195488432], [195097.2877428977, 4703451.0105044], [191481.37547614216, 4703609.953309565], [187865.44691110385, 4703770.775853914], [187704.2848308278, 4700167.143435044], [187543.13993644383, 4696561.6586428005], [183923.4488988201, 4696724.327685991], [184086.46669411066, 4700329.829315315], [180468.63167542557, ...

# %%
# Select better theme and colors
( ggplot()  
  + geom_imshow(image_arr, extent=[min_x, max_x, min_y, max_y])
  + geom_map(map=italy, use_crs=image_CRS, color="#a6b6ba", size=.8) 
  + labs(x="", y="")
  + theme_bw()+ flavor_solarized_dark()
  + ggsize(500, 500)
)
# Out:
#    <div id="OhpZeU"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "name":"bw",
# "flavor":"solarized_dark"
# },
# "ggsize":{
# "width":500,
# "height":500
# },
# "kind":"plot",
# "scales":[{
# "name":"",
# "aesthetic":"x"
# },{
# "name":"",
# "aesthetic":"y"
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# },
# "data_meta":{
# },
# "href":"...",
# "xmin":25000.0,
# "ymin":4500000.0,
# "xmax":525000.0,
# "ymax":5000000.0,
# "data":{
# }
# },{
# "geom":"map",
# "mapping":{
# },
# "data_meta":{
# },
# "map":{
# "country":["italy"],
# "found name":["Italia"],
# "geometry":["{\"type\": \"MultiPolygon\", \"coordinates\": [[[