# %% [markdown]
# # Rotation of axis labels
#
# The `angle` parameter in `element_text()` function allows to rotate the text. This functionality is currently available to rotate axis labels (i.e. for the `axis_text, axis_text_x, axis_text_y` parameters in a `theme()`).

# %%
import pandas as pd

from lets_plot import *

# %%
LetsPlot.setup_html()
# Out:
#             <script type="text/javascript" data-lets-plot-script="library">
#                 window.letsPlotCall = function(f) {f();};
#                 console.log('Embedding: lets-plot-latest.min.js');
# ...

# %%
df = pd.read_csv ("https://vincentarelbundock.github.io/Rdatasets/csv/ggplot2/diamonds.csv")

# %% [markdown]
# #### 1. Default Axis Labels Layout

# %%
p = ggplot(df) + geom_bar(aes("cut"))
p
# Out:
#    <div id="j62Zhl"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"cut"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[21551.0,13791.0,4906.0,12082.0,1610.0],
# "cut":["Ideal","Premium","Good","Very Good","Fair"]
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("j62Zhl");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### 2. `axis_text_y=element_text(angle=90)`

# %%
p + theme(axis_text_y=element_text(angle=90))
# Out:
#    <div id="eDaDQj"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_text_y":{
# "angle":90,
# "blank":false
# }
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"cut"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[21551.0,13791.0,4906.0,12082.0,1610.0],
# "cut":["Ideal","Premium","Good","Very Good","Fair"]
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("eDaDQj");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### 3. `axis_text_x=element_text(angle=-30)`

# %%
p + theme(axis_text=element_text(angle=-30), axis_text_y=element_text(angle=90)) + ggsize(300, 250)
# Out:
#    <div id="r9Osfv"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_text":{
# "angle":-30,
# "blank":false
# },
# "axis_text_y":{
# "angle":90,
# "blank":false
# }
# },
# "ggsize":{
# "width":300,
# "height":250
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"cut"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[21551.0,13791.0,4906.0,12082.0,1610.0],
# "cut":["Ideal","Premium","Good","Very Good","Fair"]
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("r9Osfv");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
