# %% [markdown]
# # Annotated Barchart
#
# Use the `labels` parameter to create an annotated Barchart.

# %%
import pandas as pd

from lets_plot import *

# %%
LetsPlot.setup_html()
# Out:
#             <div id="QVZ07T"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.1.0rc1/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("QVZ07T").appendChild(div);
#                     };
#                     var e = document.getElementById("QVZ07T");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
mpg_df = pd.read_csv ("https://raw.githubusercontent.com/JetBrains/lets-plot-docs/master/data/mpg.csv")
mpg_df.head(4)
# Out:
#    Unnamed: 0 manufacturer model  displ  year  cyl       trans drv  cty  hwy  \
# 0           1         audi    a4    1.8  1999    4    auto(l5)   f   18   29
# 1           2         audi    a4    1.8  1999    4  manual(m5)   f   21   29
# 2           3         audi    a4    2.0  2008    4  manual(m6)   f   20   31
# 3           4         audi    a4    2.0  2008    4    auto(av)   f   21   30
#
#   fl    class
# 0  p  compact
# 1  p  compact
# 2  p  compact
# 3  p  compact

# %% [markdown]
# #### Configure Layer Labels Using API Similar to the Tooltip Configuration API

# %%
gggrid([
    ggplot(mpg_df) + geom_bar(aes("trans"),
                              labels=layer_labels().line('@..count..')),
    ggplot(mpg_df) + geom_bar(aes("trans", y="..n.."), stat="sum", size=0,
                              labels=layer_labels().line('@..proppct..')) + coord_flip()
], widths=[1, 1.2])
# Out:
#    <div id="n5yOig"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":1.0,
# "widths":[1.0,1.2],
# "name":"grid"
# },
# "figures":[{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"trans"
# },
# "data_meta":{
# },
# "labels":{
# "formats":[],
# "lines":["@..count.."]
# },
# "data":{
# "..count..":[39.0,58.0,19.0,5.0,16.0,83.0,2.0,6.0,3.0,3.0],
# "trans":["auto(l5)","manual(m5)","manual(m6)","auto(av)","auto(s6)","auto(l4)","auto(l3)","auto(l6)","auto(s5)","auto(s4)"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "coord":{
# "name":"flip",
# "flip":true
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"sum",
# "mapping":{
# "x":"trans",
# "y":"..n.."
# },
# "data_meta":{
# },
# "labels":{
# "formats":[],
# "lines":["@..proppct.."]
# },
# "size":0.0,
# "data":{
# "..proppct..":[16.666666666666664,24.786324786324787,8.11965811965812,2.1367521367521367,6.837606837606838,35.47008547008547,0.8547008547008548,2.564102564102564,1.282051282051282,1.282051282051282],
# "..n..":[39.0,58.0,19.0,5.0,16.0,83.0,2.0,6.0,3.0,3.0],
# "trans":["auto(l5)","manual(m5)","manual(m6)","auto(av)","auto(s6)","auto(l4)","auto(l3)","auto(l6)","auto(s5)","auto(s4)"]
# }
# }],
# "metainfo_list":[]
# }]
# };
#            var plotContainer = document.getElementById("n5yOig");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### Stacked Bars

# %%
ggplot(mpg_df, aes('class', fill='drv')) + \
    geom_bar(labels=layer_labels().line('@..proppct..').format('..proppct..', '{d} %')) + \
    ggsize(700, 400)
# Out:
#    <div id="16HzXM"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# },
# "mapping":{
# "x":"class",
# "fill":"drv"
# },
# "data_meta":{
# },
# "ggsize":{
# "width":700.0,
# "height":400.0
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# },
# "data_meta":{
# },
# "labels":{
# "formats":[{
# "field":"..proppct..",
# "format":"{d} %"
# }],
# "lines":["@..proppct.."]
# },
# "data":{
# "..count..":[35.0,38.0,11.0,22.0,12.0,3.0,51.0,33.0,4.0,11.0,5.0,9.0],
# "class":["compact","midsize","minivan","subcompact","compact","midsize","suv","pickup","subcompact","suv","2seater","subcompact"],
# "drv":["f","f","f","f","4","4","4","4","4","r","r","r"],
# "..proppct..":[74.46808510638297,92.6829268292683,100.0,62.857142857142854,25.53191489361702,7.317073170731707,82.25806451612904,100.0,11.428571428571429,17.741935483870968,100.0,25.71428571428571]
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("16HzXM");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
ggplot(mpg_df, aes('class', fill='drv')) + \
    geom_bar(labels=layer_labels().line('@..proppct..').format('..proppct..', '{d} %'), 
             position='fill') + \
    coord_flip() + \
    ggsize(700, 400)
# Out:
#    <div id="rWYAPS"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# },
# "mapping":{
# "x":"class",
# "fill":"drv"
# },
# "data_meta":{
# },
# "coord":{
# "name":"flip",
# "flip":true
# },
# "ggsize":{
# "width":700.0,
# "height":400.0
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# },
# "position":"fill",
# "data_meta":{
# },
# "labels":{
# "formats":[{
# "field":"..proppct..",
# "format":"{d} %"
# }],
# "lines":["@..proppct.."]
# },
# "data":{
# "..count..":[35.0,38.0,11.0,22.0,12.0,3.0,51.0,33.0,4.0,11.0,5.0,9.0],
# "class":["compact","midsize","minivan","subcompact","compact","midsize","suv","pickup","subcompact","suv","2seater","subcompact"],
# "drv":["f","f","f","f","4","4","4","4","4","r","r","r"],
# "..proppct..":[74.46808510638297,92.6829268292683,100.0,62.857142857142854,25.53191489361702,7.317073170731707,82.25806451612904,100.0,11.428571428571429,17.741935483870968,100.0,25.71428571428571]
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("rWYAPS");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### Narrow Bars
# Too thin for labels to fit in.

# %%
ggplot(mpg_df, aes('class', fill='drv')) + \
    geom_bar(labels=layer_labels().line('@..proppct..').format('..proppct..', '{d} %'),
             position='dodge') + \
    ggsize(700, 400)
# Out:
#    <div id="N96pF7"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# },
# "mapping":{
# "x":"class",
# "fill":"drv"
# },
# "data_meta":{
# },
# "ggsize":{
# "width":700.0,
# "height":400.0
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# },
# "position":"dodge",
# "data_meta":{
# },
# "labels":{
# "formats":[{
# "field":"..proppct..",
# "format":"{d} %"
# }],
# "lines":["@..proppct.."]
# },
# "data":{
# "..count..":[35.0,38.0,11.0,22.0,12.0,3.0,51.0,33.0,4.0,11.0,5.0,9.0],
# "class":["compact","midsize","minivan","subcompact","compact","midsize","suv","pickup","subcompact","suv","2seater","subcompact"],
# "drv":["f","f","f","f","4","4","4","4","4","r","r","r"],
# "..proppct..":[74.46808510638297,92.6829268292683,100.0,62.857142857142854,25.53191489361702,7.317073170731707,82.25806451612904,100.0,11.428571428571429,17.741935483870968,100.0,25.71428571428571]
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("N96pF7");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
