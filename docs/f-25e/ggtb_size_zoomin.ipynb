# %% [markdown]
# # `ggtb()`: `size_zoomin` and `size_basis` Parameters for Geometry Scaling
#
# ## `size_zoomin` parameter
#
# The `size_zoomin` parameter accepts an integer value:
#
# * `0` — zoom in disabled (default)
# * `-1` — unlimited zoom in
# * Any other positive number — maximum zoom-in limit. For example, `2` means the geometry can be scaled up to **2×**.
#
# ## `size_basis` parameter
#
# The `size_basis` parameter accepts a string value: `x`, `y`, `min`, or `max` (default: `max`).
# It defines which axis is used to calculate the scaling factor.
#
# * `x` and `y` specify the corresponding axis.
# * `min` uses the smaller scaling factor.
# * `max` uses the larger scaling factor.

# %%
from lets_plot import *
import pandas as pd
LetsPlot.setup_html()
# Out:
#             <div id="G2eK4d"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.8.0rc1/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("G2eK4d").appendChild(div);
#                     };
#                     var e = document.getElementById("G2eK4d");
#                     e.appendChild(script);
#                 })()
#             </script>

# %% [markdown]
# #### Enable 'Unlimited' Zoom

# %%
ggplot() + geom_point(x=0, y=0, size=10) + ggtb(
    size_zoomin=-1                             # <-- Point size can grow without limits.
)
# Out:
#    <div id="G4Drgm"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("G4Drgm");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "mapping":{
# },
# "data_meta":{
# },
# "ggtoolbar":{
# "size_zoomin":-1.0
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "size":10.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"1"
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# #### Limit Maximum Zoom to 3× Original Size

# %%
mpg = pd.read_csv('https://raw.githubusercontent.com/JetBrains/lets-plot-docs/master/data/mpg2.csv')

# %%
p = (
  ggplot(mpg, 
         aes('engine horsepower', 'miles per gallon', 
             color=as_discrete('origin of car',order=-1)))  
  + theme_grey() + ggtitle('Efficiency vs Engine Horsepower')
)

# %%
p + geom_jitter(seed=42) + ggtb(
    size_zoomin=3                 # <-- Point size can grow to 3x of the original size max.
)
# Out:
#    <div id="WdHZGz"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("WdHZGz");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# "miles per gallon":[18.0,15.0,18.0,16.0,17.0,15.0,14.0,14.0,14.0,15.0,15.0,14.0,15.0,14.0,24.0,22.0,18.0,21.0,27.0,26.0,25.0,24.0,25.0,26.0,21.0,10.0,10.0,11.0,9.0,27.0,28.0,25.0,19.0,16.0,17.0,19.0,18.0,14.0,14.0,14.0,14.0,12.0,13.0,13.0,18.0,22.0,19.0,18.0,23.0,28.0,30.0,30.0,31.0,35.0,27.0,26.0,24.0,25.0,23.0,20.0,21.0,13.0,14.0,15.0,14.0,17.0,11.0,13.0,12.0,13.0,19.0,15.0,13.0,13.0,14.0,18.0,22.0,21.0,26.0,22.0,28.0,23.0,28.0,27.0,13.0,14.0,13.0,14.0,15.0,12.0,13.0,13.0,14.0,13.0,12.0,13.0,18.0,16.0,18.0,18.0,23.0,26.0,11.0,12.0,13.0,12.0,18.0,20.0,21.0,22.0,18.0,19.0,21.0,26.0,15.0,16.0,29.0,24.0,20.0,19.0,15.0,24.0,20.0,11.0,20.0,19.0,15.0,31.0,26.0,32.0,25.0,16.0,16.0,18.0,16.0,13.0,14.0,14.0,14.0,29.0,26.0,26.0,31.0,32.0,28.0,24.0,26.0,24.0,26.0,31.0,19.0,18.0,15.0,15.0,16.0,15.0,16.0,14.0,17.0,16.0,15.0,18.0,21.0,20.0,13.0,29.0,23.0,20.0,23.0,24.0,25.0,24.0,18.0,29.0,19.0,23.0,23.0,22.0,25.0,33.0,28.0,25.0,25.0,26.0,27.0,17.5,16.0,15.5,14.5,22.0,22.0,24.0,22.5,29.0,24.5,29.0,33.0,20.0,18.0,18.5,17.5,29.5,32.0,28.0,26.5,20.0,13.0,19.0,19.0,16.5,16.5,13.0,13.0,13.0,31.5,30.0,36.0,25.5,33.5,17.5,17.0,15.5,15.0,17.5,20.5,19.0,18.5,16.0,15.5,15.5,16.0,29.0,24.5,26.0,25.5,30.5,33.5,30.0,30.5,22.0,21.5,21.5,43.1,36.1,32.8,39.4,36.1,19.9,19.4,20.2,19.2,20.5,20.2,25.1,20.5,19.4,20.6,20.8,18.6,18.1,19.2,17.7,18.1,17.5,30.0,27.5,27.2,30.9,21.1,23.2,23.8,23.9,20.3,17.0,21.6,16.2,31.5,29.5,21.5,19.8,22.3,20.2,20.6,17.0,17.6,16.5,18.2,16.9,15.5,19.2,18.5,31.9,34.1,35.7,27.4,25.4,23.0,27.2,23.9,34.2,34.5,31.8,37.3,28.4,28.8,26.8,33.5,41.5,38.1,32.1,37.2,28.0,26.4,24.3,19.1,34.3,29.8,31.3,37.0,32.2,46.6,27.9,40.8,44.3,43.4,36.4,30.0,44.6,33.8,29.8,32.7,23.7,35.0,32.4,27.2,26.6,25.8,23.5,30.0,39.1,39.0,35.1,32.3,37.0,37.7,34.1,34.7,34.4,29.9,33.0,33.7,32.4,32.9,31.6,28.1,30.7,25.4,24.2,22.4,26.6,20.2,17.6,28.0,27.0,34.0,31.0,29.0,27.0,24.0,36.0,37.0,31.0,38.0,36.0,36.0,36.0,34.0,38.0,32.0,38.0,25.0,38.0,26.0,22.0,32.0,36.0,27.0,27.0,44.0,32.0,28.0,31.0],
# "engine horsepower":[130.0,165.0,150.0,150.0,140.0,198.0,220.0,215.0,225.0,190.0,170.0,160.0,150.0,225.0,95.0,95.0,97.0,85.0,88.0,46.0,87.0,90.0,95.0,113.0,90.0,215.0,200.0,210.0,193.0,88.0,90.0,95.0,100.0,105.0,100.0,88.0,100.0,165.0,175.0,153.0,150.0,180.0,170.0,175.0,110.0,72.0,100.0,88.0,86.0,90.0,70.0,76.0,65.0,69.0,60.0,70.0,95.0,80.0,54.0,90.0,86.0,165.0,175.0,150.0,153.0,150.0,208.0,155.0,160.0,190.0,97.0,150.0,130.0,140.0,150.0,112.0,76.0,87.0,69.0,86.0,92.0,97.0,80.0,88.0,175.0,150.0,145.0,137.0,150.0,198.0,150.0,158.0,150.0,215.0,225.0,175.0,105.0,100.0,100.0,88.0,95.0,46.0,150.0,167.0,170.0,180.0,100.0,88.0,72.0,94.0,90.0,85.0,107.0,90.0,145.0,230.0,49.0,75.0,91.0,112.0,150.0,110.0,122.0,180.0,95.0,100.0,100.0,67.0,80.0,65.0,75.0,100.0,110.0,105.0,140.0,150.0,150.0,140.0,150.0,83.0,67.0,78.0,52.0,61.0,75.0,75.0,75.0,97.0,93.0,67.0,95.0,105.0,72.0,72.0,170.0,145.0,150.0,148.0,110.0,105.0,110.0,95.0,110.0,110.0,129.0,75.0,83.0,100.0,78.0,96.0,71.0,97.0,97.0,70.0,90.0,95.0,88.0,98.0,115.0,53.0,86.0,81.0,92.0,79.0,83.0,140.0,150.0,120.0,152.0,100.0,105.0,81.0,90.0,52.0,60.0,70.0,53.0,100.0,78.0,110.0,95.0,71.0,70.0,75.0,72.0,102.0,150.0,88.0,108.0,120.0,180.0,145.0,130.0,150.0,68.0,80.0,58.0,96.0,70.0,145.0,110.0,145.0,130.0,110.0,105.0,100.0,98.0,180.0,170.0,190.0,149.0,78.0,88.0,75.0,89.0,63.0,83.0,67.0,78.0,97.0,110.0,110.0,48.0,66.0,52.0,70.0,60.0,110.0,140.0,139.0,105.0,95.0,85.0,88.0,100.0,90.0,105.0,85.0,110.0,120.0,145.0,165.0,139.0,140.0,68.0,95.0,97.0,75.0,95.0,105.0,85.0,97.0,103.0,125.0,115.0,133.0,71.0,68.0,115.0,85.0,88.0,90.0,110.0,130.0,129.0,138.0,135.0,155.0,142.0,125.0,150.0,71.0,65.0,80.0,80.0,77.0,125.0,71.0,90.0,70.0,70.0,65.0,69.0,90.0,115.0,115.0,90.0,76.0,60.0,70.0,65.0,90.0,88.0,90.0,90.0,78.0,90.0,75.0,92.0,75.0,65.0,105.0,65.0,48.0,48.0,67.0,67.0,67.0,67.0,62.0,132.0,100.0,88.0,72.0,84.0,84.0,92.0,110.0,84.0,58.0,64.0,60.0,67.0,65.0,62.0,68.0,63.0,65.0,65.0,74.0,75.0,75.0,100.0,74.0,80.0,76.0,116.0,120.0,110.0,105.0,88.0,85.0,88.0,88.0,88.0,85.0,84.0,90.0,92.0,74.0,68.0,68.0,63.0,70.0,88.0,75.0,70.0,67.0,67.0,67.0,110.0,85.0,92.0,112.0,96.0,84.0,90.0,86.0,52.0,84.0,79.0,82.0],
# "origin of car":["US","US","US","US","US","US","US","US","US","US","US","US","US","US","Asia","US","US","US","Asia","Europe","Europe","Europe","Europe","Europe","US","US","US","US","US","Asia","US","Asia","US","US","US","US","US","US","US","US","US","US","US","US","US","US","US","US","US","Europe","Europe","Europe","Asia","Asia","Europe","US","Asia","US","Europe","US","US","US","US","US","US","US","US","US","US","US","Asia","US","US","US","US","Europe","Europe","Europe","Europe","US","Asia","Asia","US","Asia","US","US","US","US","US","US","US","US","US","US","US","US","US","US","US","US","US","Europe","US","US","US","US","US","Asia","US","Asia","Asia","US","US","Europe","US","US","Europe","Europe","Europe","Europe","US","Europe","Asia","US","US","US","US","Asia","US","Asia","US","US","US","US","US","US","US","US","US","Europe","Europe","Europe","Asia","Asia","US","Europe","Europe","Asia","Asia","Europe","US","US","US","US","US","US","US","US","US","US","US","US","US","US","US","Asia","US","US","US","Asia","Europe","Asia","US","Europe","US","Europe","Europe","Europe","Europe","Asia","Europe","Europe","US","US","Europe","US","US","US","US","US","US","US","US","US","US","Europe","Asia","US","US","US","US","Europe","Asia","Asia","US","Europe","US","Europe","Asia","Europe","US","US","US","US","Asia","US","Europe","US","Asia","US","US","US","US","US","US","US","US","US","US","US","US","Europe","US","Asia","US","US","US","Asia","Europe","Asia","Europe","Asia","Europe","US","Asia","Asia","Asia","US","US","US","US","US","US","US","US","US","US","US","US","US","US","US","US","US","US","Asia","Asia","US","Asia","US","US","Asia","Europe","Europe","Europe","Europe","Europe","Asia","US","US","US","US","US","US","US","US","US","US","US","US","US","Europe","Asia","US","US","Europe","US","Europe","US","US","US","Asia","Europe","US","US","US","US","Europe","Asia","US","Asia","US","US","US","US","Europe","Asia","Asia","Asia","Asia","Asia","US","Asia","Europe","Europe","Europe","Europe","Asia","Asia","Europe","Asia","Asia","Europe","Asia","US","US","US","US","US","Asia","US","Asia","Asia","Asia","Asia","Asia","US","US","US","Europe","Asia","Asia","Asia","Asia","Europe","Europe","Asia","Asia","US","US","US","US","US","US","US","US","US","US","US","Europe","Asia","Asia","US","US","Asia","Asia","Asia","Asia","Asia","Asia","US","US","US","US","Asia","US","US","US","Europe","US","US","US"]
# },
# "mapping":{
# "x":"engine horsepower",
# "y":"miles per gallon",
# "color":"origin of car"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"origin of car"
# },{
# "type":"float",
# "column":"miles per gallon"
# },{
# "type":"int",
# "column":"number of cylinders"
# },{
# "type":"float",
# "column":"engine displacement (cu. inches)"
# },{
# "type":"int",
# "column":"engine horsepower"
# },{
# "type":"int",
# "column":"vehicle weight (lbs.)"
# },{
# "type":"float",
# "column":"time to accelerate (sec.)"
# },{
# "type":"int",
# "column":"model year"
# },{
# "type":"str",
# "column":"vehicle name"
# }],
# "mapping_annotations":[{
# "parameters":{
# "label":"origin of car",
# "order":-1.0
# },
# "aes":"color",
# "annotation":"as_discrete"
# }]
