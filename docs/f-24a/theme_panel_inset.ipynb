# %%
from lets_plot import *
LetsPlot.setup_html()
# Out:
#             <div id="wJXVSx"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.3.0rc2/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("wJXVSx").appendChild(div);
#                     };
#                     var e = document.getElementById("wJXVSx");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
hours = list(map(lambda v: '{:02d}:00'.format(v), range(12)))

p = ggplot() \
    + geom_point(aes(x=hours)) \
    + theme_grey() \
    + theme(axis_line=element_line(color='black'))

# %% [markdown]
# # Linear coordinate system
# In linear coordinate systems `inset` acts as a margin, moving the panel boundaries within the plot:

# %%
gggrid([
    p,
    p + theme(panel_inset=15)
])
# Out:
#    <div id="6O6Awg"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "name":"grey",
# "axis_line":{
# "color":"black",
# "blank":false
# }
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# "x":"x"
# },
# "data_meta":{
# },
# "data":{
# "x":["00:00","01:00","02:00","03:00","04:00","05:00","06:00","07:00","08:00","09:00","10:00","11:00"]
# }
# }],
# "metainfo_list":[]
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "name":"grey",
# "axis_line":{
# "color":"black",
# "blank":false
# },
# "panel_inset":15.0
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# "x":"x"
# },
# "data_meta":{
# },
# "data":{
# "x":["00:00","01:00","02:00","03:00","04:00","05:00","06:00","07:00","08:00","09:00","10:00","11:00"]
# }
# }],
# "metainfo_list":[]
# }]
# };
#            var plotContainer = document.getElementById("6O6Awg");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# # Polar coordinate system
# Default inset may cause tick labels overlapping in polar coordinate system.
# The `panel_inset` parameter acts as a margin and can be used to create space between the axis and the panel:

# %%
inset = [0, 35, 0, 35]
polar = coord_polar()
gggrid([
    p + polar,
    p + theme(panel_inset=inset) + polar,
])
# Out:
#    <div id="rk52X9"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "name":"grey",
# "axis_line":{
# "color":"black",
# "blank":false
# }
# },
# "coord":{
# "name":"polar"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# "x":"x"
# },
# "data_meta":{
# },
# "data":{
# "x":["00:00","01:00","02:00","03:00","04:00","05:00","06:00","07:00","08:00","09:00","10:00","11:00"]
# }
# }],
# "metainfo_list":[]
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "name":"grey",
# "axis_line":{
# "color":"black",
# "blank":false
# },
# "panel_inset":[0.0,35.0,0.0,35.0]
# },
# "coord":{
# "name":"polar"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# "x":"x"
# },
# "data_meta":{
# },
# "data":{
# "x":["00:00","01:00","02:00","03:00","04:00","05:00","06:00","07:00","08:00","09:00","10:00","11:00"]
# }
# }],
# "metainfo_list":[]
# }]
# };
#            var plotContainer = document.getElementById("rk52X9");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# # Parameter `transform_bkgr`
#
# When using the `transform_bkgr` parameter, the panel is not transformed into a circle, but remains a rectangle. This behaviour is similar to `ggplot2`.
# In this case, `panel_inset` acts as padding, pushing the content into the panel:

# %%
polar = coord_polar(transform_bkgr=False)
gggrid([
    p + polar,
    p + theme(panel_inset=inset) + polar
])
# Out:
#    <div id="yzcqEw"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "name":"grey",
# "axis_line":{
# "color":"black",
# "blank":false
# }
# },
# "coord":{
# "name":"polar",
# "transform_bkgr":false
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# "x":"x"
# },
# "data_meta":{
# },
# "data":{
# "x":["00:00","01:00","02:00","03:00","04:00","05:00","06:00","07:00","08:00","09:00","10:00","11:00"]
# }
# }],
# "metainfo_list":[]
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "name":"grey",
# "axis_line":{
# "color":"black",
# "blank":false
# },
# "panel_inset":[0.0,35.0,0.0,35.0]
# },
# "coord":{
# "name":"polar",
# "transform_bkgr":false
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# "x":"x"
# },
# "data_meta":{
# },
# "data":{
# "x":["00:00","01:00","02:00","03:00","04:00","05:00","06:00","07:00","08:00","09:00","10:00","11:00"]
# }
# }],
# "metainfo_list":[]
# }]
# };
#            var plotContainer = document.getElementById("yzcqEw");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# # `coord_fixed()`
# This is how `panel_inset` works in `coord_fixed()`.

# %%
inset = 40
p \
    + scale_x_continuous(position='both') \
    + scale_y_continuous(position='both') \
    + coord_fixed() \
    + ggtitle('coord_fixed() + inset=' + str(inset)) \
    + theme(panel_inset=inset)
# Out:
#    <div id="Ypubbm"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "name":"grey",
# "axis_line":{
# "color":"black",
# "blank":false
# },
# "panel_inset":40.0
# },
# "coord":{
# "name":"fixed",
# "ratio":1.0,
# "flip":false
# },
# "ggtitle":{
# "text":"coord_fixed() + inset=40"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "position":"both"
# },{
# "aesthetic":"y",
# "position":"both"
# }],
# "layers":[{
# "geom":"point",
# "mapping":{
# "x":"x"
# },
# "data_meta":{
# },
# "data":{
# "x":["00:00","01:00","02:00","03:00","04:00","05:00","06:00","07:00","08:00","09:00","10:00","11:00"]
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("Ypubbm");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
